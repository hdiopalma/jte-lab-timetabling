# %% [markdown]
# # Sistem Penjadwalan Praktikum Otomatis menggunakan Algoritma Genetika dan Tabu Search.

# %% [markdown]
# # Setup

# %%
import os
import sys
import django
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "LabTimetablingAPI.settings")
django.setup()
from django.conf import settings
#set debug to true
settings.DEBUG = True

#logging
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %% [markdown]
# ## Data

# %% [markdown]
# Import data dari model yang telah dibuat sebelumnya.
#
# ```python

# %%
from scheduling_data.models import Laboratory, Module, Participant, Group, Assistant, Chapter

# %% [markdown]
# Ekstrak data dari model yang telah dibuat sebelumnya.
#
# ```python

# %%
class LaboratoryData:

    def __init__(self, lab = Laboratory):
        self._lab = lab
        self._laboratories = lab.objects.all()

    @property
    def laboratories(self): 
        return self._laboratories
    
    def get_assistant(self,id):
        laboratory = self._laboratories.filter(id=id).first()
        assistants = laboratory.assistants.all()
        return assistants
    
    def get_module(self,id):
        laboratory = self._laboratories.filter(id=id).first()
        modules = laboratory.modules.all()
        return modules
    
class ModuleData:

    def __init__(self, module = Module):
        self._module = module
        self._modules = module.objects.all()

    @property
    def modules(self): 
        return self._modules
    
    def get_module(self,id):
        module = self._modules.filter(id=id).first()
        return module
    
    def get_module_chapter(self, id):
        module = self.get_module(id)
        return module.chapters.all()
    
    def get_group(self, id):
        module = self.get_module(id)
        return module.groups.all()
    
    def get_laboratory(self, id):
        module = self.get_module(id)
        return module.laboratory
    
        
class ChapterData:

    def __init__(self, chapter = Chapter):
        self._chapter = chapter
        self._chapters = chapter.objects.all()

    @property
    def chapters(self): 
        return self._chapters
    
    def get_chapter(self,id):
        chapter = self._chapters.filter(id=id).first()
        return chapter
    
    def get_chapter_module(self, id):
        chapter = self.get_chapter(id)
        return chapter.module

class ParticipantData:

    def __init__(self, participant = Participant):
        self._participant = participant
        self._participants = participant.objects.all()
    
    @property
    def participants(self):
        return self._participants
    
    def group(self, id):
        group_memberships = self._participants.filter(id=id).first().group_memberships.all()
        groups = []
        for group_membership in group_memberships:
            group = group_membership.group
            groups.append(group)
        return groups
    
class GroupData:
    def __init__(self, group = Group):
        self._group = group
        self._groups = group.objects.all()

    @property
    def groups(self):
        return self._groups
    
    def get_group(self, id):
        group = self._groups.filter(id=id).first()
        return group
    
    def get_module_group(self, module_id):
        groups = self._groups.filter(module_id=module_id)
        return groups
    
    def participants(self, id):
        group = self._groups.filter(id=id).first()
        group_memberships = group.group_memberships.all()
        participants = []
        for group_membership in group_memberships:
            participant = group_membership.participant
            participants.append(participant)
        return participants
    
    def get_participant_schedule(self, id):
        participants = self.participants(id)
        participant_schedule = []
        for participant in participants:
            participant_schedule.append(participant.regular_schedule)
        return participant_schedule
    
    def get_group_schedule(self, id):
        participant_schedule = self.get_participant_schedule(id)
        if len(participant_schedule) == 0:
            return {}
        days = participant_schedule[0].keys()
        merged_schedule = {day: {} for day in days}
        for day in days:
            for time_slot in participant_schedule[0][day]:
                is_available = all(schedule[day][time_slot] for schedule in participant_schedule)
                merged_schedule[day][time_slot] = is_available
        return merged_schedule
                
            
class AssistantData:

    def __init__(self, assistant = Assistant):
        self._assistant = assistant
        self._assistants = assistant.objects.all()

    @property
    def assistants(self):
        return self._assistants

    
    def get_assistant(self, id):
        assistant = self._assistants.filter(id=id).first()
        return assistant
    
    def get_assistant_modules(self,id):
        assistant = self._assistant.filter(id=id).first()
        assistant_memberships = assistant.assistant_memberships.all()
        modules = []
        for assistant_membership in assistant_memberships:
            module = assistant_membership.module
            modules.append(module)
        return modules

# %%
group_data = GroupData().groups
group_id = [group.id for group in group_data]
len(group_id)
# Out:
# 36

# %%
# import timeit
# import cProfile
# import pstats

# group_data = GroupData()

# group_id = [group.id for group in group_data.groups]

# def get_group_schedule(group_id = group_id, group_data = group_data):
#     for id in group_id:
#         group_data.get_group_schedule(id)
#     return group_id

# pr = cProfile.Profile()
# pr.enable()
# start = timeit.default_timer()
# #do it 10000000 times
# for i in range(1000):
#     get_group_schedule()
# stop = timeit.default_timer()
# pr.disable()

# %% [markdown]
# Constants
#
# ```python

# %%
# Constant.py
class Constant:
    days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]
    shifts = ["Shift1", "Shift2", "Shift3", "Shift4", "Shift5", "Shift6"]

# %% [markdown]
# # Algoritma Genetika

# %% [markdown]
# ## Gene Representation
#
# ```python

# %%
from collections import namedtuple
TimeSlot = namedtuple("TimeSlot", ["date", "day", "shift"])

class Gene:
    def __init__(self, laboratory, module, module_chapter, group, assistant, time_slot: TimeSlot):
        self.laboratory = laboratory
        self.module = module
        self.module_chapter = module_chapter
        self.group = group
        self.assistant = assistant
        self.time_slot = time_slot
        
    def __repr__(self):
        return f"Gene(lab={self.laboratory}, module={self.module}, module_chapter={self.module_chapter}, group={self.group}, assistant={self.assistant}, time_slot={self.time_slot})"
    
    def __eq__(self, other):
        return self.laboratory == other.laboratory and self.module == other.module and self.module_chapter == other.module_chapter and self.group == other.group and self.assistant == other.assistant and self.time_slot == other.time_slot

# %% [markdown]
# Test Gene Representation
#
# ```python

# %%
# Test Gene

# Assigning data to variables
lab_data = LaboratoryData()
module_data = ModuleData()
participant_data = ParticipantData()
group_data = GroupData()
assistant_data = AssistantData()
chapter_data = ChapterData()

gene = Gene(lab_data.laboratories[0].id, module_data.modules[0].id, chapter_data.chapters[0].id, group_data.groups[0].id,assistant_data.assistants[0].id, TimeSlot("2021-01-01", "Friday", "Shift1"))
gene2 = Gene(lab_data.laboratories[0].id, module_data.modules[0].id, chapter_data.chapters[0].id, group_data.groups[1].id, assistant_data.assistants[0].id, TimeSlot("2021-01-01", "Friday", "Shift2"))
gene3 = Gene(lab_data.laboratories[0].id, module_data.modules[0].id, chapter_data.chapters[0].id, group_data.groups[2].id, assistant_data.assistants[0].id, TimeSlot("2021-01-01", "Monday", "Shift1"))

# %% [markdown]
# ### Gene Level Constraints
#
# ```python

# %%
# Constraint Class for Constraint Function
# 1. Ensure that each chapter is assigned to the correct module.
# 2. Ensure that each module is assigned to the correct lab.
# 3. Ensure that each group is assigned to the correct module.
# 4. Ensure that each assistant is assigned to the correct lab.

# import LaboratoryData, ModuleData, GroupData, AssistantData, ChapterData

class ConstraintChecker:
    def __init__(self, gene : Gene, **kwargs):
        kwargs.setdefault("lab_data", LaboratoryData())
        kwargs.setdefault("module_data", ModuleData())
        kwargs.setdefault("group_data", GroupData())
        kwargs.setdefault("assistant_data", AssistantData())
        kwargs.setdefault("chapter_data", ChapterData())
        self.gene = gene
        self.lab_data = lab_data
        self.module_data = module_data
        self.group_data = group_data
        self.assistant_data = assistant_data
        self.chapter_data = chapter_data

    def chapter_module_constraint(self):
        module = self.module_data.get_module(self.gene.module)
        chapter = self.chapter_data.get_chapter(self.gene.module_chapter)
        return module == chapter.module
    
    def module_lab_constraint(self):
        module = self.module_data.get_module(self.gene.module)
        return module.laboratory.id == self.gene.laboratory
    
    def group_module_constraint(self):
        module = self.module_data.get_module(self.gene.module)
        group = self.group_data.get_group(self.gene.group)
        return module == group.module
    
    def assistant_lab_constraint(self):
        assistant = self.assistant_data.get_assistant(self.gene.assistant)
        return assistant.laboratory.id == self.gene.laboratory
    
    def schedule_constraint(self):
        return group_data.get_group_schedule(self.gene.group)[self.gene.time_slot.day][self.gene.time_slot.shift]
    
    def check(self):
        return self.chapter_module_constraint() and self.module_lab_constraint() and self.group_module_constraint() and self.assistant_lab_constraint()

# %% [markdown]
# Test Gene Level Constraints
#
# ```python

# %%
    # Test ConstraintChecker
ConstraintChecker(gene).check()
# Out:
# True

# %% [markdown]
# ## Chromosome Representation
#
# ```python

# %%
# Chromosome.py
# Chromosome Representation
# 1. Gene
# 2. Fitness

class Chromosome:
    def __init__(self, genes: list):
        self.genes = genes
        self.fitness = None

    def __repr__(self):
        return f"Chromosome(genes={self.genes}, fitness={self.fitness})"
    
    def __str__(self):
        return f"Chromosome(genes={self.genes}, fitness={self.fitness})"
    
    def __len__(self):
        return len(self.genes)
    
    def __eq__(self, other):
        #check for each gene if it is equal
        return all(gene == other_gene for gene, other_gene in zip(self.genes, other.genes))

# %% [markdown]
# ### Chromosome Level Constraints
#
# ```python

# %% [markdown]
# Objective class
# 1. Minimize conflict: Minimize conflicts in the schedule by ensuring that no two groups are assigned to the same lab and time slot simultaneously.
# 2. Maximize Resource Utilization: Maximize the utilization of assistants by distributing tasks evenly among them. Each assistant should be assigned to a balanced number of groups and shift to avoid overloading.
# 3. Maximize Participant Satisfaction: Maximize the satisfaction of participants by ensuring that each participant is assigned to a time slot that is available to them.

# %% [markdown]
# #### Objective Class for Fitness Function
# ##### 1. Minimize Conflicts:
# Minimize conflicts in the schedule by ensuring that no two groups are assigned to the same lab and time slot simultaneously.
#
# Deskripsi:
# - Jika dua kelompok berbeda memiliki jadwal yang sama, maka akan terjadi konflik.

# %%
#minimize_conflicts.py
from collections import namedtuple

class MinimizeConflicts:
    def __init__(self):
        self.conflicts = namedtuple("Conflicts", ["time_slot", "lab"])

    def calculate_conflicts(self, chromosome: Chromosome) -> int:
        conflicts_time_slot = set()
        assigned_time_slot = set()
        conflict_count = 0
        for gene in chromosome.genes:
            if (gene.laboratory, gene.time_slot) in assigned_time_slot:
                conflicts_time_slot.add(self.conflicts(gene.time_slot, gene.laboratory))
                conflict_count += 1
            else:
                assigned_time_slot.add((gene.laboratory, gene.time_slot))
        return conflict_count

    def calculate_fitness(self, chromosome: Chromosome) -> int:
        if settings.DEBUG:
            logger.info(f"Calculating conflicted group time slots for chromosome {chromosome}")
        return self.calculate_conflicts(chromosome)

# %% [markdown]
# ##### 2. Maximize Resource Utilization:
# Maximize the utilization of assistants by distributing tasks evenly among them. Each assistant should be assigned to a balanced number of groups and shift to avoid overloading.
#
# Deskripsi:
# - Menyeimbang tugas asistent dengan memastikan bahwa setiap asisten ditugaskan ke jumlah kelompok dan shift yang seimbang untuk menghindari overloading.

# %%
from collections import defaultdict

class MaximizeResourceUtilization:
    def __init__(self, max_groups_per_assistant: int = 2, max_shift_per_assistant: int = 2):
        self.max_groups_per_assistant = max_groups_per_assistant
        self.max_shift_per_assistant = max_shift_per_assistant
        self.assistants_assignments = defaultdict(list)
        self.assistants_shifts = defaultdict(list)
        self._overload_penalty = 0


    def calculate_assistants_assignments(self, chromosome: Chromosome) -> int:
        self.assistants_assignments.clear()
        for gene in chromosome.genes:
            self.assistants_assignments[gene.assistant].append(gene.group)
        return self.assistants_assignments
    
    def calculate_assistants_shifts(self, chromosome: Chromosome) -> int:
        self.assistants_shifts.clear()
        for gene in chromosome.genes:
            self.assistants_shifts[gene.assistant].append(gene.time_slot)
        return self.assistants_shifts
    
    def calculate_overload_penalty(self, chromosome: Chromosome) -> int:
        self._overload_penalty = 0
        self.calculate_assistants_assignments(chromosome)
        self.calculate_assistants_shifts(chromosome)
        for assistant , assignments in self.assistants_assignments.items():
            assignments_penalty = max(0, len(assignments) - self.max_groups_per_assistant)
            shift_penalty = (max(0, len(self.assistants_shifts[assistant]) - self.max_shift_per_assistant))
            self._overload_penalty += assignments_penalty + shift_penalty
        return self._overload_penalty
    
    def calculate_fitness(self, chromosome: Chromosome) -> int:
        if settings.DEBUG:
            logger.info(f"Calculating overload penalty for assistant distribution: {chromosome}")
        return self.calculate_overload_penalty(chromosome)

# %% [markdown]
# ##### 3. Maximize Participant Satisfaction:
# Maximize the satisfaction of participants by ensuring that each participant is assigned to a time slot that is available to them.
#
# Deskripsi:
# - Memaksimalkan kepuasan peserta dengan memastikan bahwa setiap peserta ditugaskan ke slot waktu yang tersedia untuk mereka.
#
# ```python

# %%
from collections import defaultdict

class ParticipantAvailability:
    def __init__(self, group_data: GroupData):
        self.group_data = group_data
        self.unsatified_participants = defaultdict(list)

    def calculate_unsatisfied_participants(self, chromosome: Chromosome):
        self.unsatified_participants.clear()
        unsatified_participants_count = 0
        for gene in chromosome.genes:
            participant_availability = group_data.get_group_schedule(gene.group)
            if not participant_availability[gene.time_slot.day][gene.time_slot.shift]:
                self.unsatified_participants[gene.group].append(gene.time_slot)
                unsatified_participants_count += 1
        return unsatified_participants_count
    
    def calculate_fitness(self, chromosome: Chromosome):
        if settings.DEBUG:
            logger.info(f"Calculating unsatisfied participants schedule for chromosome {chromosome}")
        return self.calculate_unsatisfied_participants(chromosome)

# %% [markdown]
# # Population Initialization

# %%
# import fitness_function

class Population:
    def __init__(self, chromosome, fitness_function):
        self.chromosome = chromosome
        self.fitness_function = fitness_function

    def __repr__(self):
        return f"Chromosome: {self.chromosome}, Fitness Function: {self.fitness_function}"
    
    def __str__(self):
        return f"Chromosome: {self.chromosome}, Fitness Function: {self.fitness_function}"
    
    def __len__(self):
        return len(self.chromosome)
    
    def calculate_fitness(self):
        for chromosome in self.chromosome:
            chromosome.fitness = self.fitness_function.calculate_fitness(chromosome)

# %% [markdown]
# # Helper Functions

# %% [markdown]
# ## Factory Method
#
# ```python

# %%
# Factory.py
import numpy as np
from math import ceil
from collections import namedtuple
from datetime import timedelta
# import LaboratoryData, ModuleData, GroupData, AssistantData, ChapterData
# import Constant, ConstraintChecker, Gene, Chromosome, Population

class Factory:
    def __init__(self, **kwargs):
        
        self.lab_data = kwargs.get("lab_data", LaboratoryData())
        self.module_data = kwargs.get("module_data", ModuleData())
        self.group_data = kwargs.get("group_data", GroupData())
        self.assistant_data = kwargs.get("assistant_data", AssistantData())
        self.chapter_data = kwargs.get("chapter_data", ChapterData())
        self.initialize()

    def initialize(self):
        # Caching data for faster access and less database query
        self.assistant_by_lab = defaultdict(list)
        for assistant in self.assistant_data.assistants:
            self.assistant_by_lab[assistant.laboratory.id].append(assistant.id)
            
        self.module_by_lab = defaultdict(list)
        for module in self.module_data.modules:
            self.module_by_lab[module.laboratory.id].append(module.id)

        self.group_by_module = defaultdict(list)
        for group in self.group_data.groups:
            self.group_by_module[group.module.id].append(group.id)

        self.chapter_by_module = defaultdict(list)
        for chapter in self.chapter_data.chapters:
            self.chapter_by_module[chapter.module.id].append(chapter.id)
            
        self.participant_by_group = defaultdict(list)
        for group in self.group_data.groups:
            for participant in self.group_data.participants(group.id):
                self.participant_by_group[group.id].append(participant.id)

    def create_time_slot(self, module_id):
        start = self.module_data.get_module(module_id).start_date
        end = self.module_data.get_module(module_id).end_date
        duration = (end - start).days + 1
        weeks_duration = ceil(duration / 7)
        week = np.random.randint(0, weeks_duration)
        day = np.random.choice(Constant.days)
        shift = np.random.choice(Constant.shifts)
        #date = start + timedelta(days=week*7 + Constant.days.index(day))
        date = start + timedelta(days=7 + Constant.days.index(day))
        return TimeSlot(date, day, shift)
    
    def create_time_slot_weekly(self, module_id, week):
        start = self.module_data.get_module(module_id).start_date
        day = np.random.choice(Constant.days)
        shift = np.random.choice(Constant.shifts)
        date = start + timedelta(days=week*7 + Constant.days.index(day))
        return TimeSlot(date, day, shift)

    # def generate_gene(self):
    #     while True:
    #         laboratory = np.random.choice(self.lab_data.laboratories)["id"]
    #         module = np.random.choice(self.lab_data.get_module(laboratory))["id"]
    #         module_chapter = np.random.choice(self.module_data.get_module_chapter(module))["id"]
    #         group = np.random.choice(self.module_data.get_group(module))["id"]
    #         assistant = np.random.choice(self.lab_data.get_assistant(laboratory))["id"]

    #         time_slot = self.create_time_slot(module_id=module)

    #         gene = Gene(laboratory, module, module_chapter, group, assistant, time_slot)
    #         constraint_checker = ConstraintChecker(gene)
    #         if constraint_checker.check():
    #             return gene

    def calculate_chromosome_length(self):
        chromosome_size = 0
        for module in self.module_data.modules:
            module_chapter_count = self.module_data.get_module_chapter(module.id).count()
            group_count = self.module_data.get_group(module.id).count()
            chromosome_size += module_chapter_count * group_count
        return chromosome_size
    
    def generate_chromosome(self):
        # if settings.DEBUG:
        #     logger.info("Generating chromosome...")
        genes = []
        for group in self.group_data.groups:
            for module in self.module_data.modules:
                if group.module.id == module.id:
                    # Start of weekly chapter generation
                    # Get weekly chapter duration
                    start = module.start_date
                    end = module.end_date
                    duration = (end - start).days + 1
                    weeks_duration = ceil(duration / 7)
                    chapter_count = module.chapters.count()
                    weekly_chapter_count = ceil(chapter_count / weeks_duration)
                    # Generate weekly chapter
                    for id in range(weekly_chapter_count):
                        laboratory_id = module.laboratory.id
                        module_id = module.id
                        module_chapter_id = id+1
                        group_id = group.id
                        assistant_id = np.random.choice(self.assistant_by_lab[laboratory_id])
                        time_slot = self.create_time_slot(module_id)
                        gene = Gene(laboratory_id, module_id, module_chapter_id, group_id, assistant_id, time_slot)
                        genes.append(gene)
                    # End of weekly chapter generation

                    # for chapter in module.chapters.all():
                    #     laboratory_id = module.laboratory.id
                    #     module_id = module.id
                    #     module_chapter_id = chapter.id
                    #     group_id = group.id
                    #     assistant_id = np.random.choice(self.assistant_by_lab[laboratory_id])
                    #     time_slot = self.create_time_slot(module_id)
                    #     gene = Gene(laboratory_id, module_id, module_chapter_id, group_id, assistant_id, time_slot)
                    #     genes.append(gene)

        chromosome = Chromosome(genes)
        return chromosome
            

    def generate_population(self, population_size):
        if settings.DEBUG:
            logger.info("Generating population...")
        chromosome = []
        for _ in range(population_size):
            if settings.DEBUG:
                logger.info(f"Generating chromosome {_+1}/{population_size}")
            chromosome.append(self.generate_chromosome())
        return Population(chromosome, None)

# %% [markdown]
# Test Factory

# %%
# #test Factory
factory = Factory()
settings.DEBUG = False
population = factory.generate_population(5)

# %%
# #count courses for each group
# def count_courses(population):
#     group_courses = defaultdict(list)
#     for chromosome in population.chromosome:
#         for gene in chromosome.genes:
#             group_courses[gene.group].append(gene.module_chapter)
#     return group_courses

# %%
# group_courses = count_courses(population)
# group_courses

# %%
# # test constraint checker
# # timer
# import time
# for chromosome in population.chromosome:
#     for gene in chromosome.genes:
#         constraint_checker = ConstraintChecker(gene)
#         start = time.time()
#         if not constraint_checker.check():
#             print(gene)
#             print(constraint_checker.check())
#         end = time.time()
#         print(f"Time taken for constraint checking: {end-start}")

# %% [markdown]
# ## Fitness Function
#
# ```python

# %%
class FitnessFunction:
    def __init__(self, all: bool = True):
        self.minimize_conflicts = None
        self.maximize_resource_utilization = None
        self.participant_availability = None
        self.all = all

        # MaximizeResourceUtilization Parameters
        self.max_groups_per_assistant = 2
        self.max_shift_per_assistant = 16

    def initialize(self):
        self.minimize_conflicts = MinimizeConflicts()
        self.maximize_resource_utilization = MaximizeResourceUtilization(self.max_groups_per_assistant, self.max_shift_per_assistant)
        self.participant_availability = ParticipantAvailability(GroupData())
    
    def calculate_all_fitness(self, chromosome: Chromosome):
        fitness = []
        fitness.append(self.minimize_conflicts.calculate_fitness(chromosome))
        fitness.append(self.maximize_resource_utilization.calculate_fitness(chromosome))
        fitness.append(self.participant_availability.calculate_fitness(chromosome))
        return sum(fitness)

    
    def calculate_fitness(self, chromosome: Chromosome):
        if settings.DEBUG:
            logger.info(f"Calculating fitness for chromosome {chromosome}")
        fitness = self.calculate_all_fitness(chromosome)
        return fitness

# %% [markdown]
# Test Fitness Function

# %%
#test FitnessFunction
factory = Factory()
population = factory.generate_population(10)
fitness_function = FitnessFunction()
population.fitness_function = fitness_function
fitness_function.initialize()

# %%
population.calculate_fitness()

# %%
for chromosome in population.chromosome:
    print(chromosome.fitness)
# Out:
# 150
# 144
# 150
# 150
# 145
# 149
# 152
# 146
# 157
# 150

# %% [markdown]
# ## Operator
#
# ```python

# %% [markdown]
# ### Genetic Operators
#
# ```python

# %% [markdown]
# #### Mutation
#
# ```python

# %%
from copy import deepcopy
from random import random, randint, choice
# import Factory, Chromosome, FitnessFunction

class Mutation:
    def __init__(self, mutation_rate: float = 0.1, mutation_size: int = 1, factory: Factory = Factory()):
        self.mutation_rate = mutation_rate
        self.mutation_size = mutation_size
        self.factory = factory


    def mutate(self, parent: Chromosome) -> Chromosome:
        if settings.DEBUG:
            logger.info("Mutating...")
        if random() < self.mutation_rate:
            chromosome = deepcopy(parent)
            for _ in range(self.mutation_size):
                mutation_point = self.mutation_point(parent)
                chromosome.genes[mutation_point].time_slot = self.factory.create_time_slot(chromosome.genes[mutation_point].module)
                chromosome.genes[mutation_point].assistant = choice(self.factory.assistant_by_lab[chromosome.genes[mutation_point].laboratory])
                if settings.DEBUG:
                    logger.info(f"Mutated chromosome: {chromosome}")
            return chromosome
        else:
            if settings.DEBUG:
                logger.info(f"Chromosome not mutated: {parent}")
            return parent
        
    def mutation_point(self, parent: Chromosome) -> int:
        return randint(0, len(parent.genes) - 1)

# %% [markdown]
# Test Mutation

# %%
# #test Mutation
# factory = Factory()
# population = factory.generate_population(1)
# fitness_function = FitnessFunction()
# population.fitness_function = fitness_function
# population.calculate_fitness()

# %%
# mutation = Mutation()
# mutation.mutate(population.chromosome[0])

# %% [markdown]
# #### Cross Over
#
# ```python

# %%
import logging
from copy import deepcopy
import numpy as np
class Crossover:
    def __init__(self, crossover_probability: float = 0.5, number_of_crossover_points: int = 1):

        self.crossover_probability = crossover_probability
        self.number_of_crossover_points = number_of_crossover_points
        

    def crossover(self, parent1: Chromosome, parent2: Chromosome) -> Chromosome:
        if settings.DEBUG:
            logger.info("Crossover...")

        if np.random.random() > self.crossover_probability:
            if settings.DEBUG:
                logger.info("No crossover")
            return parent1, parent2

        chromosome1 = deepcopy(parent1)
        chromosome2 = deepcopy(parent2)

        for _ in range(self.number_of_crossover_points):
            point = self.crossover_point(parent1)
            if settings.DEBUG:
                logger.info(f"Crossover point: {point}")
            chromosome1.genes[point], chromosome2.genes[point] = chromosome2.genes[point], chromosome1.genes[point] 
            if settings.DEBUG:
                logger.info(f"Chromosome 1: {chromosome1}")
                logger.info(f"Chromosome 2: {chromosome2}")


        return chromosome1, chromosome2
    
    def crossover_point(self, parent1: Chromosome):
        return np.random.randint(0, len(parent1.genes) - 1)

# %% [markdown]
# Test Cross Over

# %%
# #test Crossover
# factory = Factory()
# population = factory.generate_population(2)

# %%
# crossover = Crossover()
# a,b = crossover.crossover(population.chromosome[0], population.chromosome[1])

# %%
# import pandas as pd
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# # display population.chromosome[0].genes[0] on pandas dataframe
# data = []
# gene = population.chromosome[0].genes[158]
# data.append([gene.laboratory, gene.module, gene.module_chapter, gene.group, gene.assistant, gene.time_slot.date, gene.time_slot.day, gene.time_slot.shift])
# df = pd.DataFrame(data, columns=["Laboratory", "Module", "Module Chapter", "Group", "Assistant", "Date", "Day", "Shift"])
# df

# %%
# data2 = []
# gene2 = population.chromosome[1].genes[158]
# data2.append([gene2.laboratory, gene2.module, gene2.module_chapter, gene2.group, gene2.assistant, gene2.time_slot.date, gene2.time_slot.day, gene2.time_slot.shift])
# df2 = pd.DataFrame(data2, columns=["Laboratory", "Module", "Module Chapter", "Group", "Assistant", "Date", "Day", "Shift"])
# df2

# %%
# data3 = []
# gene3 = a.genes[158]
# data3.append([gene3.laboratory, gene3.module, gene3.module_chapter, gene3.group, gene3.assistant, gene3.time_slot.date, gene3.time_slot.day, gene3.time_slot.shift])
# df3 = pd.DataFrame(data3, columns=["Laboratory", "Module", "Module Chapter", "Group", "Assistant", "Date", "Day", "Shift"])
# df3

# %%
# data4 = []
# gene4 = b.genes[158]
# data4.append([gene4.laboratory, gene4.module, gene4.module_chapter, gene4.group, gene4.assistant, gene4.time_slot.date, gene4.time_slot.day, gene4.time_slot.shift])
# df4 = pd.DataFrame(data4, columns=["Laboratory", "Module", "Module Chapter", "Group", "Assistant", "Date", "Day", "Shift"])
# df4

# %% [markdown]
# #### Repair
#
# ```python

# %%
import time
class Repair:
    def __init__(self, factory: Factory = Factory()):
        self.factory = factory
        
    def repair(self, parent: Chromosome, max_iteration=100) -> Chromosome:
        if settings.DEBUG:
            logger.info("Repairing...")
            # count = 0
            # start = time.time()
        chromosome = deepcopy(parent)
        for index, gene in enumerate(chromosome.genes):
            constraint_checker = ConstraintChecker(gene)
            if not constraint_checker.schedule_constraint():
                # if settings.DEBUG:
                #     logger.info(f"Gene {index} is not feasible, repairing...")
                feasible_time_slot = self.find_feasible_solution(gene, max_iteration)
                gene.time_slot = feasible_time_slot
                # if settings.DEBUG:
                #     logger.info(f"Feasible time slot: {gene.time_slot}")
                #     count += 1
        # if settings.DEBUG:
        #     end = time.time()
        #     logger.info(f"Repaired {count} genes in {end-start} seconds")
        return chromosome
    
    def find_feasible_solution(self, gene, max_iteration=100):
        # if settings.DEBUG:
        #     logger.info("Finding feasible solution...")

        new_gene = deepcopy(gene)
        for _ in range(max_iteration):
            feasible_time_slot = self.factory.create_time_slot(gene.module)
            new_gene.time_slot = feasible_time_slot
            constraint_checker = ConstraintChecker(new_gene)
            if constraint_checker.schedule_constraint():
                # if settings.DEBUG:
                #     logger.info("Found!")
                return feasible_time_slot
            
        if settings.DEBUG:
            logger.info("No feasible solution found, returning random time slot")
        return self.factory.create_time_slot(gene.module)

# %% [markdown]
# Test Repair

# %%
# #test Repair
# factory = Factory()
# population = factory.generate_population(1)
# repair = Repair()
# z = repair.repair(population.chromosome[0])

# %%
# counter = 0
# for gene in z.genes:
#     constraint_checker = ConstraintChecker(gene)
#     if not constraint_checker.schedule_constraint():
#         print("not feasible")
#         counter += 1
# print(counter)

# %% [markdown]
# #### Selection
#
# ```python

# %%
import numpy as np
from copy import deepcopy
from collections import defaultdict

class Selection:
    '''
    Description:
    Selection class for selecting chromosomes from population
    Selection methods:
    1. Tournament selection
    2. Elitism selection
    3. Roulette selection
    '''
    def __init__(self, tournament_size: int = 3, elitism_size: int = 1, elitism_offset: int = 0, elitism_range: int = 1, elitism_probability: float = 0.5, method: str = "tournament"):
        self.tournament_size = tournament_size
        self.elitism_size = elitism_size
        self.elitism_offset = elitism_offset
        self.elitism_range = elitism_range
        self.elitism_probability = elitism_probability
        self.method = method
        
    def select(self, population: Population, method: str = None, **kwargs) -> Chromosome:
        method = method or self.method
        if settings.DEBUG:
            logger.info("Selecting...")
        if method == "tournament":
            return self.tournament_selection(population)
        elif method == "elitism":
            return self.elitism_selection(population)
        elif method == "roulette":
            return self.roulette_selection(population)
        else:
            raise ValueError("Invalid selection method")
    
    def elitism_selection(self, population: Population) -> Chromosome:
        if settings.DEBUG:
            logger.info("Elitism selection...")
        sorted_population = sorted(population.chromosome, key=lambda x: x.fitness)
        return sorted_population[self.elitism_offset:self.elitism_offset + self.elitism_range]
    
    def tournament_selection(self, population: Population) -> Chromosome:
        if settings.DEBUG:
            logger.info("Tournament selection...")
        selected_chromosome = []
        for _ in range(len(population.chromosome)):
            selected_chromosome.append(self.tournament_selection_helper(population))
        return selected_chromosome[0]
    
    def tournament_selection_helper(self, population: Population) -> Chromosome:
        tournament_population = np.random.choice(population.chromosome, self.tournament_size)
        sorted_population = sorted(tournament_population, key=lambda x: x.fitness)
        return sorted_population[0]
    
    def roulette_selection(self, population: Population) -> Chromosome:
        if settings.DEBUG:
            logger.info("Roulette selection...")
        fitness = [chromosome.fitness for chromosome in population.chromosome]
        total_fitness = sum(fitness)
        probabilities = [chromosome_fitness / total_fitness for chromosome_fitness in fitness]
        selected_chromosome = np.random.choice(population.chromosome, p=probabilities)
        return selected_chromosome

# %%
# # test Selection,
# factory = Factory()
# population = factory.generate_population(10)
# fitness_function = FitnessFunction()
# population.fitness_function = fitness_function
# population.calculate_fitness()

# %%
# for chromosome in population.chromosome:
#     print(chromosome.fitness)

# %% [markdown]
# Test Selection

# %%
# selection = Selection(method="elitism", elitism_offset=0, elitism_range=5, elitism_probability=0.5)
# a = selection.select(population)

# %%
# for chromosome in a:
#     print(chromosome.fitness)

# %%
#test Selection
# factory = Factory()
# population = factory.generate_population(2)
# population.chromosome[0].genes
# population.chromosome[1].genes
# selection = Selection(population, method="roulette")
# a = selection.select()

# %% [markdown]
# ### Genetic Algorithm
#
# ```python

# %%
from math import log


class GeneticAlgorithm:
    '''
    Description:
    Main class for genetic algorithm implementation
    '''
    def __init__(self, builder):
        # Dependency injection
        self.builder = builder
        self.population_size, self.max_generation = self.builder.get_population_parameters()
        self.mutation_rate, self.mutation_size = self.builder.get_mutations_parameters()
        self.crossover_probability, self.number_of_crossover_points = self.builder.get_crossover_parameters()
        self.fitness_function = self.builder.fitness_function
        self.factory = self.builder.factory
        self.mutation = self.builder.mutation
        self.crossover = self.builder.crossover
        self.selection = self.builder.selection
        self.repair = self.builder.repair
        self.logging = self.builder.logging
        # Results
        self._results = defaultdict(list)
        self._best_chromosome = None
        self._best_fitness = None
        self._best_generation = None
        self._best_chromosome_history = []
        self._best_fitness_history = []

    def show_config(self):
        if settings.DEBUG:
            logger.info("Showing configuration...")
        print(f"Population size: {self.population_size}")
        print(f"Max generation: {self.max_generation}")
        print(f"Mutation rate: {self.mutation_rate}")
        print(f"Mutation size: {self.mutation_size}")
        print(f"Crossover probability: {self.crossover_probability}")
        print(f"Number of crossover points: {self.number_of_crossover_points}")
        print(f"Fitness function: {self.fitness_function}")
        print(f"Logging: {self.logging}")
        return self

    def initialize_population(self):
        self.show_config()
        if settings.DEBUG:
            logger.info("Initializing population...")
        population = self.factory.generate_population(self.population_size)
        population.fitness_function = self.fitness_function
        population.calculate_fitness()
        return population
    
    def loggings(self, population):
        if settings.DEBUG:
            logger.info("Logging...")
        self._results["best_chromosome"].append(population.chromosome[0])
        self._results["best_fitness"].append(population.chromosome[0].fitness)
        self._results["average_fitness"].append(sum([chromosome.fitness for chromosome in population.chromosome]) / len(population.chromosome))
        self._results["worst_fitness"].append(population.chromosome[-1].fitness)
        self._best_chromosome_history.append(population.chromosome[0])
        self._best_fitness_history.append(population.chromosome[0].fitness)
        return self
    
    def evolve(self, population):
        if settings.DEBUG:
            logger.info("Evolving...")
        new_population = Population([], None)

        # Choose the best chromosome from the previous generation
        new_population.chromosome.extend(self.selection.select(population, method="elitism"))
        while len(new_population.chromosome) < self.population_size:
            parent1 = self.selection.select(population)
            parent2 = self.selection.select(population)
            child1, child2 = self.crossover.crossover(parent1, parent2)
            child1 = self.mutation.mutate(child1)
            child2 = self.mutation.mutate(child2)
            child2 = self.repair.repair(child2)
            child1 = self.repair.repair(child1)
            new_population.chromosome.extend([child1, child2])
        new_population.fitness_function = self.fitness_function
        new_population.calculate_fitness()
        if self.logging:
            self.loggings(new_population)

        return new_population
        

    def run(self):
        #if settings.DEBUG:
        logger.info("Running...")
        population = self.initialize_population()
        if self.logging:
            self.loggings(population)
        for generation in range(self.max_generation):
            #if settings.DEBUG:
            logger.info(f"Generation {generation}")
            start = time.time()
            population = self.evolve(population)
            logger.info(f"Population length: {len(population)}") 
            end = time.time()
            logger.info(f"Time taken for generation {generation}: {end-start}")
            if self.logging:
                self.loggings(population)
                logger.info(f"Best fitness: {self._results['best_fitness'][-1]}")
        self._best_chromosome = self._results["best_chromosome"][-1]
        self._best_fitness = self._results["best_fitness"][-1]
        self._best_generation = self._best_fitness_history.index(self._best_fitness)
        return self
    
    def get_results(self):
        return self._results
    
    def get_best_chromosome(self):
        return self._best_chromosome
    
    def get_best_fitness(self):
        return self._best_fitness
    
    def get_best_generation(self):
        return self._best_generation
    
    def get_best_chromosome_history(self):
        return self._best_chromosome_history
    
    def get_best_fitness_history(self):
        return self._best_fitness_history

# %% [markdown]
# #### Builder

# %%
from collections import defaultdict, namedtuple

class GeneticAlgorithmBuilder:
    '''
    Description:
    Genetic Algorithm Builder class for managing genetic algorithm parameters.
    '''
    def __init__(self):
        # Population parameters
        self.population_size = None
        self.max_generation = 10
        # Mutation parameters
        self.mutation_rate = 0.5
        self.mutation_size = 1
        # Crossover parameters
        self.crossover_probability = 0.5
        self.number_of_crossover_points = 1
        self.crossover = Crossover()
        # Selection parameters
        self.tournament_size = 3
        self.elitism_size = 1
        self.elitism_offset = 0
        self.elitism_range = 1
        self.elitism_probability = 0.5
        self.selection_method = "tournament"
        # Dependency injection
        # Fitness function
        self.fitness_function = FitnessFunction()
        # Factory
        self.factory = Factory()
        # Mutation
        self.mutation = Mutation()
        # Selection
        self.selection = Selection()
        # Repair
        self.repair = Repair()
        # Logging
        self.logging = False
        # Data
        self._lab_data = LaboratoryData()
        self._module_data = ModuleData()
        self._group_data = GroupData()
        self._assistant_data = AssistantData()
        self._chapter_data = ChapterData()

    
    
    def set_mutations_class(self, mutation):
        self.mutation = mutation
        return self

    def set_mutations(self, mutation_rate, mutation_size):
        """
        Set mutation parameters
        :param mutation_rate: Mutation rate, probability of mutation
        :type mutation_rate: float
        :param mutation_size: Number of genes to mutate
        :type mutation_size: int
        :return: self
        """
        self.mutation_rate = mutation_rate
        self.mutation_size = mutation_size
        return self
    
    def get_mutations_parameters(self):
        return self.mutation_rate, self.mutation_size
    
    def set_crossover_class(self, crossover):
        self.crossover = crossover
        return self
    
    def set_crossover(self, crossover_probability, number_of_crossover_points):
        """
        Set crossover parameters
        :param crossover_probability: Probability of crossover
        :type crossover_probability: float
        :param number_of_crossover_points: Number of points to crossover
        :type number_of_crossover_points: int
        :return: self"""

        self.crossover_probability = crossover_probability
        self.number_of_crossover_points = number_of_crossover_points
        return self
    
    def get_crossover_parameters(self):
        return self.crossover_probability, self.number_of_crossover_points
    
    def set_selection_class(self, selection):
        self.selection = selection
        return self
    
    def set_selection(self, selection_method, **kwargs):

        """
        Set selection parameters
        :param selection_method: Selection method, "tournament", "elitism" or "roulette"
        :type selection_method: str
        :param kwargs: Selection parameters, tournament_size, elitism_size, elitism_offset, elitism_range, elitism_probability
        :type kwargs: dict
        :param tournament_size: Number of chromosomes to select for tournament selection
        :type tournament_size: int
        :param elitism_size: Number of chromosomes to select for elitism selection
        :type elitism_size: int
        :param elitism_offset: Offset for elitism selection, position of the first chromosome to select
        :type elitism_offset: int
        :param elitism_range: Range for elitism selection, number of chromosomes to select from the offset
        :type elitism_range: int
        :param elitism_probability: Probability of selecting from the elitism selection
        :type elitism_probability: float
        :return: self
        """
        

        self.selection_method = selection_method
        if selection_method == "tournament":
            self.tournament_size = kwargs.get("tournament_size", 3)
        elif selection_method == "elitism":
            self.elitism_size = kwargs.get("elitism_size", 1)
            self.elitism_offset = kwargs.get("elitism_offset", 0)
            self.elitism_range = kwargs.get("elitism_range", 1)
            self.elitism_probability = kwargs.get("elitism_probability", 0.5)
        elif selection_method == "roulette":
            pass
        else:
            raise ValueError("Invalid selection method.")
        return self
    
    def get_selection_parameters(self):
        return self.tournament_size, self.elitism_size, self.elitism_offset, self.elitism_range, self.elitism_probability
    
    def set_population_parameters(self, population_size, max_generation):
        """
        Set population parameters
        :param population_size: Population size
        :type population_size: int
        :param max_generation: Maximum number of generation
        :type max_generation: int
        :return: self
        """
        self.population_size = population_size
        self.max_generation = max_generation
        return self
    
    def get_population_parameters(self):
        return self.population_size, self.max_generation
    
    def set_lab_data(self, lab_data: LaboratoryData):
        self._lab_data = lab_data
        return self
    
    def set_module_data(self, module_data: ModuleData):
        self._module_data = module_data
        return self
    
    def set_group_data(self, group_data: GroupData):
        self._group_data = group_data
        return self
    
    def set_assistant_data(self, assistant_data: AssistantData):
        self._assistant_data = assistant_data
        return self
    
    def set_chapter_data(self, chapter_data: ChapterData):
        self._chapter_data = chapter_data
        return self
    
    def initialize(self):
        self.mutation = Mutation(mutation_rate=self.mutation_rate, mutation_size=self.mutation_size, factory=self.factory)
        self.crossover = Crossover(crossover_probability=self.crossover_probability, number_of_crossover_points=self.number_of_crossover_points)
        self.selection = Selection(tournament_size=self.tournament_size, elitism_size=self.elitism_size, elitism_offset=self.elitism_offset, elitism_range=self.elitism_range, elitism_probability=self.elitism_probability, method = self.selection_method)
        self.repair = Repair(factory=self.factory)
        self.fitness_function.initialize()
        return self
    
    def build(self):
        """
        Build genetic algorithm
        :return: GeneticAlgorithm
        """
        self.initialize()
        return GeneticAlgorithm(self)

# %% [markdown]
# Test Genetic Algorithm

# %%
#test GeneticAlgorithm
builder = GeneticAlgorithmBuilder()
builder.set_population_parameters(population_size=10,
                                  max_generation=5)
builder.set_mutations(mutation_rate=0.7,
                      mutation_size=1)
builder.set_crossover(crossover_probability=0.7,
                      number_of_crossover_points=1)
builder.set_selection(selection_method="tournament",
                        tournament_size=3)

builder.fitness_function = FitnessFunction()
builder.fitness_function.max_groups_per_assistant = 15
builder.fitness_function.max_shift_per_assistant = 15
builder.logging = True
algorithm = builder.build()

# %%
import cProfile
cProfile.run("algorithm.run()", sort="tottime")
# Out:
# INFO:__main__:Running...
# Population size: 10
# Max generation: 5
# Mutation rate: 0.7
# Mutation size: 1
# Crossover probability: 0.7
# Number of crossover points: 1
# Fitness function: <__main__.FitnessFunction object at 0x0000019F7D2E0670>
# Logging: True
# INFO:__main__:Generation 0
# INFO:__main__:Population length: 11
# INFO:__main__:Time taken for generation 0: 31.943116426467896
# INFO:__main__:Best fitness: 82
# INFO:__main__:Generation 1
# INFO:__main__:Population length: 11
# INFO:__main__:Time taken for generation 1: 13.648922443389893
# INFO:__main__:Best fitness: 38
# INFO:__main__:Generation 2
# INFO:__main__:Population length: 11
# INFO:__main__:Time taken for generation 2: 12.420017004013062
# INFO:__main__:Best fitness: 38
# INFO:__main__:Generation 3
# INFO:__main__:Population length: 11
# INFO:__main__:Time taken for generation 3: 12.27732253074646
# INFO:__main__:Best fitness: 38
# INFO:__main__:Generation 4
# INFO:__main__:Population length: 11
# INFO:__main__:Time taken for generation 4: 10.409946203231812
# INFO:__main__:Best fitness: 38
#          46150635 function calls (44795974 primitive calls) in 89.329 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     54185   22.919    0.000   23.491    0.000 {method 'execute' of 'psycopg2.extensions.cursor' objects}
# 83554/54185    1.325    0.000    8.897    0.000 query.py:1361(build_filter)
#    127142    1.316    0.000   66.325    0.001 query.py:85(__iter__)
# 2118219/2053797    1.211    0.000    2.796    0.000 {built-in method builtins.getattr}
#     54185    1.136    0.000   23.427    0.000 compiler.py:725(as_sql)
#     54185    1.061    0.000    6.780    0.000 compiler.py:229(get_select)
#    113072    1.026    0.000    1.853    0.000 query.py:314(clone)
#     73317    0.958    0.000    1.876    0.000 base.py:460(__init__)
#    660351    0.863    0.000    1.499    0.000 compiler.py:519(quote_name_unless_alias)
# 480937/357628    0.795    0.000    8.191    0.000 compiler.py:541(compile)
# 2505481/2476323    0.766    0.000    1.175    0.000 {built-in method builtins.isinstance}
# 83554/54185    0.764    0.000   10.715    0.000 query.py:1556(_add_q)
#    137528    0.761    0.000    0.934    0.000 query.py:1652(names_to_path)
#     53825    0.728    0.000    2.384    0.000 compiler.py:950(get_default_columns)
#     54185    0.682    0.000   53.644    0.001 compiler.py:1532(execute_sql)
#    114152    0.658    0.000    2.549    0.000 copy.py:66(copy)
#   1948756    0.645    0.000    0.645    0.000 {built-in method builtins.hasattr}
#    107650    0.617    0.000    1.807    0.000 compiler.py:2093(<lambda>)
#     68764    0.617    0.000    1.372    0.000 query.py:1768(setup_joins)
#    524525    0.597    0.000    2.110    0.000 {method 'join' of 'str' objects}
#    303083    0.589    0.000    1.165    0.000 __init__.py:492(get_col)
#     54185    0.569    0.000    2.015    0.000 compiler.py:1483(get_converters)
#     64422    0.535    0.000    1.009    0.000 local.py:44(_get_context_id)
#    356908    0.530    0.000    0.707    0.000 __init__.py:615(__eq__)
# 311112/280874    0.528    0.000    0.628    0.000 deconstruct.py:15(__new__)
#     54195    0.520    0.000   66.891    0.001 query.py:1879(_fetch_all)
#     29369    0.518    0.000    0.518    0.000 decoder.py:343(raw_decode)
#    112712    0.515    0.000    2.884    0.000 query.py:1860(_clone)
#    303083    0.514    0.000    2.437    0.000 expressions.py:1130(as_sql)
# 295988/187618    0.485    0.000    5.128    0.000 functional.py:49(__get__)
#    234319    0.473    0.000    1.388    0.000 expressions.py:1146(get_db_converters)
#     54185    0.461    0.000    3.456    0.000 lookups.py:213(process_lhs)
#     68764    0.460    0.000    4.630    0.000 compiler.py:316(_order_by_pairs)
#    178303    0.457    0.000    0.801    0.000 query.py:294(__init__)
# 143280/114756    0.450    0.000    1.894    0.000 copy.py:259(_reconstruct)
#      9877    0.447    0.000   76.738    0.008 2213152367.py:117(get_group_schedule)
#    458694    0.445    0.000    0.445    0.000 tree.py:22(__init__)
#     20361    0.420    0.000    1.196    0.000 inspect.py:2280(_signature_from_function)
#    134014    0.411    0.000    0.601    0.000 {method '__reduce_ex__' of 'object' objects}
#     54185    0.411    0.000   15.946    0.000 compiler.py:78(pre_sql_setup)
# 197856/604    0.410    0.000    0.961    0.002 copy.py:128(deepcopy)
#     54185    0.400    0.000    0.866    0.000 query_utils.py:232(get_lookup)
#    162195    0.394    0.000    0.542    0.000 utils.py:22(__getattr__)
#     54185    0.385    0.000    0.385    0.000 {method 'cursor' of 'psycopg2.extensions.connection' objects}
# 162555/54185    0.382    0.000    3.051    0.000 asyncio.py:15(inner)
#    107650    0.381    0.000    0.435    0.000 {method 'fetchmany' of 'psycopg2.extensions.cursor' objects}
#    107650    0.380    0.000    2.331    0.000 compiler.py:2087(cursor_iter)
#     83554    0.372    0.000    0.728    0.000 query.py:2640(update_join_types)
# 40722/20361    0.366    0.000    2.090    0.000 inspect.py:2375(_signature_from_callable)
#     54185    0.361    0.000    7.272    0.000 compiler.py:70(setup_query)
#    289224    0.346    0.000    0.472    0.000 operations.py:199(quote_name)
# 1552587/1549707    0.337    0.000    0.438    0.000 {method 'get' of 'dict' objects}
#     73317    0.335    0.000    2.247    0.000 base.py:574(from_db)
#     54185    0.335    0.000    4.833    0.000 where.py:114(as_sql)
#     54185    0.334    0.000    2.621    0.000 query.py:1293(build_lookup)
#     54185    0.334    0.000    2.438    0.000 base.py:304(_cursor)
# 83703/69124    0.325    0.000    2.347    0.000 expressions.py:258(resolve_expression)
#    288864    0.325    0.000    0.571    0.000 utf_8.py:15(decode)
#     30449    0.324    0.000   43.752    0.001 related_descriptors.py:201(__get__)
#     20361    0.322    0.000    0.428    0.000 inspect.py:3050(_bind)
#    122589    0.317    0.000    0.924    0.000 query.py:1018(get_initial_alias)
#   1896798    0.310    0.000    0.310    0.000 {method 'append' of 'list' objects}
#    136757    0.310    0.000    0.617    0.000 related_descriptors.py:86(__set__)
#     29369    0.309    0.000   40.414    0.001 query.py:613(get)
#     54185    0.307    0.000    6.366    0.000 compiler.py:448(get_order_by)
#     20361    0.297    0.000    3.210    0.000 expressions.py:477(identity)
#     40722    0.297    0.000    0.400    0.000 inspect.py:2920(__init__)
#     54185    0.293    0.000   23.850    0.000 utils.py:82(_execute)
#     54185    0.288    0.000   11.181    0.000 query.py:1531(add_q)
#     54185    0.281    0.000    0.684    0.000 lookups.py:328(get_prep_lookup)
#   1152634    0.278    0.000    0.278    0.000 {method 'copy' of 'dict' objects}
#     54185    0.278    0.000    0.846    0.000 query.py:1222(solve_lookup_type)
#     83554    0.273    0.000    0.541    0.000 query_utils.py:48(__init__)
#     59720    0.268    0.000    0.463    0.000 query.py:1040(join)
#    162555    0.268    0.000    0.577    0.000 os.py:675(__getitem__)
#    138866    0.267    0.000    0.292    0.000 functional.py:291(__getattribute__)
# 351533/322164    0.267    0.000    1.128    0.000 {built-in method builtins.setattr}
#     53825    0.266    0.000    0.266    0.000 query.py:102(<listcomp>)
#     65591    0.266    0.000    0.344    0.000 query.py:231(__init__)
#     64422    0.265    0.000    1.538    0.000 local.py:99(__getattr__)
#      2351    0.265    0.000   10.131    0.004 2558330897.py:42(create_time_slot)
#    113072    0.259    0.000    0.535    0.000 where.py:209(clone)
#     68764    0.258    0.000    0.313    0.000 query.py:1893(trim_joins)
#     53825    0.258    0.000    2.345    0.000 compiler.py:1504(results_iter)
#     54185    0.255    0.000    1.882    0.000 query.py:296(get_compiler)
#    288864    0.247    0.000    0.247    0.000 {built-in method _codecs.utf_8_decode}
#    234679    0.246    0.000    0.385    0.000 expressions.py:463(select_format)
#     29369    0.241    0.000   42.993    0.001 related_descriptors.py:196(get_object)
#    112712    0.240    0.000    2.115    0.000 query.py:359(chain)
#     80364    0.240    0.000    0.403    0.000 inspect.py:2637(__init__)
#    171810    0.233    0.000    0.381    0.000 tree.py:28(create)
# 232759/124389    0.232    0.000    1.263    0.000 {built-in method builtins.any}
#    108010    0.230    0.000    0.716    0.000 utils.py:96(inner)
#     54185    0.228    0.000    0.228    0.000 datastructures.py:267(__init__)
#     29369    0.225    0.000    0.903    0.000 related.py:402(get_reverse_related_filter)
#     78641    0.221    0.000    1.176    0.000 related.py:1184(get_col)
#    409757    0.220    0.000    0.451    0.000 {built-in method builtins.all}
#     83554    0.219    0.000    0.462    0.000 query.py:2612(__init__)
#     43948    0.219    0.000    1.693    0.000 query.py:1653(order_by)
#    685378    0.218    0.000    3.079    0.000 query.py:310(query)
#   1133521    0.217    0.000    0.217    0.000 2213152367.py:125(<genexpr>)
#      9877    0.217    0.000   75.765    0.008 2213152367.py:101(participants)
#     54185    0.217    0.000    4.121    0.000 lookups.py:223(as_sql)
#    137739    0.216    0.000    0.277    0.000 tree.py:89(add)
#     54185    0.216    0.000    0.468    0.000 compiler.py:1106(get_from_clause)
# 968766/704440    0.212    0.000   32.028    0.000 {built-in method builtins.len}
#     54185    0.209    0.000   11.725    0.000 query.py:1457(_filter_or_exclude_inplace)
#    147976    0.208    0.000    0.208    0.000 {built-in method _abc._abc_instancecheck}
# 108370/54185    0.205    0.000    0.839    0.000 where.py:236(_contains_aggregate)
#     83554    0.201    0.000    0.243    0.000 __init__.py:565(__init__)
#     68404    0.201    0.000    0.245    0.000 related.py:1178(get_db_converters)
#    412796    0.198    0.000    0.198    0.000 {built-in method __new__ of type object at 0x00007FFD3E308EF0}
#    136757    0.196    0.000    0.303    0.000 mixins.py:21(is_cached)
#    137739    0.194    0.000    0.258    0.000 query.py:890(demote_joins)
#     54185    0.188    0.000   10.644    0.000 query.py:1446(_filter_or_exclude)
#     59458    0.183    0.000    1.301    0.000 compiler.py:1493(apply_converters)
#     54185    0.181    0.000    0.708    0.000 base.py:321(create_cursor)
#     54185    0.180    0.000    1.194    0.000 lookups.py:25(__init__)
#     54185    0.177    0.000    0.270    0.000 query.py:909(reset_refcounts)
#     65591    0.176    0.000    0.751    0.000 manager.py:150(get_queryset)
#     54185    0.176    0.000    2.040    0.000 lookups.py:98(process_lhs)
#     54185    0.174    0.000    0.558    0.000 __init__.py:798(db_type)
#    333172    0.173    0.000    0.173    0.000 {method 'startswith' of 'str' objects}
#    167108    0.171    0.000    0.453    0.000 __init__.py:640(update)
#     29369    0.170    0.000    0.299    0.000 related_descriptors.py:252(__set__)
#     43948    0.167    0.000    0.305    0.000 operations.py:250(limit_offset_sql)
#     10237    0.166    0.000    0.933    0.000 related_descriptors.py:665(_apply_rel_filters)
#    132806    0.166    0.000    0.426    0.000 copyreg.py:100(__newobj__)
#     64422    0.165    0.000    1.242    0.000 local.py:80(_get_storage)
#     10237    0.163    0.000    0.191    0.000 __init__.py:179(__init__)
#     29369    0.161    0.000    1.435    0.000 related_descriptors.py:152(get_queryset)
#     54185    0.161    0.000    0.447    0.000 query_utils.py:213(_get_lookup)
#    162555    0.159    0.000    0.310    0.000 os.py:747(encodekey)
#    343049    0.156    0.000    0.156    0.000 query.py:2482(extra_select)
#     54185    0.155    0.000    0.388    0.000 lookups.py:80(get_prep_lookup)
#     54185    0.155    0.000   24.005    0.000 utils.py:76(_execute_with_wrappers)
#     54185    0.153    0.000    0.229    0.000 lookups.py:242(get_db_prep_lookup)
#     54185    0.152    0.000    0.277    0.000 query.py:1769(db)
#     68404    0.151    0.000    0.187    0.000 expressions.py:1119(__init__)
#    303083    0.150    0.000    0.246    0.000 __init__.py:860(get_db_converters)
#     29369    0.149    0.000    0.838    0.000 decoder.py:332(decode)
# 108370/54185    0.148    0.000    0.602    0.000 where.py:246(_contains_over_clause)
#     54185    0.147    0.000    0.171    0.000 base.py:630(allow_thread_sharing)
#    182047    0.145    0.000    0.145    0.000 query.py:2101(is_sliced)
#     54185    0.144    0.000    0.167    0.000 query_utils.py:223(get_instance_lookups)
#    304898    0.143    0.000    0.143    0.000 query.py:305(get_meta)
#     14579    0.142    0.000   22.989    0.002 query.py:1050(first)
#     54185    0.141    0.000   24.146    0.000 utils.py:66(execute)
#     64422    0.140    0.000    0.195    0.000 __init__.py:2048(get_prep_value)
#     58738    0.140    0.000    0.140    0.000 {method 'match' of 're.Pattern' objects}
#     64422    0.138    0.000    0.155    0.000 utils.py:218(_route_db)
#     54185    0.138    0.000    4.273    0.000 lookups.py:343(as_sql)
#     20361    0.137    0.000    0.383    0.000 inspect.py:1959(_signature_bound_method)
#    133777    0.135    0.000    0.135    0.000 {method 'update' of 'dict' objects}
#     54185    0.134    0.000    0.722    0.000 base.py:293(_prepare_cursor)
#    564518    0.133    0.000    0.133    0.000 {method 'items' of 'dict' objects}
#    699260    0.133    0.000    0.133    0.000 {method 'extend' of 'list' objects}
#     84459    0.133    0.000    0.133    0.000 {built-in method builtins.sorted}
#     54185    0.130    0.000    0.358    0.000 __init__.py:781(db_type_parameters)
#     84783    0.129    0.000    0.186    0.000 expressions.py:185(__getstate__)
#    162555    0.128    0.000    0.705    0.000 _collections_abc.py:821(get)
#     64422    0.126    0.000    0.205    0.000 tasks.py:35(current_task)
#     84783    0.124    0.000    1.935    0.000 expressions.py:414(copy)
#     29369    0.121    0.000    1.111    0.000 json.py:86(from_db_value)
#     14579    0.120    0.000    0.256    0.000 expressions.py:1610(as_sql)
#     43948    0.118    0.000    0.225    0.000 query.py:2199(add_ordering)
#     54185    0.116    0.000    0.358    0.000 lookups.py:108(process_rhs)
#     54185    0.116    0.000    0.312    0.000 base.py:647(validate_thread_sharing)
#     54545    0.114    0.000    1.819    0.000 where.py:38(split_having_qualify)
#     20361    0.113    0.000    0.143    0.000 inspect.py:2840(apply_defaults)
#    108370    0.107    0.000    0.204    0.000 lookups.py:69(get_source_expressions)
#     54185    0.107    0.000    0.344    0.000 expressions.py:239(contains_aggregate)
#     30449    0.105    0.000    0.112    0.000 mixins.py:12(get_cached_value)
#    112712    0.104    0.000    2.988    0.000 query.py:1849(_chain)
#     64422    0.104    0.000    0.166    0.000 <frozen importlib._bootstrap>:404(parent)
#     64422    0.104    0.000    0.308    0.000 sync.py:545(get_current_task)
#     59720    0.103    0.000    0.117    0.000 query.py:818(table_alias)
#     54185    0.102    0.000    0.144    0.000 base.py:690(make_cursor)
#     54185    0.100    0.000    0.100    0.000 query_utils.py:206(__get__)
#    137528    0.099    0.000    0.099    0.000 options.py:660(get_field)
#    147976    0.099    0.000    0.306    0.000 abc.py:117(__instancecheck__)
#      9877    0.098    0.000   75.867    0.008 2213152367.py:110(get_participant_schedule)
#     14579    0.098    0.000    0.452    0.000 query.py:415(__getitem__)
#     29369    0.097    0.000    0.972    0.000 __init__.py:299(loads)
#     83554    0.096    0.000    0.096    0.000 {built-in method _collections._count_elements}
#     54185    0.096    0.000    0.096    0.000 compiler.py:46(__init__)
#     29369    0.095    0.000    0.234    0.000 query_utils.py:55(_combine)
#     54185    0.095    0.000   10.830    0.000 query.py:1430(filter)
#     14579    0.094    0.000    0.652    0.000 compiler.py:1026(find_ordering_name)
#     10237    0.094    0.000    1.196    0.000 related_descriptors.py:713(get_queryset)
#     29369    0.093    0.000    0.164    0.000 related.py:755(get_instance_value_for_fields)
#     53825    0.092    0.000    0.103    0.000 query.py:106(<listcomp>)
#    226977    0.091    0.000    0.091    0.000 {built-in method _asyncio.get_running_loop}
#     36020    0.089    0.000    0.143    0.000 hashable.py:4(make_hashable)
#     80364    0.089    0.000    0.120    0.000 enum.py:359(__call__)
#     10237    0.088    0.000    0.146    0.000 related_lookups.py:43(get_normalized_value)
#     83554    0.088    0.000    0.499    0.000 query.py:2633(add_votes)
#    108370    0.088    0.000    0.127    0.000 query.py:1280(check_filterable)
#     29369    0.088    0.000    0.826    0.000 manager.py:136(db_manager)
#     54185    0.086    0.000    0.111    0.000 compiler.py:1000(get_distinct)
#     39606    0.086    0.000    0.110    0.000 manager.py:21(__new__)
#     83554    0.086    0.000    0.086    0.000 query.py:853(promote_joins)
#     53825    0.085    0.000    0.105    0.000 query.py:2625(get_related_populators)
#     58738    0.085    0.000    0.102    0.000 mixins.py:24(set_cached_value)
#    216380    0.085    0.000    0.085    0.000 utils.py:70(__exit__)
#    196477    0.085    0.000    0.085    0.000 tree.py:63(__bool__)
#    108370    0.083    0.000    0.640    0.000 where.py:239(<genexpr>)
#    234319    0.083    0.000    0.083    0.000 query.py:1090(join_parent_model)
#    109352    0.081    0.000    0.081    0.000 related.py:1057(target_field)
#     88107    0.080    0.000    0.080    0.000 query_utils.py:164(__get__)
#     54185    0.079    0.000    0.079    0.000 operations.py:154(lookup_cast)
#    162555    0.079    0.000    0.104    0.000 os.py:741(check_str)
#    108370    0.078    0.000    0.078    0.000 compiler.py:71(<genexpr>)
#     58203    0.077    0.000    0.091    0.000 expressions.py:1160(__init__)
#     54185    0.077    0.000    0.943    0.000 expressions.py:379(get_lookup)
#     54185    0.076    0.000    0.915    0.000 where.py:242(contains_aggregate)
#     54185    0.076    0.000    0.101    0.000 datastructures.py:199(as_sql)
#     54185    0.076    0.000    0.076    0.000 lookups.py:230(get_rhs_op)
#      6502    0.076    0.000    0.076    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    225944    0.074    0.000    0.074    0.000 related.py:509(get_cache_name)
#     54185    0.074    0.000    0.240    0.000 expressions.py:245(contains_over_clause)
#     25985    0.073    0.000    0.087    0.000 manager.py:184(__get__)
#     57843    0.073    0.000    0.163    0.000 compiler.py:31(__init__)
#    108370    0.073    0.000    0.097    0.000 lookups.py:128(rhs_is_direct_value)
#     10237    0.073    0.000    0.400    0.000 related_lookups.py:152(get_prep_lookup)
#    146634    0.072    0.000    0.072    0.000 dispatcher.py:152(send)
#    207269    0.071    0.000    0.071    0.000 {built-in method builtins.iter}
#    108010    0.071    0.000    0.071    0.000 utils.py:93(__call__)
# 105540/104820    0.069    0.000    0.069    0.000 {built-in method builtins.hash}
#     54185    0.068    0.000    0.319    0.000 query.py:379(_get_col)
#    104028    0.068    0.000    0.068    0.000 {method 'pop' of 'list' objects}
#     65231    0.067    0.000    1.819    0.000 manager.py:157(all)
#     43948    0.067    0.000    0.067    0.000 query.py:2074(set_limits)
#     54185    0.066    0.000    0.120    0.000 query.py:1202(resolve_lookup_value)
#     14939    0.066    0.000    0.066    0.000 {method 'search' of 're.Pattern' objects}
#     83343    0.066    0.000    0.066    0.000 {method 'split' of 'str' objects}
#     54185    0.064    0.000    0.091    0.000 query.py:1958(_not_support_combined_queries)
#     27589    0.064    0.000    0.064    0.000 {method '__deepcopy__' of 'numpy.generic' objects}
#    108370    0.064    0.000    0.064    0.000 {method 'update' of 'set' objects}
#      5197    0.063    0.000    0.452    0.000 3432167734.py:10(__init__)
#     14579    0.063    0.000    0.196    0.000 compiler.py:1086(<listcomp>)
#     20361    0.063    0.000    0.097    0.000 inspect.py:612(unwrap)
#     64422    0.062    0.000    0.062    0.000 {method 'rpartition' of 'str' objects}
#    100725    0.061    0.000    0.078    0.000 inspect.py:2969(<genexpr>)
#    225054    0.061    0.000    0.061    0.000 {built-in method builtins.issubclass}
#     29369    0.061    0.000   31.873    0.001 query.py:379(__len__)
#     73106    0.060    0.000    0.060    0.000 query.py:845(ref_alias)
#    198935    0.060    0.000    0.060    0.000 {method 'pop' of 'dict' objects}
#     20361    0.060    0.000    0.093    0.000 inspect.py:66(get_annotations)
#     14579    0.060    0.000    0.318    0.000 compiler.py:1091(_setup_joins)
#     14579    0.060    0.000    0.215    0.000 query.py:1748(ordered)
#     10237    0.060    0.000    0.157    0.000 related_descriptors.py:641(__init__)
#    108370    0.059    0.000    0.463    0.000 where.py:249(<genexpr>)
#     64422    0.057    0.000    1.779    0.000 connection.py:56(__getitem__)
# 59643/58923    0.057    0.000    3.366    0.000 expressions.py:501(__hash__)
#     74659    0.057    0.000    0.057    0.000 query.py:849(unref_alias)
#     73317    0.057    0.000    0.057    0.000 base.py:440(__get__)
#     54185    0.056    0.000    2.494    0.000 base.py:327(cursor)
#    113072    0.055    0.000    0.055    0.000 {method 'copy' of 'set' objects}
#  9388/604    0.055    0.000    0.936    0.002 copy.py:227(_deepcopy_dict)
#     54185    0.055    0.000    0.055    0.000 {method 'close' of 'psycopg2.extensions.cursor' objects}
# 83703/69124    0.055    0.000    0.375    0.000 expressions.py:278(<listcomp>)
#    108370    0.054    0.000    0.054    0.000 expressions.py:241(<genexpr>)
#     10237    0.053    0.000    0.243    0.000 related_descriptors.py:604(__get__)
#     53825    0.053    0.000    0.053    0.000 compiler.py:1516(<listcomp>)
#     20361    0.053    0.000    2.143    0.000 inspect.py:2998(from_callable)
#     29369    0.052    0.000    0.216    0.000 related.py:749(get_local_related_value)
#     54185    0.052    0.000    0.654    0.000 where.py:252(contains_over_clause)
#     54185    0.052    0.000    0.132    0.000 base.py:183(queries_logged)
#    234679    0.052    0.000    0.052    0.000 __init__.py:507(select_format)
#    234679    0.052    0.000    0.052    0.000 operations.py:632(get_db_converters)
#     24826    0.051    0.000   35.141    0.001 query.py:383(__iter__)
#     54185    0.051    0.000    0.101    0.000 query.py:1257(check_related_objects)
#     38562    0.050    0.000    0.050    0.000 options.py:162(label)
#     10237    0.050    0.000    0.098    0.000 manager.py:27(__init__)
#    127327    0.050    0.000    0.050    0.000 expressions.py:181(__init__)
#     65623    0.050    0.000    0.069    0.000 copy.py:243(_keep_alive)
#     10237    0.049    0.000    0.350    0.000 __init__.py:2795(rel_db_type)
#     54185    0.049    0.000    0.049    0.000 query.py:796(get_select_mask)
#        65    0.048    0.001   35.524    0.547 1002078068.py:8(calculate_unsatisfied_participants)
#     54185    0.048    0.000    0.048    0.000 compiler.py:94(get_group_by)
#      5197    0.047    0.000   41.310    0.008 3432167734.py:41(schedule_constraint)
#     10237    0.047    0.000    0.047    0.000 manager.py:128(_set_creation_counter)
#    216380    0.047    0.000    0.047    0.000 utils.py:67(__enter__)
#    162555    0.047    0.000    0.047    0.000 {method 'upper' of 'str' objects}
#     54185    0.047    0.000    0.064    0.000 operations.py:363(compiler)
#     29369    0.047    0.000    0.097    0.000 tree.py:47(__copy__)
#     59720    0.047    0.000    0.066    0.000 query.py:1061(<listcomp>)
#     53825    0.046    0.000    0.046    0.000 query.py:47(__init__)
#     20361    0.046    0.000    2.188    0.000 inspect.py:3252(signature)
#     44308    0.045    0.000    0.045    0.000 query.py:2236(clear_ordering)
#    323082    0.044    0.000    0.044    0.000 {built-in method builtins.id}
#     54185    0.044    0.000    0.044    0.000 compiler.py:509(get_extra_select)
#    158928    0.043    0.000    0.046    0.000 {built-in method builtins.next}
#     55265    0.043    0.000    0.044    0.000 query.py:2462(annotation_select)
#     54185    0.043    0.000    0.043    0.000 utils.py:16(__init__)
#    108370    0.041    0.000    0.041    0.000 expressions.py:247(<genexpr>)
#     10237    0.041    0.000    0.054    0.000 related.py:779(get_joining_columns)
#     14579    0.041    0.000    0.047    0.000 expressions.py:1578(__init__)
#     87896    0.040    0.000    0.040    0.000 operations.py:253(<genexpr>)
#     20361    0.039    0.000    0.212    0.000 inspect.py:3014(replace)
# 96528/65106    0.039    0.000    0.352    0.000 copy.py:264(<genexpr>)
#    259653    0.039    0.000    0.039    0.000 inspect.py:2687(name)
#     54185    0.039    0.000    0.039    0.000 query.py:1542(<setcomp>)
#     64422    0.039    0.000    0.055    0.000 __init__.py:934(get_prep_value)
#     29369    0.038    0.000    0.038    0.000 options.py:715(get_ancestor_link)
#     43948    0.038    0.000    0.038    0.000 operations.py:242(_get_limit_offset_params)
#     29369    0.038    0.000    0.085    0.000 related.py:410(<listcomp>)
#      4702    0.037    0.000    9.735    0.002 2213152367.py:31(get_module)
#     29369    0.037    0.000    0.047    0.000 _json.py:159(typecast_json)
#     58527    0.037    0.000    0.037    0.000 query.py:267(base_table)
#     14579    0.037    0.000    0.118    0.000 query.py:1980(__instancecheck__)
#     54185    0.037    0.000    0.055    0.000 lookups.py:90(get_prep_lhs)
#     54185    0.036    0.000    0.036    0.000 base.py:588(close_if_health_check_failed)
#        10    0.034    0.003    3.975    0.398 2558330897.py:84(generate_chromosome)
#     80364    0.034    0.000    0.034    0.000 {method 'isidentifier' of 'str' objects}
#     29369    0.034    0.000    0.268    0.000 query_utils.py:71(__and__)
#     49483    0.034    0.000    0.034    0.000 datastructures.py:195(__init__)
#     14939    0.034    0.000    0.064    0.000 functional.py:264(inner)
#      6502    0.033    0.000    0.130    0.000 fromnumeric.py:71(_wrapreduction)
#    113050    0.033    0.000    0.033    0.000 {method 'add' of 'set' objects}
#     54185    0.033    0.000    0.034    0.000 query.py:1436(<setcomp>)
#        50    0.032    0.001   49.100    0.982 397601474.py:6(repair)
#       435    0.032    0.000    0.032    0.000 {method 'acquire' of '_thread.lock' objects}
#     10237    0.031    0.000    0.086    0.000 datastructures.py:45(__init__)
#     20361    0.031    0.000    0.459    0.000 inspect.py:3188(bind_partial)
#    222531    0.031    0.000    0.031    0.000 inspect.py:2699(kind)
#     64459    0.031    0.000    0.031    0.000 {method '__exit__' of '_thread.RLock' objects}
#     80364    0.031    0.000    0.031    0.000 enum.py:678(__new__)
#     40722    0.031    0.000    0.036    0.000 inspect.py:277(isfunction)
#     54185    0.030    0.000    0.030    0.000 base.py:284(ensure_connection)
#     40722    0.029    0.000    0.029    0.000 {method 'values' of 'mappingproxy' objects}
#     20474    0.029    0.000    0.034    0.000 base.py:653(_get_pk_val)
#     53825    0.028    0.000    0.028    0.000 {built-in method from_iterable}
#     29369    0.028    0.000    0.028    0.000 utils.py:240(allow_relation)
#     10237    0.027    0.000    1.127    0.000 related_lookups.py:170(as_sql)
#     54285    0.026    0.000    0.026    0.000 {built-in method _thread.get_ident}
#    115268    0.026    0.000    0.026    0.000 {built-in method builtins.callable}
#     87896    0.025    0.000    0.025    0.000 __init__.py:2792(get_internal_type)
#     14579    0.025    0.000    0.073    0.000 query.py:2071(is_empty)
#       482    0.024    0.000   20.309    0.042 397601474.py:27(find_feasible_solution)
#     54243    0.023    0.000    0.023    0.000 {method '__exit__' of '_thread.lock' objects}
#     29369    0.023    0.000    0.023    0.000 base.py:430(_base_manager)
#     29369    0.023    0.000    0.046    0.000 query.py:2108(can_filter)
#     10237    0.023    0.000    0.379    0.000 related.py:1162(db_type)
#     29158    0.022    0.000    0.022    0.000 query.py:2592(get_order_dir)
#     10237    0.022    0.000    0.045    0.000 query.py:1245(check_query_object_type)
#      5197    0.022    0.000    0.135    0.000 2213152367.py:3(__init__)
#     54185    0.022    0.000    0.022    0.000 base.py:529(validate_no_broken_transaction)
#     54185    0.022    0.000    0.022    0.000 __init__.py:2740(get_db_prep_value)
#     14579    0.021    0.000    0.029    0.000 query.py:1969(_check_ordering_first_last_queryset_aggregation)
#     69484    0.021    0.000    0.021    0.000 expressions.py:200(set_source_expressions)
#     10237    0.021    0.000    0.030    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#     14579    0.021    0.000    0.021    0.000 {method 'count' of 'str' objects}
#       360    0.021    0.000    0.584    0.002 query.py:384(get_aggregation)
#      9877    0.020    0.000    0.020    0.000 2213152367.py:122(<dictcomp>)
#     58738    0.019    0.000    0.019    0.000 {method 'end' of 're.Match' objects}
#       540    0.019    0.000    0.034    0.000 1255315854.py:49(tournament_selection_helper)
#      6502    0.018    0.000    0.148    0.000 fromnumeric.py:2979(prod)
#     70564    0.018    0.000    0.018    0.000 expressions.py:197(get_source_expressions)
#     14579    0.017    0.000    0.021    0.000 itercompat.py:1(is_iterable)
#     20361    0.017    0.000    0.017    0.000 {method 'items' of 'mappingproxy' objects}
#    122967    0.016    0.000    0.016    0.000 copy.py:182(_deepcopy_atomic)
#     14579    0.016    0.000    0.028    0.000 query.py:1813(final_transformer)
#     10237    0.016    0.000    0.043    0.000 related.py:1134(get_prep_value)
#     10237    0.016    0.000    0.016    0.000 __init__.py:927(get_internal_type)
#     54185    0.016    0.000    0.016    0.000 operations.py:215(field_cast_sql)
#     29158    0.015    0.000    0.028    0.000 query.py:2072(<genexpr>)
#      5197    0.015    0.000    0.070    0.000 2213152367.py:23(__init__)
#     10237    0.015    0.000    0.019    0.000 __init__.py:643(__hash__)
#     25985    0.014    0.000    0.014    0.000 options.py:415(swapped)
#     20474    0.014    0.000    0.014    0.000 related.py:781(<genexpr>)
#      5197    0.014    0.000    0.059    0.000 2213152367.py:50(__init__)
#     10237    0.013    0.000    0.020    0.000 query_utils.py:367(check_rel_lookup_compatibility)
#     10237    0.013    0.000    0.013    0.000 query.py:1916(<dictcomp>)
#     20361    0.013    0.000    0.013    0.000 inspect.py:2779(__init__)
#     10237    0.013    0.000    0.013    0.000 query.py:2573(is_nullable)
#     10237    0.013    0.000    0.021    0.000 query.py:1929(_add_hints)
#     20361    0.012    0.000    0.018    0.000 inspect.py:632(_is_wrapper)
#      5197    0.012    0.000    0.059    0.000 2213152367.py:85(__init__)
#      5197    0.012    0.000    0.058    0.000 2213152367.py:132(__init__)
#     61083    0.012    0.000    0.012    0.000 inspect.py:3006(parameters)
#     14579    0.011    0.000    0.011    0.000 expressions.py:1604(set_source_expressions)
#      9877    0.011    0.000    0.011    0.000 query.py:111(<listcomp>)
#       153    0.011    0.000    0.011    0.000 socket.py:545(send)
#        65    0.010    0.000    0.012    0.000 2174509031.py:8(calculate_conflicts)
#     20361    0.009    0.000    0.009    0.000 {built-in method sys.getrecursionlimit}
#     29369    0.009    0.000    0.009    0.000 base.py:283(<lambda>)
#     14600    0.009    0.000    0.009    0.000 {method 'rstrip' of 'str' objects}
#     29369    0.009    0.000    0.009    0.000 related.py:788(get_extra_descriptor_filter)
#     62163    0.009    0.000    0.009    0.000 inspect.py:2691(default)
#     26345    0.009    0.000    0.009    0.000 {method 'setdefault' of 'dict' objects}
#      6502    0.009    0.000    0.009    0.000 fromnumeric.py:72(<dictcomp>)
#     20474    0.008    0.000    0.008    0.000 query.py:1921(<genexpr>)
#     10237    0.008    0.000    0.012    0.000 datastructures.py:215(__eq__)
#     10237    0.008    0.000    0.008    0.000 query.py:1912(<setcomp>)
#     10237    0.007    0.000    0.007    0.000 query_utils.py:375(check)
#       122    0.007    0.000    0.853    0.007 copy.py:201(_deepcopy_list)
#     14579    0.007    0.000    0.007    0.000 expressions.py:1607(get_source_expressions)
#      9404    0.007    0.000    0.007    0.000 base.py:342(tzinfo_factory)
#     10237    0.006    0.000    0.006    0.000 {method 'issubset' of 'set' objects}
#     14939    0.006    0.000    0.006    0.000 operations.py:645(check_expression_support)
#      9266    0.006    0.000    0.006    0.000 {method '__reduce_ex__' of 'datetime.datetime' objects}
#     10237    0.005    0.000    0.007    0.000 datastructures.py:160(__eq__)
#       360    0.005    0.000    0.007    0.000 expressions.py:947(as_sql)
#      9877    0.005    0.000    0.005    0.000 {method 'keys' of 'dict' objects}
#     10597    0.005    0.000    0.005    0.000 __init__.py:2063(get_internal_type)
#     10237    0.005    0.000    0.005    0.000 query.py:1913(<setcomp>)
#      9266    0.004    0.000    0.004    0.000 __init__.py:447(__getnewargs__)
#       360    0.004    0.000    0.604    0.002 query.py:563(get_count)
#       360    0.004    0.000    0.771    0.002 manager.py:85(manager_method)
#         5    0.003    0.001   80.691   16.138 224259907.py:63(evolve)
#       360    0.003    0.000    0.720    0.002 query.py:597(count)
#   720/360    0.003    0.000    0.123    0.000 expressions.py:395(replace_expressions)
# 2160/1080    0.003    0.000    0.005    0.000 expressions.py:408(get_refs)
#      3071    0.003    0.000    0.003    0.000 {built-in method math.ceil}
#      6502    0.003    0.000    0.003    0.000 fromnumeric.py:2974(_prod_dispatcher)
#        65    0.003    0.000    0.003    0.000 491081120.py:12(calculate_assistants_assignments)
#       720    0.003    0.000    0.021    0.000 expressions.py:986(copy)
#       360    0.002    0.000    0.007    0.000 aggregates.py:167(__init__)
#      2352    0.002    0.000    0.002    0.000 {method 'index' of 'list' objects}
#       360    0.002    0.000    0.006    0.000 expressions.py:190(get_db_converters)
#       360    0.002    0.000    0.009    0.000 aggregates.py:114(as_sql)
#      1440    0.002    0.000    0.002    0.000 aggregates.py:50(get_source_expressions)
#       360    0.002    0.000    0.026    0.000 aggregates.py:60(resolve_expression)
#        65    0.002    0.000    0.002    0.000 491081120.py:18(calculate_assistants_shifts)
#       360    0.002    0.000    0.022    0.000 expressions.py:936(resolve_expression)
#        50    0.002    0.000    0.396    0.008 1117434174.py:12(mutate)
#       720    0.002    0.000    0.002    0.000 1277855371.py:5(__init__)
#       360    0.002    0.000    0.003    0.000 expressions.py:901(__init__)
#       360    0.002    0.000    0.006    0.000 query.py:1123(check_alias)
#        25    0.002    0.000    0.286    0.011 812580972.py:11(crossover)
#       360    0.001    0.000    0.002    0.000 expressions.py:350(convert_value)
#       360    0.001    0.000    0.004    0.000 aggregates.py:34(__init__)
#         1    0.001    0.001   89.398   89.398 224259907.py:88(run)
#        65    0.001    0.000    0.007    0.000 491081120.py:24(calculate_overload_penalty)
#       720    0.001    0.000    0.001    0.000 query.py:2387(set_annotation_mask)
#      2547    0.001    0.000    0.002    0.000 <string>:1(<lambda>)
#       360    0.001    0.000    0.001    0.000 {method 'fetchone' of 'psycopg2.extensions.cursor' objects}
#        19    0.001    0.000    0.001    0.000 812580972.py:35(crossover_point)
#       360    0.001    0.000    0.001    0.000 aggregates.py:56(set_source_expressions)
#   720/360    0.001    0.000    0.045    0.000 expressions.py:401(<listcomp>)
#        50    0.001    0.000    0.035    0.001 1255315854.py:41(tournament_selection)
#        58    0.001    0.000    0.043    0.001 iostream.py:547(flush)
#        21    0.001    0.000    0.002    0.000 __init__.py:283(__init__)
#       360    0.001    0.000    0.001    0.000 query.py:2097(clear_limits)
#        58    0.001    0.000    0.001    0.000 threading.py:236(__init__)
#        65    0.001    0.000   35.545    0.547 2059219220.py:17(calculate_all_fitness)
#       360    0.001    0.000    0.001    0.000 {method 'endswith' of 'str' objects}
#       153    0.001    0.000    0.012    0.000 iostream.py:243(schedule)
#       360    0.001    0.000    0.001    0.000 query.py:419(<dictcomp>)
#        58    0.001    0.000    0.034    0.001 threading.py:589(wait)
#      1440    0.001    0.000    0.001    0.000 expressions.py:930(get_source_expressions)
#        56    0.001    0.000    0.033    0.001 threading.py:288(wait)
#       360    0.000    0.000    0.001    0.000 expressions.py:204(<listcomp>)
#       360    0.000    0.000    0.001    0.000 expressions.py:203(_parse_expressions)
#       360    0.000    0.000    0.000    0.000 expressions.py:367(<lambda>)
#       211    0.000    0.000    0.001    0.000 threading.py:1169(is_alive)
#       360    0.000    0.000    0.000    0.000 query.py:544(<listcomp>)
#       114    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#       360    0.000    0.000    0.000    0.000 query.py:2473(<dictcomp>)
#        37    0.000    0.000    0.006    0.000 iostream.py:610(write)
#      1080    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#        65    0.000    0.000    0.013    0.000 2174509031.py:20(calculate_fitness)
#       360    0.000    0.000    0.000    0.000 query.py:406(<genexpr>)
#        21    0.000    0.000    0.001    0.000 ntpath.py:206(split)
#      1620    0.000    0.000    0.000    0.000 1255315854.py:51(<lambda>)
#        37    0.000    0.000    0.000    0.000 ansitowin32.py:260(convert_osc)
#        37    0.000    0.000    0.038    0.001 ansitowin32.py:208(write_plain_text)
#       195    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#       801    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       360    0.000    0.000    0.000    0.000 query.py:2395(append_annotation_mask)
#       720    0.000    0.000    0.000    0.000 query.py:548(<genexpr>)
#       360    0.000    0.000    0.000    0.000 2213152367.py:27(modules)
#         6    0.000    0.000   35.546    5.924 2172666981.py:17(calculate_fitness)
#        21    0.000    0.000    0.012    0.001 __init__.py:1077(flush)
#       211    0.000    0.000    0.000    0.000 threading.py:1102(_wait_for_tstate_lock)
#        68    0.000    0.000    0.000    0.000 random.py:239(_randbelow_with_getrandbits)
#         1    0.000    0.000   89.398   89.398 <string>:1(<module>)
#        65    0.000    0.000   35.545    0.547 2059219220.py:25(calculate_fitness)
#        65    0.000    0.000   35.524    0.547 1002078068.py:18(calculate_fitness)
#        21    0.000    0.000    0.001    0.000 __init__.py:1549(findCaller)
#       360    0.000    0.000    0.000    0.000 query.py:425(<genexpr>)
#        37    0.000    0.000    0.039    0.001 ansitowin32.py:192(write_and_convert)
#       360    0.000    0.000    0.000    0.000 hashable.py:12(<listcomp>)
#       360    0.000    0.000    0.000    0.000 expressions.py:1111(as_sql)
#        55    0.000    0.000    0.035    0.001 1255315854.py:22(select)
#       153    0.000    0.000    0.000    0.000 iostream.py:127(_event_pipe)
#        11    0.000    0.000    0.000    0.000 224259907.py:52(loggings)
#        58    0.000    0.000    0.001    0.000 threading.py:545(__init__)
#        21    0.000    0.000    0.035    0.002 __init__.py:1088(emit)
#        34    0.000    0.000    0.000    0.000 random.py:292(randrange)
#        65    0.000    0.000    0.007    0.000 491081120.py:34(calculate_fitness)
#        21    0.000    0.000    0.000    0.000 {built-in method _winapi.LCMapStringEx}
#       360    0.000    0.000    0.000    0.000 expressions.py:933(set_source_expressions)
#        56    0.000    0.000    0.000    0.000 threading.py:276(_acquire_restore)
#        21    0.000    0.000    0.035    0.002 __init__.py:1680(callHandlers)
#        21    0.000    0.000    0.000    0.000 ntpath.py:150(splitdrive)
#        74    0.000    0.000    0.000    0.000 {method 'finditer' of 're.Pattern' objects}
#        34    0.000    0.000    0.001    0.000 1117434174.py:29(mutation_point)
#        79    0.000    0.000    0.000    0.000 threading.py:1430(current_thread)
#       360    0.000    0.000    0.000    0.000 query.py:410(<genexpr>)
#        21    0.000    0.000    0.038    0.002 __init__.py:1600(_log)
#        21    0.000    0.000    0.038    0.002 __init__.py:1467(info)
#        37    0.000    0.000    0.006    0.000 iostream.py:532(_schedule_flush)
#        21    0.000    0.000    0.000    0.000 ntpath.py:51(normcase)
#        58    0.000    0.000    0.000    0.000 threading.py:267(__exit__)
#        37    0.000    0.000    0.039    0.001 ansitowin32.py:46(write)
#        21    0.000    0.000    0.000    0.000 genericpath.py:121(_splitext)
#        21    0.000    0.000    0.000    0.000 __init__.py:431(_format)
#        37    0.000    0.000    0.039    0.001 ansitowin32.py:175(write)
#        21    0.000    0.000    0.035    0.002 __init__.py:955(handle)
#        34    0.000    0.000    0.000    0.000 random.py:366(randint)
#        11    0.000    0.000    0.000    0.000 224259907.py:57(<listcomp>)
#       116    0.000    0.000    0.000    0.000 threading.py:1145(ident)
#        34    0.000    0.000    0.000    0.000 random.py:375(choice)
#        21    0.000    0.000    0.000    0.000 __init__.py:665(format)
#        21    0.000    0.000    0.000    0.000 ntpath.py:229(splitext)
#        21    0.000    0.000    0.002    0.000 __init__.py:1585(makeRecord)
#         1    0.000    0.000    0.016    0.016 224259907.py:30(show_config)
#        42    0.000    0.000    0.000    0.000 __init__.py:912(acquire)
#        76    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#        21    0.000    0.000    0.035    0.002 __init__.py:1626(handle)
#        42    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         8    0.000    0.000    0.016    0.002 {built-in method builtins.print}
#        58    0.000    0.000    0.000    0.000 threading.py:264(__enter__)
#         1    0.000    0.000   89.398   89.398 {built-in method builtins.exec}
#       209    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       211    0.000    0.000    0.000    0.000 threading.py:553(is_set)
#        37    0.000    0.000    0.000    0.000 iostream.py:505(_is_master_process)
#        21    0.000    0.000    0.000    0.000 __init__.py:932(format)
#        21    0.000    0.000    0.000    0.000 __init__.py:160(<lambda>)
#        21    0.000    0.000    0.000    0.000 __init__.py:1724(isEnabledFor)
#        42    0.000    0.000    0.000    0.000 __init__.py:919(release)
#         1    0.000    0.000    3.975    3.975 2558330897.py:125(generate_population)
#        56    0.000    0.000    0.000    0.000 threading.py:279(_is_owned)
#        63    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#        42    0.000    0.000    0.000    0.000 ansitowin32.py:28(__getattr__)
#        21    0.000    0.000    0.000    0.000 __init__.py:643(usesTime)
#        21    0.000    0.000    0.000    0.000 __init__.py:423(usesTime)
#        56    0.000    0.000    0.000    0.000 threading.py:273(_release_save)
#        42    0.000    0.000    0.000    0.000 __init__.py:806(filter)
#        95    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#        21    0.000    0.000    0.000    0.000 __init__.py:119(getLevelName)
#        21    0.000    0.000    0.001    0.000 ntpath.py:240(basename)
#        58    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#        50    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#        37    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        21    0.000    0.000    0.000    0.000 __init__.py:359(getMessage)
#       102    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#        43    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#        58    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        21    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#        21    0.000    0.000    0.000    0.000 __init__.py:438(format)
#        84    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#         5    0.000    0.000    0.000    0.000 1255315854.py:35(elitism_selection)
#        21    0.000    0.000    0.000    0.000 __init__.py:649(formatMessage)
#        21    0.000    0.000    0.000    0.000 threading.py:1129(name)
#        31    0.000    0.000    0.000    0.000 {built-in method time.time}
#        68    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#        21    0.000    0.000    0.000    0.000 ntpath.py:35(_get_bothseps)
#        21    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#        54    0.000    0.000    0.000    0.000 1255315854.py:38(<lambda>)
#         1    0.000    0.000    8.667    8.667 224259907.py:43(initialize_population)
#        43    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#        10    0.000    0.000    0.000    0.000 1412964167.py:7(__init__)
#        56    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 copyreg.py:109(_slotnames)
#         6    0.000    0.000    0.000    0.000 2172666981.py:4(__init__)
#        10    0.000    0.000    0.000    0.000 2213152367.py:89(groups)
#         1    0.000    0.000    0.000    0.000 __init__.py:219(_acquireLock)
#         1    0.000    0.000    0.000    0.000 __init__.py:1710(getEffectiveLevel)
#         5    0.000    0.000    0.000    0.000 2172666981.py:14(__len__)
#         1    0.000    0.000    0.000    0.000 __init__.py:228(_releaseLock)
#         1    0.000    0.000    0.000    0.000 __init__.py:1307(disable)
#         3    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
cProfile.run("algorithm.run()", sort="cumtime")
# Out:
# INFO:__main__:Running...
# Population size: 10
# Max generation: 25
# Mutation rate: 0.7
# Mutation size: 1
# Crossover probability: 0.7
# Number of crossover points: 1
# Fitness function: <__main__.FitnessFunction object at 0x00000122B3C9ABC0>
# Logging: True
# INFO:__main__:Generation 0
# INFO:__main__:Time taken for generation 0: 34.35796880722046
# INFO:__main__:Best fitness: 84
# INFO:__main__:Generation 1
# INFO:__main__:Time taken for generation 1: 14.001246213912964
# INFO:__main__:Best fitness: 38
# INFO:__main__:Generation 2
# INFO:__main__:Time taken for generation 2: 13.60663890838623
# INFO:__main__:Best fitness: 38
# INFO:__main__:Generation 3
# INFO:__main__:Time taken for generation 3: 9.577097415924072
# INFO:__main__:Best fitness: 38
# INFO:__main__:Generation 4
# INFO:__main__:Time taken for generation 4: 9.708483934402466
# INFO:__main__:Best fitness: 38
# INFO:__main__:Generation 5
# INFO:__main__:Time taken for generation 5: 9.321520805358887
# INFO:__main__:Best fitness: 38
# INFO:__main__:Generation 6
# INFO:__main__:Time taken for generation 6: 9.123462677001953
# INFO:__main__:Best fitness: 38
# INFO:__main__:Generation 7
# INFO:__main__:Time taken for generation 7: 9.539746046066284
# INFO:__main__:Best fitness: 37
# INFO:__main__:Generation 8
# INFO:__main__:Time taken for generation 8: 9.14809250831604
# INFO:__main__:Best fitness: 37
# INFO:__main__:Generation 9
# INFO:__main__:Time taken for generation 9: 9.748253107070923
# INFO:__main__:Best fitness: 37
# INFO:__main__:Generation 10
# INFO:__main__:Time taken for generation 10: 10.30260181427002
# INFO:__main__:Best fitness: 37
# INFO:__main__:Generation 11
# INFO:__main__:Time taken for generation 11: 9.088990449905396
# INFO:__main__:Best fitness: 37
# INFO:__main__:Generation 12
# INFO:__main__:Time taken for generation 12: 9.391903638839722
# INFO:__main__:Best fitness: 37
# INFO:__main__:Generation 13
# INFO:__main__:Time taken for generation 13: 9.572596549987793
# INFO:__main__:Best fitness: 37
# INFO:__main__:Generation 14
# INFO:__main__:Time taken for generation 14: 9.529676914215088
# INFO:__main__:Best fitness: 37
# INFO:__main__:Generation 15
# INFO:__main__:Time taken for generation 15: 9.168890476226807
# INFO:__main__:Best fitness: 37
# INFO:__main__:Generation 16
# INFO:__main__:Time taken for generation 16: 9.43608546257019
# INFO:__main__:Best fitness: 37
# INFO:__main__:Generation 17
# INFO:__main__:Time taken for generation 17: 9.905388593673706
# INFO:__main__:Best fitness: 37
# INFO:__main__:Generation 18
# INFO:__main__:Time taken for generation 18: 10.870670318603516
# INFO:__main__:Best fitness: 37
# INFO:__main__:Generation 19
# INFO:__main__:Time taken for generation 19: 9.66727352142334
# INFO:__main__:Best fitness: 37
# INFO:__main__:Generation 20
# INFO:__main__:Time taken for generation 20: 10.298346996307373
# INFO:__main__:Best fitness: 36
# INFO:__main__:Generation 21
# INFO:__main__:Time taken for generation 21: 9.601191997528076
# INFO:__main__:Best fitness: 36
# INFO:__main__:Generation 22
# INFO:__main__:Time taken for generation 22: 9.410361289978027
# INFO:__main__:Best fitness: 36
# INFO:__main__:Generation 23
# INFO:__main__:Time taken for generation 23: 10.027003765106201
# INFO:__main__:Best fitness: 36
# INFO:__main__:Generation 24
# INFO:__main__:Time taken for generation 24: 9.803152799606323
# INFO:__main__:Best fitness: 36
#          173529489 function calls (168121103 primitive calls) in 280.977 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000  281.200  281.200 {built-in method builtins.exec}
#         1    0.000    0.000  281.200  281.200 <string>:1(<module>)
#         1    0.010    0.010  281.200  281.200 3775596053.py:85(run)
#        25    0.018    0.001  274.192   10.968 3775596053.py:60(evolve)
#     40468    1.537    0.000  263.218    0.007 2213152367.py:117(get_group_schedule)
#     40468    0.369    0.000  260.120    0.006 2213152367.py:110(get_participant_schedule)
#     40468    0.712    0.000  259.736    0.006 2213152367.py:101(participants)
#    207317    1.617    0.000  209.467    0.001 query.py:1879(_fetch_all)
#    493739    4.267    0.000  207.705    0.000 query.py:85(__iter__)
#    207307    2.146    0.000  164.381    0.001 compiler.py:1532(execute_sql)
#    121393    1.096    0.000  149.294    0.001 related_descriptors.py:201(__get__)
#    120313    0.863    0.000  146.768    0.001 related_descriptors.py:196(get_object)
#       250    0.138    0.001  143.962    0.576 397601474.py:6(repair)
#    120313    1.118    0.000  137.834    0.001 query.py:613(get)
#     19948    0.169    0.000  132.284    0.007 3432167734.py:41(schedule_constraint)
#        26    0.001    0.000  131.382    5.053 2172666981.py:17(calculate_fitness)
#       285    0.001    0.000  131.381    0.461 2059219220.py:25(calculate_fitness)
#       285    0.003    0.000  131.379    0.461 2059219220.py:17(calculate_all_fitness)
#       285    0.001    0.000  131.293    0.461 1002078068.py:18(calculate_fitness)
#       285    0.189    0.001  131.292    0.461 1002078068.py:8(calculate_unsatisfied_participants)
# 3725053/2642236    0.719    0.000  108.090    0.000 {built-in method builtins.len}
#    120313    0.191    0.000  107.577    0.001 query.py:379(__len__)
#     87004    0.140    0.000  102.261    0.001 query.py:383(__iter__)
#    207307    3.631    0.000   73.390    0.000 compiler.py:725(as_sql)
#    207307    0.447    0.000   71.342    0.000 utils.py:66(execute)
#    207307    0.524    0.000   70.895    0.000 utils.py:76(_execute_with_wrappers)
#    207307    0.979    0.000   70.371    0.000 utils.py:82(_execute)
#    207307   67.333    0.000   69.188    0.000 {method 'execute' of 'psycopg2.extensions.cursor' objects}
#     46166    0.379    0.000   59.235    0.001 query.py:1050(first)
#    207307    1.357    0.000   48.715    0.000 compiler.py:78(pre_sql_setup)
#    207307    0.667    0.000   39.209    0.000 query.py:1457(_filter_or_exclude_inplace)
#    207307    0.987    0.000   37.465    0.000 query.py:1531(add_q)
# 327620/207307    2.563    0.000   35.894    0.000 query.py:1556(_add_q)
#    207307    0.309    0.000   35.480    0.000 query.py:1430(filter)
#    207307    0.602    0.000   34.906    0.000 query.py:1446(_filter_or_exclude)
# 327620/207307    4.404    0.000   30.039    0.000 query.py:1361(build_filter)
# 1800841/1339701    2.644    0.000   27.235    0.000 compiler.py:541(compile)
#       569    0.030    0.000   24.691    0.043 397601474.py:27(find_feasible_solution)
#    207307    1.208    0.000   24.061    0.000 compiler.py:70(setup_query)
#    207307    3.530    0.000   22.412    0.000 compiler.py:229(get_select)
#    207307    0.879    0.000   17.065    0.000 compiler.py:448(get_order_by)
#    207307    1.078    0.000   15.996    0.000 where.py:114(as_sql)
#    207307    0.452    0.000   14.186    0.000 lookups.py:343(as_sql)
# 1095177/680563    1.511    0.000   14.087    0.000 functional.py:49(__get__)
#    207307    0.723    0.000   13.676    0.000 lookups.py:223(as_sql)
#    253473    1.308    0.000   12.102    0.000 compiler.py:316(_order_by_pairs)
#    207307    1.460    0.000   11.458    0.000 lookups.py:213(process_lhs)
#      2849    0.313    0.000   11.178    0.004 2558330897.py:42(create_time_slot)
#      5698    0.042    0.000   10.701    0.002 2213152367.py:31(get_module)
#   2586350    0.675    0.000   10.639    0.000 query.py:310(query)
# 621921/207307    1.318    0.000   10.018    0.000 asyncio.py:15(inner)
#    419952    0.318    0.000    9.332    0.000 query.py:1849(_chain)
# 8025213/7777078    4.065    0.000    9.044    0.000 {built-in method builtins.getattr}
#    419952    1.662    0.000    9.014    0.000 query.py:1860(_clone)
#    207307    1.000    0.000    8.859    0.000 query.py:1293(build_lookup)
# 157392/156672    0.140    0.000    8.280    0.000 expressions.py:501(__hash__)
#   1132034    1.734    0.000    8.278    0.000 expressions.py:1130(as_sql)
#    421392    2.084    0.000    8.210    0.000 copy.py:66(copy)
#    207307    0.198    0.000    8.187    0.000 base.py:327(cursor)
#    207307    0.975    0.000    7.988    0.000 base.py:304(_cursor)
#     52944    0.716    0.000    7.889    0.000 expressions.py:477(identity)
#    206947    2.284    0.000    7.628    0.000 compiler.py:950(get_default_columns)
#    206947    0.775    0.000    7.488    0.000 compiler.py:1504(results_iter)
#    413894    1.349    0.000    7.480    0.000 compiler.py:2087(cursor_iter)
# 299999/253833    0.972    0.000    7.357    0.000 expressions.py:258(resolve_expression)
#    286792    0.996    0.000    7.250    0.000 base.py:574(from_db)
#   1966960    1.996    0.000    7.146    0.000 {method 'join' of 'str' objects}
# 557608/422570    1.509    0.000    6.886    0.000 copy.py:259(_reconstruct)
#         1    0.000    0.000    6.886    6.886 3775596053.py:40(initialize_population)
#    207307    0.581    0.000    6.804    0.000 lookups.py:98(process_lhs)
#    419952    0.729    0.000    6.567    0.000 query.py:359(chain)
#    207307    1.735    0.000    6.441    0.000 compiler.py:1483(get_converters)
#    260521    0.235    0.000    6.276    0.000 manager.py:157(all)
#    286792    3.147    0.000    6.139    0.000 base.py:460(__init__)
#    301079    0.404    0.000    6.071    0.000 expressions.py:414(copy)
#    207307    0.740    0.000    6.008    0.000 query.py:296(get_compiler)
#    207667    0.362    0.000    5.954    0.000 where.py:38(split_having_qualify)
#    420312    3.135    0.000    5.729    0.000 query.py:314(clone)
#    248135    0.179    0.000    5.618    0.000 connection.py:56(__getitem__)
#    413894    1.979    0.000    5.558    0.000 compiler.py:2093(<lambda>)
#     52944    0.108    0.000    5.434    0.000 inspect.py:3252(signature)
#     52944    0.135    0.000    5.326    0.000 inspect.py:2998(from_callable)
#    166479    0.701    0.000    5.323    0.000 query.py:1653(order_by)
# 105888/52944    0.899    0.000    5.191    0.000 inspect.py:2375(_signature_from_callable)
#   2471375    2.903    0.000    5.093    0.000 compiler.py:519(quote_name_unless_alias)
#    120313    0.519    0.000    4.924    0.000 related_descriptors.py:152(get_queryset)
#    248135    0.901    0.000    4.806    0.000 local.py:99(__getattr__)
#    241346    0.642    0.000    4.702    0.000 compiler.py:1493(apply_converters)
#    878561    1.520    0.000    4.532    0.000 expressions.py:1146(get_db_converters)
#    253473    1.996    0.000    4.444    0.000 query.py:1768(setup_joins)
#    207307    0.642    0.000    4.259    0.000 lookups.py:25(__init__)
# 876834/462220    0.742    0.000    4.087    0.000 {built-in method builtins.any}
#    120313    0.407    0.000    4.037    0.000 json.py:86(from_db_value)
#     40828    0.330    0.000    3.979    0.000 related_descriptors.py:713(get_queryset)
#     40828    0.095    0.000    3.853    0.000 related_lookups.py:170(as_sql)
# 941732/1178    1.626    0.000    3.810    0.003 copy.py:128(deepcopy)
#    248135    0.470    0.000    3.801    0.000 local.py:80(_get_storage)
#    293941    0.752    0.000    3.787    0.000 related.py:1184(get_col)
#   1132034    2.012    0.000    3.781    0.000 __init__.py:492(get_col)
# 1358722/1238409    0.863    0.000    3.776    0.000 {built-in method builtins.setattr}
# 45026/1178    0.223    0.000    3.767    0.003 copy.py:227(_deepcopy_dict)
# 9147543/9055211    2.450    0.000    3.726    0.000 {built-in method builtins.isinstance}
#       609    0.032    0.000    3.661    0.006 copy.py:201(_deepcopy_list)
#    120313    0.333    0.000    3.562    0.000 __init__.py:299(loads)
#    248135    1.704    0.000    3.183    0.000 local.py:44(_get_context_id)
#    120313    0.782    0.000    3.148    0.000 related.py:402(get_reverse_related_filter)
#    120313    0.550    0.000    3.088    0.000 decoder.py:332(decode)
#    207307    0.256    0.000    3.075    0.000 expressions.py:379(get_lookup)
#     40828    0.564    0.000    3.072    0.000 related_descriptors.py:665(_apply_rel_filters)
#    460420    1.037    0.000    3.048    0.000 query.py:1018(get_initial_alias)
#     52944    1.067    0.000    2.999    0.000 inspect.py:2280(_signature_from_function)
#    506946    2.412    0.000    2.979    0.000 query.py:1652(names_to_path)
#    207307    0.228    0.000    2.949    0.000 where.py:242(contains_aggregate)
#    120313    0.281    0.000    2.824    0.000 manager.py:136(db_manager)
#    207307    1.334    0.000    2.820    0.000 query_utils.py:232(get_lookup)
#    207307    0.898    0.000    2.751    0.000 query.py:1222(solve_lookup_type)
# 414614/207307    0.686    0.000    2.721    0.000 where.py:236(_contains_aggregate)
#    680833    1.556    0.000    2.708    0.000 query.py:294(__init__)
#    260881    0.592    0.000    2.602    0.000 manager.py:150(get_queryset)
#         1    0.000    0.000    2.583    2.583 2558330897.py:125(generate_population)
#        10    0.022    0.002    2.583    0.258 2558330897.py:84(generate_chromosome)
#    327620    1.287    0.000    2.513    0.000 query.py:2640(update_join_types)
#    207307    0.435    0.000    2.397    0.000 base.py:293(_prepare_cursor)
#    207307    1.032    0.000    2.360    0.000 lookups.py:328(get_prep_lookup)
#    207307    0.604    0.000    2.345    0.000 base.py:321(create_cursor)
#    621921    0.417    0.000    2.322    0.000 _collections_abc.py:821(get)
#   1338981    1.700    0.000    2.274    0.000 __init__.py:615(__eq__)
#    207307    0.170    0.000    2.187    0.000 where.py:252(contains_over_clause)
#    414254    0.789    0.000    2.134    0.000 utils.py:96(inner)
#   7325020    2.122    0.000    2.122    0.000 {built-in method builtins.hasattr}
#    414614    0.279    0.000    2.068    0.000 where.py:239(<genexpr>)
# 1057749/964337    1.726    0.000    2.052    0.000 deconstruct.py:15(__new__)
#    533116    1.035    0.000    2.048    0.000 related_descriptors.py:86(__set__)
# 414614/207307    0.475    0.000    2.017    0.000 where.py:246(_contains_over_clause)
#    120313    1.944    0.000    1.944    0.000 decoder.py:343(raw_decode)
#    513191    1.269    0.000    1.926    0.000 {method '__reduce_ex__' of 'object' objects}
#    621921    0.894    0.000    1.906    0.000 os.py:675(__getitem__)
#       250    0.008    0.000    1.878    0.008 1117434174.py:12(mutate)
#    207307    0.568    0.000    1.857    0.000 __init__.py:798(db_type)
#   1086228    1.038    0.000    1.855    0.000 utf_8.py:15(decode)
#     46166    0.254    0.000    1.846    0.000 compiler.py:1026(find_ordering_name)
#    327620    0.914    0.000    1.781    0.000 query_utils.py:48(__init__)
#    327620    0.299    0.000    1.693    0.000 query.py:2633(add_votes)
#    621561    1.190    0.000    1.675    0.000 utils.py:22(__getattr__)
#   1086588    1.198    0.000    1.649    0.000 operations.py:199(quote_name)
#   1664155    0.779    0.000    1.632    0.000 {built-in method builtins.all}
#    420312    0.798    0.000    1.605    0.000 where.py:209(clone)
#    242437    0.895    0.000    1.582    0.000 query.py:1040(join)
#    414614    0.210    0.000    1.554    0.000 where.py:249(<genexpr>)
#    207307    0.716    0.000    1.532    0.000 compiler.py:1106(get_from_clause)
#    655240    0.568    0.000    1.525    0.000 __init__.py:640(update)
#     19948    0.193    0.000    1.481    0.000 3432167734.py:10(__init__)
#    510835    0.555    0.000    1.459    0.000 copyreg.py:100(__newobj__)
#   1784366    1.440    0.000    1.440    0.000 tree.py:22(__init__)
#    327620    0.632    0.000    1.428    0.000 query.py:2612(__init__)
#    207307    0.515    0.000    1.426    0.000 query_utils.py:213(_get_lookup)
#     40828    0.255    0.000    1.408    0.000 related_lookups.py:152(get_prep_lookup)
# 452456/312137    0.154    0.000    1.388    0.000 copy.py:264(<genexpr>)
#     40828    0.080    0.000    1.320    0.000 related.py:1162(db_type)
#    878921    0.823    0.000    1.281    0.000 expressions.py:463(select_format)
#    207307    0.519    0.000    1.274    0.000 lookups.py:80(get_prep_lookup)
#    207307    1.231    0.000    1.231    0.000 {method 'cursor' of 'psycopg2.extensions.connection' objects}
#    660938    0.779    0.000    1.227    0.000 tree.py:28(create)
#     40828    0.171    0.000    1.223    0.000 __init__.py:2795(rel_db_type)
#     46166    0.257    0.000    1.221    0.000 query.py:415(__getitem__)
#    207307    0.435    0.000    1.200    0.000 __init__.py:781(db_type_parameters)
#    207307    0.385    0.000    1.189    0.000 lookups.py:108(process_rhs)
#    413894    1.010    0.000    1.184    0.000 {method 'fetchmany' of 'psycopg2.extensions.cursor' objects}
# 6156761/6153881    1.097    0.000    1.166    0.000 {method 'get' of 'dict' objects}
#    260881    0.919    0.000    1.152    0.000 query.py:231(__init__)
#    207307    0.364    0.000    1.136    0.000 expressions.py:239(contains_aggregate)
#     52944    0.077    0.000    1.116    0.000 inspect.py:3188(bind_partial)
# 299999/253833    0.161    0.000    1.100    0.000 expressions.py:278(<listcomp>)
#    253473    0.884    0.000    1.084    0.000 query.py:1893(trim_joins)
#       125    0.006    0.000    1.078    0.009 812580972.py:11(crossover)
#    120313    0.594    0.000    1.071    0.000 related_descriptors.py:252(__set__)
#    207307    0.213    0.000    1.062    0.000 query.py:379(_get_col)
#    166479    0.587    0.000    1.045    0.000 operations.py:250(limit_offset_sql)
#     52944    0.793    0.000    1.039    0.000 inspect.py:3050(_bind)
#    207307    0.401    0.000    1.033    0.000 base.py:647(validate_thread_sharing)
#    210696    0.598    0.000    1.017    0.000 inspect.py:2637(__init__)
#    621921    0.507    0.000    1.012    0.000 os.py:747(encodekey)
#    533116    0.648    0.000    1.010    0.000 mixins.py:21(is_cached)
#    510534    0.882    0.000    1.008    0.000 functional.py:291(__getattribute__)
#    575755    0.318    0.000    1.003    0.000 abc.py:117(__instancecheck__)
#   6983908    0.989    0.000    0.989    0.000 {method 'append' of 'list' objects}
#    105888    0.717    0.000    0.977    0.000 inspect.py:2920(__init__)
#    248135    0.325    0.000    0.949    0.000 sync.py:545(get_current_task)
#   4286216    0.949    0.000    0.949    0.000 {method 'copy' of 'dict' objects}
#     52944    0.341    0.000    0.943    0.000 inspect.py:1959(_signature_bound_method)
#    120313    0.110    0.000    0.942    0.000 query_utils.py:71(__and__)
#    207307    0.609    0.000    0.930    0.000 query.py:909(reset_refcounts)
#    534927    0.711    0.000    0.918    0.000 tree.py:89(add)
#    207307    0.503    0.000    0.918    0.000 query.py:1769(db)
#    534927    0.670    0.000    0.892    0.000 query.py:890(demote_joins)
#     46166    0.157    0.000    0.873    0.000 compiler.py:1091(_setup_joins)
#    207307    0.251    0.000    0.838    0.000 expressions.py:245(contains_over_clause)
#    120313    0.330    0.000    0.832    0.000 query_utils.py:55(_combine)
#   4643733    0.824    0.000    0.824    0.000 2213152367.py:125(<genexpr>)
#   1086228    0.817    0.000    0.817    0.000 {built-in method _codecs.utf_8_decode}
#    253113    0.674    0.000    0.816    0.000 related.py:1178(get_db_converters)
#    327620    0.665    0.000    0.796    0.000 __init__.py:565(__init__)
#   1132034    0.492    0.000    0.789    0.000 __init__.py:860(get_db_converters)
#    206947    0.789    0.000    0.789    0.000 query.py:102(<listcomp>)
#     40828    0.161    0.000    0.773    0.000 related_descriptors.py:604(__get__)
#     46166    0.372    0.000    0.766    0.000 expressions.py:1610(as_sql)
#    207307    0.765    0.000    0.765    0.000 datastructures.py:267(__init__)
#    207307    0.503    0.000    0.763    0.000 lookups.py:242(get_db_prep_lookup)
#    120313    0.167    0.000    0.712    0.000 related.py:749(get_local_related_value)
#    575755    0.685    0.000    0.685    0.000 {built-in method _abc._abc_instancecheck}
#    414614    0.351    0.000    0.673    0.000 lookups.py:69(get_source_expressions)
#     40828    0.565    0.000    0.668    0.000 __init__.py:179(__init__)
#    166479    0.360    0.000    0.667    0.000 query.py:2199(add_ordering)
#    248135    0.460    0.000    0.644    0.000 __init__.py:2048(get_prep_value)
#    301079    0.445    0.000    0.638    0.000 expressions.py:185(__getstate__)
#    248135    0.380    0.000    0.625    0.000 tasks.py:35(current_task)
#   1481972    0.623    0.000    0.623    0.000 {built-in method __new__ of type object at 0x00007FFA5E4F8EF0}
#   1253067    0.616    0.000    0.616    0.000 {method 'startswith' of 'str' objects}
#     46166    0.192    0.000    0.589    0.000 compiler.py:1086(<listcomp>)
#     46166    0.172    0.000    0.573    0.000 query.py:1748(ordered)
#    207307    0.476    0.000    0.551    0.000 base.py:630(allow_thread_sharing)
#    253113    0.434    0.000    0.549    0.000 expressions.py:1119(__init__)
#    120313    0.295    0.000    0.545    0.000 related.py:755(get_instance_value_for_fields)
#    248135    0.328    0.000    0.530    0.000 <frozen importlib._bootstrap>:404(parent)
#    207307    0.441    0.000    0.529    0.000 query_utils.py:223(get_instance_lookups)
#     40828    0.304    0.000    0.516    0.000 related_lookups.py:43(get_normalized_value)
#    248135    0.462    0.000    0.515    0.000 utils.py:218(_route_db)
#   1293535    0.515    0.000    0.515    0.000 query.py:2482(extra_select)
#       360    0.003    0.000    0.509    0.001 manager.py:85(manager_method)
#     52944    0.093    0.000    0.505    0.000 inspect.py:3014(replace)
#     40828    0.181    0.000    0.501    0.000 related_descriptors.py:641(__init__)
#    414614    0.297    0.000    0.493    0.000 query.py:1280(check_filterable)
#    240626    0.487    0.000    0.487    0.000 {method 'match' of 're.Pattern' objects}
#    207307    0.198    0.000    0.486    0.000 base.py:183(queries_logged)
#       360    0.002    0.000    0.477    0.001 query.py:597(count)
#   1163277    0.467    0.000    0.467    0.000 query.py:305(get_meta)
#    701766    0.465    0.000    0.465    0.000 query.py:2101(is_sliced)
#   2165758    0.453    0.000    0.453    0.000 {method 'items' of 'dict' objects}
#    330745    0.444    0.000    0.445    0.000 {built-in method builtins.sorted}
#    207307    0.301    0.000    0.443    0.000 base.py:690(make_cursor)
#     19948    0.074    0.000    0.436    0.000 2213152367.py:3(__init__)
#    207307    0.433    0.000    0.433    0.000 compiler.py:46(__init__)
#    507246    0.432    0.000    0.432    0.000 {method 'update' of 'dict' objects}
#   2660371    0.431    0.000    0.431    0.000 {method 'extend' of 'list' objects}
#    242437    0.367    0.000    0.418    0.000 query.py:818(table_alias)
#    155592    0.184    0.000    0.410    0.000 compiler.py:31(__init__)
#    161141    0.312    0.000    0.399    0.000 manager.py:21(__new__)
#       360    0.003    0.000    0.398    0.001 query.py:563(get_count)
#    121393    0.366    0.000    0.389    0.000 mixins.py:12(get_cached_value)
#       360    0.013    0.000    0.384    0.001 query.py:384(get_aggregation)
#    100190    0.230    0.000    0.373    0.000 hashable.py:4(make_hashable)
#    207307    0.288    0.000    0.368    0.000 compiler.py:1000(get_distinct)
#    206947    0.326    0.000    0.367    0.000 query.py:106(<listcomp>)
#    120313    0.171    0.000    0.353    0.000 tree.py:47(__copy__)
#    207307    0.210    0.000    0.353    0.000 query.py:1202(resolve_lookup_value)
#    206947    0.290    0.000    0.352    0.000 query.py:2625(get_related_populators)
#    621921    0.262    0.000    0.348    0.000 os.py:741(check_str)
#    506946    0.342    0.000    0.342    0.000 options.py:660(get_field)
#    207307    0.160    0.000    0.336    0.000 query.py:1257(check_related_objects)
#     52944    0.259    0.000    0.331    0.000 inspect.py:2840(apply_defaults)
#    207307    0.325    0.000    0.325    0.000 query_utils.py:206(__get__)
#    414614    0.247    0.000    0.322    0.000 lookups.py:128(rhs_is_direct_value)
#     40828    0.156    0.000    0.319    0.000 manager.py:27(__init__)
#    327620    0.319    0.000    0.319    0.000 {built-in method _collections._count_elements}
#    120313    0.145    0.000    0.316    0.000 related.py:410(<listcomp>)
#    207307    0.242    0.000    0.313    0.000 datastructures.py:199(as_sql)
#    240626    0.255    0.000    0.311    0.000 mixins.py:24(set_cached_value)
#    210696    0.226    0.000    0.305    0.000 enum.py:359(__call__)
#     99740    0.256    0.000    0.298    0.000 manager.py:184(__get__)
#     40828    0.111    0.000    0.297    0.000 datastructures.py:45(__init__)
#    870056    0.296    0.000    0.296    0.000 {built-in method _asyncio.get_running_loop}
#     46166    0.094    0.000    0.293    0.000 query.py:1980(__instancecheck__)
#    327620    0.290    0.000    0.290    0.000 query.py:853(promote_joins)
#    360939    0.288    0.000    0.288    0.000 query_utils.py:164(__get__)
#    775553    0.286    0.000    0.286    0.000 tree.py:63(__bool__)
#    310452    0.201    0.000    0.283    0.000 copy.py:243(_keep_alive)
#    207307    0.191    0.000    0.265    0.000 query.py:1958(_not_support_combined_queries)
#    129779    0.264    0.000    0.264    0.000 {method '__deepcopy__' of 'numpy.generic' objects}
#    878561    0.264    0.000    0.264    0.000 query.py:1090(join_parent_model)
#    414614    0.262    0.000    0.262    0.000 compiler.py:71(<genexpr>)
#    828868    0.258    0.000    0.258    0.000 utils.py:70(__exit__)
#    207307    0.258    0.000    0.258    0.000 lookups.py:230(get_rhs_op)
#    207307    0.251    0.000    0.251    0.000 {method 'close' of 'psycopg2.extensions.cursor' objects}
#    895135    0.251    0.000    0.251    0.000 related.py:509(get_cache_name)
#    207307    0.250    0.000    0.250    0.000 operations.py:154(lookup_cast)
#     19948    0.047    0.000    0.245    0.000 2213152367.py:23(__init__)
#    207307    0.129    0.000    0.245    0.000 lookups.py:90(get_prep_lhs)
#     52944    0.153    0.000    0.238    0.000 inspect.py:612(unwrap)
#    573584    0.236    0.000    0.236    0.000 dispatcher.py:152(send)
#    409276    0.235    0.000    0.235    0.000 {method 'pop' of 'list' objects}
#    242437    0.156    0.000    0.227    0.000 query.py:1061(<listcomp>)
#    732797    0.227    0.000    0.227    0.000 {built-in method builtins.iter}
#    155952    0.191    0.000    0.226    0.000 expressions.py:1160(__init__)
#     52944    0.148    0.000    0.225    0.000 inspect.py:66(get_annotations)
#    207307    0.156    0.000    0.223    0.000 operations.py:363(compiler)
#    414614    0.222    0.000    0.222    0.000 {method 'update' of 'set' objects}
#    414254    0.213    0.000    0.213    0.000 utils.py:93(__call__)
#     11898    0.026    0.000    0.212    0.000 fromnumeric.py:2979(prod)
#    299639    0.212    0.000    0.212    0.000 {method 'split' of 'str' objects}
#    416425    0.209    0.000    0.209    0.000 related.py:1057(target_field)
#    166479    0.204    0.000    0.204    0.000 query.py:2074(set_limits)
#     19948    0.040    0.000    0.203    0.000 2213152367.py:85(__init__)
#    248135    0.201    0.000    0.201    0.000 {method 'rpartition' of 'str' objects}
#    894694    0.201    0.000    0.201    0.000 {built-in method builtins.issubclass}
#    420312    0.196    0.000    0.196    0.000 {method 'copy' of 'set' objects}
#    263640    0.149    0.000    0.195    0.000 inspect.py:2969(<genexpr>)
#    722471    0.195    0.000    0.195    0.000 {method 'pop' of 'dict' objects}
#    288963    0.195    0.000    0.195    0.000 query.py:849(unref_alias)
#    286792    0.190    0.000    0.190    0.000 base.py:440(__get__)
#    258811    0.189    0.000    0.189    0.000 query.py:845(ref_alias)
#     19948    0.037    0.000    0.188    0.000 2213152367.py:132(__init__)
#     19948    0.037    0.000    0.186    0.000 2213152367.py:50(__init__)
#     11898    0.046    0.000    0.186    0.000 fromnumeric.py:71(_wrapreduction)
#     40828    0.135    0.000    0.186    0.000 related.py:779(get_joining_columns)
#    248135    0.130    0.000    0.184    0.000 __init__.py:934(get_prep_value)
#     46526    0.097    0.000    0.182    0.000 functional.py:264(inner)
#    414614    0.182    0.000    0.182    0.000 expressions.py:241(<genexpr>)
#     46166    0.069    0.000    0.180    0.000 query.py:2071(is_empty)
# 298050/297330    0.179    0.000    0.179    0.000 {built-in method builtins.hash}
#    206947    0.176    0.000    0.176    0.000 compiler.py:1516(<listcomp>)
#    878921    0.171    0.000    0.171    0.000 operations.py:632(get_db_converters)
#    414614    0.169    0.000    0.169    0.000 expressions.py:247(<genexpr>)
#     46526    0.169    0.000    0.169    0.000 {method 'search' of 're.Pattern' objects}
#   1488157    0.168    0.000    0.168    0.000 {built-in method builtins.id}
#    878921    0.168    0.000    0.168    0.000 __init__.py:507(select_format)
#    120313    0.133    0.000    0.168    0.000 _json.py:159(typecast_json)
#    120313    0.083    0.000    0.164    0.000 query.py:2108(can_filter)
#     40828    0.164    0.000    0.164    0.000 manager.py:128(_set_creation_counter)
#    207307    0.163    0.000    0.163    0.000 compiler.py:94(get_group_by)
#    166839    0.161    0.000    0.161    0.000 query.py:2236(clear_ordering)
#     40828    0.081    0.000    0.158    0.000 query.py:1245(check_query_object_type)
#    621921    0.157    0.000    0.157    0.000 {method 'upper' of 'str' objects}
#       275    0.001    0.000    0.157    0.001 1255315854.py:22(select)
#       250    0.003    0.000    0.155    0.001 1255315854.py:41(tournament_selection)
#    207307    0.154    0.000    0.154    0.000 query.py:796(get_select_mask)
#      2740    0.090    0.000    0.151    0.000 1255315854.py:49(tournament_selection_helper)
#    409785    0.150    0.000    0.150    0.000 expressions.py:181(__init__)
#    828868    0.147    0.000    0.147    0.000 utils.py:67(__enter__)
#    206947    0.145    0.000    0.145    0.000 query.py:47(__init__)
#     40828    0.056    0.000    0.145    0.000 related.py:1134(get_prep_value)
#    207307    0.142    0.000    0.142    0.000 utils.py:16(__init__)
#    120313    0.138    0.000    0.138    0.000 options.py:715(get_ancestor_link)
#    103728    0.136    0.000    0.136    0.000 options.py:162(label)
#    208387    0.133    0.000    0.133    0.000 query.py:2462(annotation_select)
#    332958    0.128    0.000    0.128    0.000 operations.py:253(<genexpr>)
#    201609    0.126    0.000    0.126    0.000 datastructures.py:195(__init__)
#    207307    0.125    0.000    0.125    0.000 compiler.py:509(get_extra_select)
#    166479    0.124    0.000    0.124    0.000 operations.py:242(_get_limit_offset_params)
#     46166    0.099    0.000    0.123    0.000 expressions.py:1578(__init__)
#    207307    0.119    0.000    0.119    0.000 query.py:1542(<setcomp>)
#    207307    0.116    0.000    0.116    0.000 base.py:588(close_if_health_check_failed)
#     81656    0.096    0.000    0.116    0.000 base.py:653(_get_pk_val)
#     40828    0.081    0.000    0.115    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#    212645    0.113    0.000    0.113    0.000 query.py:267(base_table)
#    435134    0.111    0.000    0.111    0.000 {method 'add' of 'set' objects}
#        76    0.000    0.000    0.111    0.001 __init__.py:1467(info)
#        76    0.000    0.000    0.111    0.001 __init__.py:1600(_log)
#     11898    0.108    0.000    0.108    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    120313    0.107    0.000    0.107    0.000 utils.py:240(allow_relation)
#       168    0.002    0.000    0.105    0.001 iostream.py:547(flush)
#        76    0.000    0.000    0.104    0.001 __init__.py:1626(handle)
#        76    0.000    0.000    0.104    0.001 __init__.py:1680(callHandlers)
#        76    0.000    0.000    0.103    0.001 __init__.py:955(handle)
#        76    0.000    0.000    0.103    0.001 __init__.py:1088(emit)
#    248227    0.103    0.000    0.103    0.000 {method '__exit__' of '_thread.RLock' objects}
#    206947    0.101    0.000    0.101    0.000 {built-in method from_iterable}
#    419592    0.097    0.000    0.099    0.000 {built-in method builtins.next}
#    683232    0.098    0.000    0.098    0.000 inspect.py:2687(name)
#    207307    0.095    0.000    0.096    0.000 query.py:1436(<setcomp>)
#    207307    0.093    0.000    0.093    0.000 base.py:284(ensure_connection)
#    210696    0.090    0.000    0.090    0.000 {method 'isidentifier' of 'str' objects}
#        92    0.000    0.000    0.086    0.001 ansitowin32.py:46(write)
#        92    0.000    0.000    0.086    0.001 ansitowin32.py:175(write)
#        92    0.000    0.000    0.085    0.001 ansitowin32.py:192(write_and_convert)
#   720/360    0.002    0.000    0.084    0.000 expressions.py:395(replace_expressions)
#        92    0.001    0.000    0.084    0.001 ansitowin32.py:208(write_plain_text)
#    105888    0.071    0.000    0.083    0.000 inspect.py:277(isfunction)
#    207627    0.081    0.000    0.081    0.000 {built-in method _thread.get_ident}
#    210696    0.079    0.000    0.079    0.000 enum.py:678(__new__)
#     46166    0.043    0.000    0.079    0.000 query.py:1813(final_transformer)
#       168    0.001    0.000    0.079    0.000 threading.py:589(wait)
#    580944    0.078    0.000    0.078    0.000 inspect.py:2699(kind)
#       151    0.001    0.000    0.077    0.001 threading.py:288(wait)
#     46166    0.054    0.000    0.076    0.000 query.py:1969(_check_ordering_first_last_queryset_aggregation)
#    105888    0.075    0.000    0.075    0.000 {method 'values' of 'mappingproxy' objects}
#      1200    0.075    0.000    0.075    0.000 {method 'acquire' of '_thread.lock' objects}
#    207475    0.075    0.000    0.075    0.000 {method '__exit__' of '_thread.lock' objects}
#    120313    0.074    0.000    0.074    0.000 base.py:430(_base_manager)
#    332958    0.074    0.000    0.074    0.000 __init__.py:2792(get_internal_type)
#    366139    0.073    0.000    0.073    0.000 {built-in method builtins.callable}
#    207307    0.071    0.000    0.071    0.000 base.py:529(validate_no_broken_transaction)
#     40468    0.071    0.000    0.071    0.000 2213152367.py:122(<dictcomp>)
#     40828    0.045    0.000    0.071    0.000 query_utils.py:367(check_rel_lookup_compatibility)
#    207307    0.069    0.000    0.069    0.000 __init__.py:2740(get_db_prep_value)
#    240626    0.069    0.000    0.069    0.000 {method 'end' of 're.Match' objects}
#    254193    0.067    0.000    0.067    0.000 expressions.py:200(set_source_expressions)
#     46166    0.066    0.000    0.066    0.000 {method 'count' of 'str' objects}
#     40828    0.037    0.000    0.065    0.000 query.py:1929(_add_hints)
#     92332    0.063    0.000    0.063    0.000 query.py:2592(get_order_dir)
#    586863    0.063    0.000    0.063    0.000 copy.py:182(_deepcopy_atomic)
#     92332    0.042    0.000    0.057    0.000 query.py:2072(<genexpr>)
#     46166    0.046    0.000    0.057    0.000 itercompat.py:1(is_iterable)
#    207307    0.056    0.000    0.056    0.000 operations.py:215(field_cast_sql)
#    255273    0.054    0.000    0.054    0.000 expressions.py:197(get_source_expressions)
#       285    0.001    0.000    0.054    0.000 2174509031.py:20(calculate_fitness)
#       285    0.042    0.000    0.052    0.000 2174509031.py:8(calculate_conflicts)
#     81656    0.051    0.000    0.051    0.000 related.py:781(<genexpr>)
#     40828    0.049    0.000    0.049    0.000 __init__.py:927(get_internal_type)
#     40828    0.049    0.000    0.049    0.000 query.py:2573(is_nullable)
#     40828    0.048    0.000    0.048    0.000 query.py:1916(<dictcomp>)
#     40828    0.036    0.000    0.048    0.000 __init__.py:643(__hash__)
#     40828    0.032    0.000    0.046    0.000 datastructures.py:215(__eq__)
#     52944    0.031    0.000    0.044    0.000 inspect.py:632(_is_wrapper)
#     99740    0.042    0.000    0.042    0.000 options.py:415(swapped)
#     40468    0.041    0.000    0.041    0.000 query.py:111(<listcomp>)
#     52944    0.041    0.000    0.041    0.000 {method 'items' of 'mappingproxy' objects}
#        76    0.001    0.000    0.036    0.000 __init__.py:1077(flush)
#    120313    0.034    0.000    0.034    0.000 base.py:283(<lambda>)
#     81656    0.032    0.000    0.032    0.000 query.py:1921(<genexpr>)
#     46166    0.032    0.000    0.032    0.000 expressions.py:1604(set_source_expressions)
#     40828    0.032    0.000    0.032    0.000 query.py:1912(<setcomp>)
#   720/360    0.001    0.000    0.031    0.000 expressions.py:401(<listcomp>)
#     52944    0.031    0.000    0.031    0.000 inspect.py:2779(__init__)
#    158832    0.031    0.000    0.031    0.000 inspect.py:3006(parameters)
#       428    0.002    0.000    0.031    0.000 iostream.py:243(schedule)
#    120313    0.031    0.000    0.031    0.000 related.py:788(get_extra_descriptor_filter)
#    100100    0.029    0.000    0.029    0.000 {method 'setdefault' of 'dict' objects}
#       285    0.001    0.000    0.029    0.000 491081120.py:34(calculate_fitness)
#       285    0.004    0.000    0.027    0.000 491081120.py:24(calculate_overload_penalty)
#     46242    0.027    0.000    0.027    0.000 {method 'rstrip' of 'str' objects}
#    159912    0.027    0.000    0.027    0.000 inspect.py:2691(default)
#       428    0.027    0.000    0.027    0.000 socket.py:545(send)
#     40828    0.026    0.000    0.026    0.000 query_utils.py:375(check)
#     40828    0.019    0.000    0.025    0.000 datastructures.py:160(__eq__)
#     52944    0.024    0.000    0.024    0.000 {built-in method sys.getrecursionlimit}
#     44417    0.022    0.000    0.022    0.000 {method '__reduce_ex__' of 'datetime.datetime' objects}
#         1    0.000    0.000    0.021    0.021 3775596053.py:27(show_config)
#         8    0.000    0.000    0.021    0.003 {built-in method builtins.print}
#     40828    0.021    0.000    0.021    0.000 {method 'issubset' of 'set' objects}
#     44417    0.019    0.000    0.019    0.000 __init__.py:447(__getnewargs__)
#     41188    0.017    0.000    0.017    0.000 __init__.py:2063(get_internal_type)
#       360    0.001    0.000    0.017    0.000 aggregates.py:60(resolve_expression)
#     46166    0.017    0.000    0.017    0.000 expressions.py:1607(get_source_expressions)
#     40828    0.016    0.000    0.016    0.000 query.py:1913(<setcomp>)
#     46526    0.016    0.000    0.016    0.000 operations.py:645(check_expression_support)
#     40468    0.016    0.000    0.016    0.000 {method 'keys' of 'dict' objects}
#       360    0.001    0.000    0.014    0.000 expressions.py:936(resolve_expression)
#       720    0.002    0.000    0.014    0.000 expressions.py:986(copy)
#       285    0.011    0.000    0.013    0.000 491081120.py:12(calculate_assistants_assignments)
#        92    0.001    0.000    0.012    0.000 iostream.py:610(write)
#     11898    0.011    0.000    0.011    0.000 fromnumeric.py:72(<dictcomp>)
#        92    0.000    0.000    0.011    0.000 iostream.py:532(_schedule_flush)
#       285    0.007    0.000    0.009    0.000 491081120.py:18(calculate_assistants_shifts)
#     10729    0.003    0.000    0.006    0.000 <string>:1(<lambda>)
#     11396    0.006    0.000    0.006    0.000 base.py:342(tzinfo_factory)
#       360    0.001    0.000    0.006    0.000 aggregates.py:114(as_sql)
#       360    0.002    0.000    0.005    0.000 aggregates.py:167(__init__)
#       360    0.003    0.000    0.004    0.000 expressions.py:947(as_sql)
#        76    0.000    0.000    0.004    0.000 __init__.py:1585(makeRecord)
#     11898    0.004    0.000    0.004    0.000 fromnumeric.py:2974(_prod_dispatcher)
#        76    0.001    0.000    0.004    0.000 __init__.py:283(__init__)
#       360    0.001    0.000    0.004    0.000 expressions.py:190(get_db_converters)
#       360    0.001    0.000    0.004    0.000 query.py:1123(check_alias)
# 2160/1080    0.002    0.000    0.003    0.000 expressions.py:408(get_refs)
#       181    0.001    0.000    0.003    0.000 1117434174.py:29(mutation_point)
#       168    0.001    0.000    0.003    0.000 threading.py:545(__init__)
#      3569    0.003    0.000    0.003    0.000 {built-in method math.ceil}
#       360    0.001    0.000    0.003    0.000 aggregates.py:34(__init__)
#        89    0.003    0.000    0.003    0.000 812580972.py:35(crossover_point)
#      2850    0.003    0.000    0.003    0.000 {method 'index' of 'list' objects}
#       596    0.001    0.000    0.002    0.000 threading.py:1169(is_alive)
#       181    0.000    0.000    0.002    0.000 random.py:366(randint)
#       360    0.001    0.000    0.002    0.000 expressions.py:901(__init__)
#       181    0.001    0.000    0.002    0.000 random.py:292(randrange)
#        76    0.001    0.000    0.002    0.000 __init__.py:1549(findCaller)
#       168    0.002    0.000    0.002    0.000 threading.py:236(__init__)
#       360    0.001    0.000    0.002    0.000 expressions.py:350(convert_value)
#      1440    0.001    0.000    0.002    0.000 aggregates.py:50(get_source_expressions)
#       362    0.001    0.000    0.001    0.000 random.py:239(_randbelow_with_getrandbits)
#      8220    0.001    0.000    0.001    0.000 1255315854.py:51(<lambda>)
#        76    0.000    0.000    0.001    0.000 ntpath.py:240(basename)
#        76    0.000    0.000    0.001    0.000 __init__.py:932(format)
#        76    0.001    0.000    0.001    0.000 ntpath.py:206(split)
#        51    0.001    0.000    0.001    0.000 3775596053.py:49(loggings)
#       720    0.001    0.000    0.001    0.000 1277855371.py:5(__init__)
#        76    0.000    0.000    0.001    0.000 __init__.py:665(format)
#       855    0.001    0.000    0.001    0.000 {method 'clear' of 'dict' objects}
#      3496    0.001    0.000    0.001    0.000 {built-in method builtins.max}
#       181    0.000    0.000    0.001    0.000 random.py:375(choice)
#       596    0.001    0.000    0.001    0.000 threading.py:1102(_wait_for_tstate_lock)
#        76    0.000    0.000    0.001    0.000 ntpath.py:51(normcase)
#       319    0.001    0.000    0.001    0.000 {built-in method _thread.allocate_lock}
#        92    0.001    0.000    0.001    0.000 ansitowin32.py:260(convert_osc)
#       360    0.000    0.000    0.001    0.000 expressions.py:203(_parse_expressions)
#        76    0.000    0.000    0.001    0.000 ntpath.py:229(splitext)
#       720    0.001    0.000    0.001    0.000 query.py:2387(set_annotation_mask)
#       428    0.001    0.000    0.001    0.000 iostream.py:127(_event_pipe)
#       360    0.001    0.000    0.001    0.000 aggregates.py:56(set_source_expressions)
#       360    0.001    0.000    0.001    0.000 {method 'fetchone' of 'psycopg2.extensions.cursor' objects}
#       360    0.000    0.000    0.001    0.000 query.py:419(<dictcomp>)
#        76    0.000    0.000    0.001    0.000 genericpath.py:121(_splitext)
#       151    0.000    0.000    0.001    0.000 threading.py:276(_acquire_restore)
#       360    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#       360    0.000    0.000    0.000    0.000 query.py:2097(clear_limits)
#        76    0.000    0.000    0.000    0.000 ntpath.py:150(splitdrive)
#       360    0.000    0.000    0.000    0.000 expressions.py:204(<listcomp>)
#        76    0.000    0.000    0.000    0.000 __init__.py:649(formatMessage)
#       244    0.000    0.000    0.000    0.000 threading.py:1430(current_thread)
#        25    0.000    0.000    0.000    0.000 1255315854.py:35(elitism_selection)
#        76    0.000    0.000    0.000    0.000 __init__.py:438(format)
#       168    0.000    0.000    0.000    0.000 threading.py:267(__exit__)
#       360    0.000    0.000    0.000    0.000 query.py:544(<listcomp>)
#      1440    0.000    0.000    0.000    0.000 expressions.py:930(get_source_expressions)
#       152    0.000    0.000    0.000    0.000 __init__.py:912(acquire)
#       184    0.000    0.000    0.000    0.000 {method 'finditer' of 're.Pattern' objects}
#        76    0.000    0.000    0.000    0.000 {built-in method _winapi.LCMapStringEx}
#        76    0.000    0.000    0.000    0.000 __init__.py:643(usesTime)
#        76    0.000    0.000    0.000    0.000 __init__.py:431(_format)
#      1080    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#       360    0.000    0.000    0.000    0.000 expressions.py:367(<lambda>)
#       360    0.000    0.000    0.000    0.000 query.py:2473(<dictcomp>)
#       336    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#       168    0.000    0.000    0.000    0.000 threading.py:264(__enter__)
#        51    0.000    0.000    0.000    0.000 3775596053.py:54(<listcomp>)
#       554    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#       720    0.000    0.000    0.000    0.000 query.py:548(<genexpr>)
#       152    0.000    0.000    0.000    0.000 __init__.py:919(release)
#       360    0.000    0.000    0.000    0.000 query.py:2395(append_annotation_mask)
#        76    0.000    0.000    0.000    0.000 __init__.py:160(<lambda>)
#        76    0.000    0.000    0.000    0.000 __init__.py:423(usesTime)
#        92    0.000    0.000    0.000    0.000 iostream.py:505(_is_master_process)
#       152    0.000    0.000    0.000    0.000 ansitowin32.py:28(__getattr__)
#       151    0.000    0.000    0.000    0.000 threading.py:279(_is_owned)
#       336    0.000    0.000    0.000    0.000 threading.py:1145(ident)
#       250    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#       360    0.000    0.000    0.000    0.000 hashable.py:12(<listcomp>)
#       360    0.000    0.000    0.000    0.000 query.py:425(<genexpr>)
#       579    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       360    0.000    0.000    0.000    0.000 2213152367.py:27(modules)
#       228    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#       360    0.000    0.000    0.000    0.000 query.py:406(<genexpr>)
#       543    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#       151    0.000    0.000    0.000    0.000 threading.py:273(_release_save)
#       596    0.000    0.000    0.000    0.000 threading.py:553(is_set)
#       360    0.000    0.000    0.000    0.000 expressions.py:1111(as_sql)
#        76    0.000    0.000    0.000    0.000 __init__.py:119(getLevelName)
#        76    0.000    0.000    0.000    0.000 __init__.py:1724(isEnabledFor)
#       168    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#       360    0.000    0.000    0.000    0.000 expressions.py:933(set_source_expressions)
#       152    0.000    0.000    0.000    0.000 __init__.py:806(filter)
#       362    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#       274    0.000    0.000    0.000    0.000 1255315854.py:38(<lambda>)
#       152    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#       168    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#       360    0.000    0.000    0.000    0.000 query.py:410(<genexpr>)
#       152    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#        76    0.000    0.000    0.000    0.000 ntpath.py:35(_get_bothseps)
#        92    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        76    0.000    0.000    0.000    0.000 __init__.py:359(getMessage)
#        76    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#       304    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#       126    0.000    0.000    0.000    0.000 {built-in method time.time}
#        76    0.000    0.000    0.000    0.000 threading.py:1129(name)
#        76    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#       152    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#        26    0.000    0.000    0.000    0.000 2172666981.py:4(__init__)
#       151    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#        10    0.000    0.000    0.000    0.000 1412964167.py:7(__init__)
#        10    0.000    0.000    0.000    0.000 2213152367.py:89(groups)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
best_chromosome = algorithm.get_best_chromosome()

# %%
best_chromosome.fitness
# Out:
# 38

# %%
best_chromosome.genes
# Out:
# [Gene(lab=1, module=1, module_chapter=1, group=1, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=2, group=1, assistant=6, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=1, group=2, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=2, group=2, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift1')),
#  Gene(lab=1, module=1, module_chapter=1, group=3, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=2, group=3, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=1, group=4, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 19, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Monday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=2, group=4, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift1')),
#  Gene(lab=1, module=1, module_chapter=1, group=5, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 24, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Saturday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=2, group=5, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift1')),
#  Gene(lab=1, module=1, module_chapter=1, group=6, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 24, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Saturday', shift='Shift1')),
#  Gene(lab=1, module=1, module_chapter=2, group=6, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=1, group=7, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=2, group=7, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=1, group=8, assistant=6, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 19, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Monday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=2, group=8, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 24, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Saturday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=1, group=9, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=2, group=9, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=1, group=10, assistant=6, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=2, group=10, assistant=6, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=1, group=11, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 24, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Saturday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=2, group=11, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=1, group=12, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=2, group=12, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=1, group=13, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=2, group=13, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 24, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Saturday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=1, group=14, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=2, group=14, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=1, group=15, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 24, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Saturday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=2, group=15, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift1')),
#  Gene(lab=1, module=1, module_chapter=1, group=16, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=2, group=16, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=1, group=17, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=2, group=17, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=1, group=18, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=2, group=18, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=1, group=19, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 19, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Monday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=2, group=19, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=1, group=20, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift1')),
#  Gene(lab=1, module=1, module_chapter=2, group=20, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=1, group=21, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=2, group=21, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=1, group=22, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=2, group=22, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=1, group=23, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=2, group=23, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=1, group=24, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=2, group=24, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 19, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Monday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=1, group=25, assistant=6, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 19, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Monday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=2, group=25, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=1, group=26, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 19, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Monday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=2, group=26, assistant=6, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=1, group=27, assistant=6, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=2, group=27, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=1, group=28, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=2, group=28, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=1, group=29, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 24, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Saturday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=2, group=29, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=1, group=30, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=2, group=30, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=1, group=31, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 19, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Monday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=2, group=31, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=1, group=32, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 24, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Saturday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=2, group=32, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=1, group=33, assistant=6, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift1')),
#  Gene(lab=1, module=1, module_chapter=2, group=33, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 19, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Monday', shift='Shift1')),
#  Gene(lab=1, module=1, module_chapter=1, group=34, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 19, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Monday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=2, group=34, assistant=6, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=1, group=35, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 24, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Saturday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=2, group=35, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=1, group=36, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=2, group=36, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift2'))]

# %% [markdown]
# ##### Test Data

# %%
# display best chromosome on pandas dataframe, group each gene by date and shift, which the assistant as the column and show the group as the value
import pandas as pd
data = []
for gene in best_chromosome.genes:
    data.append([gene.time_slot.date, gene.time_slot.shift, gene.assistant, gene.group])
df = pd.DataFrame(data, columns=["Date", "Shift", "Assistant", "Group"])
df = df.groupby(["Date", "Shift", "Assistant"])["Group"].apply(list).reset_index()
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 4
#       2 import pandas as pd
#       3 data = []
# ----> 4 for gene in best_chromosome.genes:
#       5     data.append([gene.time_slot.date, gene.time_slot.shift, gene.assistant, gene.group])
#       6 df = pd.DataFrame(data, columns=["Date", "Shift", "Assistant", "Group"])
#
# NameError: name 'best_chromosome' is not defined

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')
start_date = df["Date"].min()
date_interval = pd.DateOffset(days=7)

weekly_schedule = []
while start_date <= df["Date"].max():
    end_date = start_date + date_interval
    weekly_df = df[(df["Date"] >= start_date) & (df["Date"] < end_date)]
    # fill missing values with empty list
    weekly_schedule.append(weekly_df.pivot_table(index=["Date", "Shift"], columns="Assistant", values="Group", aggfunc=lambda x: x))
    start_date = end_date

for i, weekly_df in enumerate(weekly_schedule):
    print(f"Week {i+1}")
    # Format date to dd-mm-yyyy
    weekly_df.index = weekly_df.index.set_levels(weekly_df.index.levels[0].strftime('%d-%m-%Y'), level=0)
    print(weekly_df)
    print("\n")
# Out:
# Week 1
# Assistant                1         2             3         4        5        6
# Date       Shift
# 19-09-2022 Shift1      NaN       NaN           NaN       NaN     [33]      NaN
#            Shift2      NaN       NaN           NaN       NaN      NaN  [8, 25]
#            Shift3      NaN  [31, 34]           NaN      [24]      NaN      NaN
#            Shift4      NaN       [4]           NaN       NaN      NaN      NaN
#            Shift5      NaN       NaN          [26]       NaN     [19]      NaN
# 20-09-2022 Shift1      NaN       NaN           [2]       NaN      NaN      NaN
#            Shift2      NaN       NaN      [20, 21]  [12, 21]     [36]      NaN
#            Shift3      NaN       NaN          [14]       NaN     [24]      NaN
#            Shift4     [16]       NaN           NaN       NaN      NaN      NaN
#            Shift5     [31]  [13, 27]           NaN    [7, 9]      NaN     [10]
#            Shift6      NaN       NaN           NaN       NaN     [29]      NaN
# 21-09-2022 Shift1      NaN       NaN           NaN      [20]      NaN      NaN
#            Shift2      NaN       NaN           NaN      [11]      [7]      NaN
#            Shift3      NaN       NaN  [18, 19, 30]       NaN      NaN      NaN
#            Shift4     [14]       NaN           NaN       NaN      NaN      NaN
#            Shift6      NaN       NaN       [3, 25]       NaN      NaN      [1]
# 22-09-2022 Shift1      NaN       [4]           NaN       NaN      NaN      NaN
#            Shift2      NaN       NaN           NaN       NaN      NaN     [10]
#            Shift3      NaN       NaN           NaN       NaN     [30]      NaN
#            Shift4     [17]      [17]           NaN      [23]     [12]      NaN
#            Shift5      NaN       [1]           NaN       NaN      NaN     [34]
#            Shift6      NaN  [18, 22]           NaN       [9]      NaN     [26]
# 23-09-2022 Shift1      NaN      [15]           NaN       [5]      NaN     [33]
#            Shift2      NaN       NaN          [28]       NaN     [36]      NaN
#            Shift3     [22]       NaN           NaN       NaN  [3, 35]      NaN
#            Shift4  [2, 16]       NaN           NaN       NaN      NaN      NaN
#            Shift5     [23]       NaN           NaN       NaN      NaN      NaN
#            Shift6      NaN      [32]          [28]       [6]      NaN     [27]
# 24-09-2022 Shift1      [6]       NaN           NaN       NaN      NaN      NaN
#            Shift2      [8]       NaN          [29]       NaN     [32]      NaN
#            Shift3      NaN       NaN      [13, 15]       NaN      NaN      NaN
#            Shift4      [5]       NaN           NaN       NaN      NaN      NaN
#            Shift5      NaN      [35]           NaN       NaN      NaN      NaN
#            Shift6      NaN      [11]           NaN       NaN      NaN      NaN

# %%
# Count total of shifts and group for each assistant, each shift of the same day with different group is counted as 1

assistant_shifts = defaultdict(set)
assistant_groups = defaultdict(set)
assistant_modules = defaultdict(set)

for gene in best_chromosome.genes:
    assistant_shifts[gene.assistant].add((gene.time_slot.date, gene.time_slot.shift, gene.module))
    assistant_groups[gene.assistant].add((gene.time_slot.date, gene.time_slot.shift, gene.group, gene.module))


#sort by assistant id
assistant_shifts = dict(sorted(assistant_shifts.items()))
for assistant in assistant_shifts:
    assistant_name = assistant_data.get_assistant(assistant)
    print(f"Assistant {assistant_name} of {assistant_name.laboratory}")
    print(f"Total shifts: {len(assistant_shifts[assistant])}")
    print(f"Total groups: {len(assistant_groups[assistant])}")
    print("---------------------------------")
# Out:
# Assistant Fatimah of Dasar Elektro
# Total shifts: 10
# Total groups: 11
# ---------------------------------
# Assistant Rahmat of Dasar Elektro
# Total shifts: 11
# Total groups: 14
# ---------------------------------
# Assistant Amel of Dasar Elektro
# Total shifts: 10
# Total groups: 15
# ---------------------------------
# Assistant Bowo of Dasar Elektro
# Total shifts: 9
# Total groups: 11
# ---------------------------------
# Assistant Rafli of Dasar Elektro
# Total shifts: 11
# Total groups: 12
# ---------------------------------
# Assistant Andi of Dasar Elektro
# Total shifts: 8
# Total groups: 9
# ---------------------------------

# %% [markdown]
# # Tabu Search
#
# ```python

# %%
#tabu search
import collections
from copy import deepcopy
import numpy as np
import itertools
import random

# %% [markdown]
# ## Tabu List

# %%
# Tabu Search Operators
import collections
class TabuList:
    def __init__(self, tabu_list_size):
        """"
        Tabu list class for managing tabu list
        :param tabu_list_size: Tabu list size
        :type tabu_list_size: int
        """
        self.tabu_list_size = tabu_list_size
        self.tabu_list = collections.deque(maxlen=tabu_list_size)
    
    def __repr__(self):
        return f"Tabu List Size: {self.tabu_list_size}, Tabu List: {self.tabu_list}"
    
    def __str__(self):
        return f"Tabu List Size: {self.tabu_list_size}, Tabu List: {self.tabu_list}"
    
    def is_tabu(self, chromosome: Chromosome):
        '''
        Check if chromosome is in tabu list
        :param chromosome: Chromosome
        :type chromosome: Chromosome
        :return: bool
        '''
        return chromosome in self.tabu_list
        
    
    def clear(self):
        '''
        Clear tabu list
        :return: None
        '''
        self.tabu_list.clear()
    
    def update(self, chromosome):
        '''
        Update tabu list
        :param chromosome: Chromosome
        :type chromosome: Chromosome
        :return: None
        '''
        self.tabu_list.append(chromosome)

# %% [markdown]
# ## Neighborhood Operation

# %%
# Neighborhood Operators

import itertools
from copy import deepcopy
import numpy as np
class Neighborhood:
    def __init__(self, tabu_list: TabuList):
        self.tabu_list = tabu_list
    
    def swap(self, chromosome: Chromosome):
        '''
        Swap two adjacent genes
        :param chromosome: Chromosome
        :type chromosome: Chromosome
        :return: Chromosome
        '''
        if settings.DEBUG:
            logger.info("Swapping...")
        new_chromosome = deepcopy(chromosome)
        max_distance = min(2, len(new_chromosome.genes) - 1)
        swap_attempt = min(2, len(new_chromosome.genes) // 2)

        for _ in range(swap_attempt):
            gene1, gene2 = np.random.choice(new_chromosome.genes, 2, replace=False)
            if abs(new_chromosome.genes.index(gene1) - new_chromosome.genes.index(gene2)) <= max_distance:
                if gene1.module == gene2.module:
                    gene1.assistant, gene2.assistant = gene2.assistant, gene1.assistant
                    gene1.time_slot, gene2.time_slot = gene2.time_slot, gene1.time_slot
                if not self.tabu_list.is_tabu(new_chromosome):
                    logger.info("Swapped! gene1 index: {}, gene2 index: {}".format(new_chromosome.genes.index(gene1), new_chromosome.genes.index(gene2)))
                    return new_chromosome
                else:
                    if gene1.module == gene2.module:
                        gene1.assistant, gene2.assistant = gene2.assistant, gene1.assistant
                        gene1.time_slot, gene2.time_slot = gene2.time_slot, gene1.time_slot
    
    def swap_random(self, chromosome: Chromosome):
        '''
        Swap two random genes
        :param chromosome: Chromosome
        :type chromosome: Chromosome
        :return: Chromosome
        '''
        if settings.DEBUG:
            logger.info("Swapping random...")
        new_chromosome = deepcopy(chromosome)
        swap_attempt = min(2, len(new_chromosome.genes) // 2)
        for _ in range(swap_attempt):
            gene1, gene2 = np.random.choice(new_chromosome.genes, 2, replace=False)
            if gene1.module == gene2.module:
                gene1.assistant, gene2.assistant = gene2.assistant, gene1.assistant
                gene1.time_slot, gene2.time_slot = gene2.time_slot, gene1.time_slot
            if not self.tabu_list.is_tabu(new_chromosome):
                logger.info("Swapped! gene1 index: {}, gene2 index: {}".format(new_chromosome.genes.index(gene1), new_chromosome.genes.index(gene2)))
                return new_chromosome
            else:
                if gene1.module == gene2.module:
                    gene1.assistant, gene2.assistant = gene2.assistant, gene1.assistant
                    gene1.time_slot, gene2.time_slot = gene2.time_slot, gene1.time_slot

        
    def run(self, chromosome: Chromosome):
        '''
        Run neighborhood operators
        :param chromosome: Chromosome
        :type chromosome: Chromosome
        :return: list
        '''
        if settings.DEBUG:
            logger.info("Running neighborhood operators...")
        neighborhood = []
        neighborhood.append(self.swap(chromosome))
        #neighborhood.append(self.swap_random(chromosome))

        neighborhood = [neighbor for neighbor in neighborhood if neighbor is not None]
        return neighborhood

# %%
# Test Neighborhood
tabu_list = TabuList(tabu_list_size=10)
neighborhood = Neighborhood(tabu_list)
best_chromosome = algorithm.get_best_chromosome()

len(best_chromosome.genes)
# Out:
# 72

# %% [markdown]
# ## Search Strategy
#
# ```python

# %%
# Strategy Operators
# Best Improvement, First Improvement, Random

class Strategy:
    def __init__(self, tabu_list: TabuList, fitness_function: FitnessFunction):
        self.tabu_list = tabu_list
        self.fitness_function = fitness_function
    
    def best_improvement(self, neighborhood: list) -> Chromosome:
        '''
        Best improvement strategy
        :param neighborhood: Neighborhood
        :type neighborhood: list
        :return: Chromosome
        '''
        if settings.DEBUG:
            logger.info("Best improvement...")
        best_chromosome = None
        best_fitness = 0
        for chromosome in neighborhood:
            fitness = self.fitness_function.calculate_fitness(chromosome)
            logger.info(f"Fitness: {fitness}, Best fitness: {best_fitness}")

            if fitness > best_fitness:
                best_fitness = fitness
                best_chromosome = chromosome
        return best_chromosome
    
    def first_improvement(self, neighborhood: list) -> Chromosome:
        '''
        First improvement strategy
        :param neighborhood: Neighborhood
        :type neighborhood: list
        :return: Chromosome
        '''
        if settings.DEBUG:
            logger.info("First improvement...")
        for chromosome in neighborhood:
            if not self.tabu_list.is_tabu(chromosome):
                return chromosome
        return None
    
    def random(self, neighborhood: list) -> Chromosome:
        '''
        Random strategy
        :param neighborhood: Neighborhood
        :type neighborhood: list
        :return: Chromosome
        '''
        if settings.DEBUG:
            logger.info("Random...")
        return random.choice(neighborhood)
    
    def run(self, neighborhood: list, method: str = "best_improvement") -> Chromosome:
        '''
        Run strategy
        :param neighborhood: Neighborhood
        :type neighborhood: list
        :return: Chromosome
        '''
        if method == "best_improvement":
            selected_strategy = self.best_improvement
        elif method == "first_improvement":
            selected_strategy = self.first_improvement
        elif method == "random":
            selected_strategy = self.random
        return selected_strategy(neighborhood)

# %% [markdown]
# ## Tabu Search Algorithm
#
# ```python

# %%
# Tabu Search
class TabuSearch:
    def __init__(self, tabu_list: TabuList, neighborhood: Neighborhood, strategy: Strategy, fitness_function: FitnessFunction, max_iteration: int = 100):
        self.tabu_list = tabu_list
        self.neighborhood = neighborhood
        self.strategy = strategy
        self.max_iteration = max_iteration
        self.fitness_function = fitness_function
        self.fitness_function.initialize()
        
    
    def search(self, chromosome: Chromosome, method: str = "swap") -> Chromosome:
        '''
        Tabu search
        :param chromosome: Chromosome
        :type chromosome: Chromosome
        :return: Chromosome
        '''
        self.tabu_list.clear()
        if settings.DEBUG:
            logger.info("Tabu search...")
        iteration = 0
        best_chromosome = chromosome
        while iteration < self.max_iteration:
            iteration += 1
            neighborhood = self.neighborhood.run(best_chromosome)
            logger.info(f"Neighborhood size: {len(neighborhood)}")
            best_chromosome = self.strategy.run(neighborhood, method="best_improvement")
            self.tabu_list.update(best_chromosome)
            logger.info(f"Iteration {iteration}, Best fitness: {best_chromosome.fitness}")
        return best_chromosome

# %%
chromosome = best_chromosome
tabu_list = TabuList(tabu_list_size=5)
fitness_function = FitnessFunction()
fitness_function.max_groups_per_assistant = 15
fitness_function.max_shift_per_assistant = 15
neighborhood = Neighborhood(tabu_list)
strategy = Strategy(tabu_list, fitness_function)
tabu_search = TabuSearch(tabu_list, neighborhood, strategy, max_iteration=20, fitness_function=fitness_function)
settings.DEBUG = False
best_chromosome_tabu = tabu_search.search(chromosome, method="swap")
# Out:
# INFO:__main__:Neighborhood size: 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Projects\Kuliah\skripsi\jte-lab-timetabling\LabTimetablingAPI\Sistem_penjadwalan GA dan TS weekly.ipynb Cell 99 line 1
#       <a href='vscode-notebook-cell:/d%3A/Projects/Kuliah/skripsi/jte-lab-timetabling/LabTimetablingAPI/Sistem_penjadwalan%20GA%20dan%20TS%20weekly.ipynb#Y200sZmlsZQ%3D%3D?line=7'>8</a> tabu_search = TabuSearch(tabu_list, neighborhood, strategy, max_iteration=20, fitness_function=fitness_function)
#       <a href='vscode-notebook-cell:/d%3A/Projects/Kuliah/skripsi/jte-lab-timetabling/LabTimetablingAPI/Sistem_penjadwalan%20GA%20dan%20TS%20weekly.ipynb#Y200sZmlsZQ%3D%3D?line=8'>9</a> settings.DEBUG = False
# ---> <a href='vscode-notebook-cell:/d%3A/Projects/Kuliah/skripsi/jte-lab-timetabling/LabTimetablingAPI/Sistem_penjadwalan%20GA%20dan%20TS%20weekly.ipynb#Y200sZmlsZQ%3D%3D?line=9'>10</a> best_chromosome_tabu = tabu_search.search(chromosome, method="swap")
#
# d:\Projects\Kuliah\skripsi\jte-lab-timetabling\LabTimetablingAPI\Sistem_penjadwalan GA dan TS weekly.ipynb Cell 99 line 3
#      <a href='vscode-notebook-cell:/d%3A/Projects/Kuliah/skripsi/jte-lab-timetabling/LabTimetablingAPI/Sistem_penjadwalan%20GA%20dan%20TS%20weekly.ipynb#Y200sZmlsZQ%3D%3D?line=27'>28</a>     best_chromosome = self.strategy.run(neighborhood, method="best_improvement")
#      <a href='vscode-notebook-cell:/d%3A/Projects/Kuliah/skripsi/jte-lab-timetabling/LabTimetablingAPI/Sistem_penjadwalan%20GA%20dan%20TS%20weekly.ipynb#Y200sZmlsZQ%3D%3D?line=28'>29</a>     self.tabu_list.update(best_chromosome)
# ---> <a href='vscode-notebook-cell:/d%3A/Projects/Kuliah/skripsi/jte-lab-timetabling/LabTimetablingAPI/Sistem_penjadwalan%20GA%20dan%20TS%20weekly.ipynb#Y200sZmlsZQ%3D%3D?line=29'>30</a>     logger.info(f"Iteration {iteration}, Best fitness: {best_chromosome.fitness}")
#      <a href='vscode-notebook-cell:/d%3A/Projects/Kuliah/skripsi/jte-lab-timetabling/LabTimetablingAPI/Sistem_penjadwalan%20GA%20dan%20TS%20weekly.ipynb#Y200sZmlsZQ%3D%3D?line=30'>31</a> return best_chromosome
#
# AttributeError: 'NoneType' object has no attribute 'fitness'

# %%
# Out:
# False

# %%
class TabuSearchBuilder:
    def __init__(self):
        self.tabu_list_size = None
        self.max_iteration = None
        self.neighborhood_method = None
        self.search_strategy = None
        self.factory = Factory()
        self.fitness_function = FitnessFunction()
        self.tabu_list = TabuList(self.tabu_list_size)
        self.neighborhood = Neighborhood()
        self.logging = False
        self._results = defaultdict(list)
        self._best_chromosome = None
        self._best_fitness = None
        self._best_iteration = None
        self._best_chromosome_history = []
        self._best_fitness_history = []
    
    def set_tabu_list_size(self, tabu_list_size):
        self.tabu_list_size = tabu_list_size
        return self
    
    def set_max_iteration(self, max_iteration):
        self.max_iteration = max_iteration
        return self
    
    def set_neighborhood_method(self, neighborhood_method):
        self.neighborhood_method = neighborhood_method
        return self
    
    def set_search_strategy(self, search_strategy):
        self.search_strategy = search_strategy
        return self
    
    def set_factory(self, factory):
        self.factory = factory
        return self
    
    def set_fitness_function(self, fitness_function):
        self.fitness_function = fitness_function
        return self
    
    def set_logging(self, logging):
        self.logging = logging
        return self
    
    def get_results(self):
        return self._results
    
    def get_best_chromosome(self):
        return self._best_chromosome
    
    def get_best_fitness(self):
        return self._best_fitness
    
    def get_best_iteration(self):
        return self._best_iteration
    
    def get_best_chromosome_history(self):
        return self._best_chromosome_history
    
    def get_best_fitness_history(self):
        return self._best_fitness_history
    
    def build(self):
        if self.tabu_list_size is None:
            raise ValueError("Tabu list size is not set")
        if self.max_iteration is None:
            raise ValueError("Max iteration is not set")
        if self.neighborhood_method is None:
            raise ValueError("Neighborhood method is not set")
        if self.search_strategy is None:
            raise ValueError("Search strategy is not set")
        if self.factory is None:
            raise ValueError("Factory is not set")
        if self.fitness_function is None:
            raise ValueError("Fitness function is not set")
        return TabuSearch(self)

# %%
# #test TabuSearch
builder = TabuSearchBuilder()
builder.tabu_list_size = 10
builder.max_iteration = 100
builder.neighborhood_method = "swap"
builder.search_strategy = FirstImprovementStrategy(max_iteration=100)
builder.factory = Factory()
builder.fitness_function = FitnessFunction()
builder.logging = True
tabu_search = builder.build()
