# %% [markdown]
# # Sistem Penjadwalan Praktikum Otomatis menggunakan Algoritma Genetika dan Tabu Search.

# %% [markdown]
# # Setup

# %%
import os
import sys
import django
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "LabTimetablingAPI.settings")
django.setup()
from django.conf import settings
#set debug to true
settings.DEBUG = True

#logging
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %% [markdown]
# ## Data

# %% [markdown]
# Import data dari model yang telah dibuat sebelumnya.
#
# ```python

# %%
from scheduling_data.models import Laboratory, Module, Participant, Group, Assistant, Chapter

# %% [markdown]
# Ekstrak data dari model yang telah dibuat sebelumnya.
#
# ```python

# %%
class LaboratoryData:

    def __init__(self, lab = Laboratory):
        self._lab = lab
        self._laboratories = lab.objects.all()

    @property
    def laboratories(self): 
        return self._laboratories
    
    def get_assistant(self,id):
        laboratory = self._laboratories.filter(id=id).first()
        assistants = laboratory.assistants.all()
        return assistants
    
    def get_module(self,id):
        laboratory = self._laboratories.filter(id=id).first()
        modules = laboratory.modules.all()
        return modules
    
class ModuleData:

    def __init__(self, module = Module):
        self._module = module
        self._modules = module.objects.all()

    @property
    def modules(self): 
        return self._modules
    
    def get_module(self,id):
        module = self._modules.filter(id=id).first()
        return module
    
    def get_module_chapter(self, id):
        module = self.get_module(id)
        return module.chapters.all()
    
    def get_group(self, id):
        module = self.get_module(id)
        return module.groups.all()
    
    def get_laboratory(self, id):
        module = self.get_module(id)
        return module.laboratory
    
        
class ChapterData:

    def __init__(self, chapter = Chapter):
        self._chapter = chapter
        self._chapters = chapter.objects.all()

    @property
    def chapters(self): 
        return self._chapters
    
    def get_chapter(self,id):
        chapter = self._chapters.filter(id=id).first()
        return chapter
    
    def get_chapter_module(self, id):
        chapter = self.get_chapter(id)
        return chapter.module

class ParticipantData:

    def __init__(self, participant = Participant):
        self._participant = participant
        self._participants = participant.objects.all()
    
    @property
    def participants(self):
        return self._participants
    
    def group(self, id):
        group_memberships = self._participants.filter(id=id).first().group_memberships.all()
        groups = []
        for group_membership in group_memberships:
            group = group_membership.group
            groups.append(group)
        return groups
    
class GroupData:
    def __init__(self, group = Group):
        self._group = group
        self._groups = group.objects.all()

    @property
    def groups(self):
        return self._groups
    
    def get_group(self, id):
        group = self._groups.filter(id=id).first()
        return group
    
    def get_module_group(self, module_id):
        groups = self._groups.filter(module_id=module_id)
        return groups
    
    def participants(self, id):
        group = self._groups.filter(id=id).first()
        group_memberships = group.group_memberships.all()
        participants = []
        for group_membership in group_memberships:
            participant = group_membership.participant
            participants.append(participant)
        return participants
    
    def get_participant_schedule(self, id):
        participants = self.participants(id)
        participant_schedule = []
        for participant in participants:
            participant_schedule.append(participant.regular_schedule)
        return participant_schedule
    
    def get_group_schedule(self, id):
        participant_schedule = self.get_participant_schedule(id)
        if len(participant_schedule) == 0:
            return {}
        days = participant_schedule[0].keys()
        merged_schedule = {day: {} for day in days}
        for day in days:
            for time_slot in participant_schedule[0][day]:
                is_available = all(schedule[day][time_slot] for schedule in participant_schedule)
                merged_schedule[day][time_slot] = is_available
        return merged_schedule
                
            
class AssistantData:

    def __init__(self, assistant = Assistant):
        self._assistant = assistant
        self._assistants = assistant.objects.all()

    @property
    def assistants(self):
        return self._assistants

    
    def get_assistant(self, id):
        assistant = self._assistants.filter(id=id).first()
        return assistant
    
    def get_assistant_modules(self,id):
        assistant = self._assistant.filter(id=id).first()
        assistant_memberships = assistant.assistant_memberships.all()
        modules = []
        for assistant_membership in assistant_memberships:
            module = assistant_membership.module
            modules.append(module)
        return modules

# %%
group_data = GroupData().groups
group_id = [group.id for group in group_data]
len(group_id)
# Out:
# 36

# %%
# import timeit
# import cProfile
# import pstats

# group_data = GroupData()

# group_id = [group.id for group in group_data.groups]

# def get_group_schedule(group_id = group_id, group_data = group_data):
#     for id in group_id:
#         group_data.get_group_schedule(id)
#     return group_id

# pr = cProfile.Profile()
# pr.enable()
# start = timeit.default_timer()
# #do it 10000000 times
# for i in range(1000):
#     get_group_schedule()
# stop = timeit.default_timer()
# pr.disable()

# %% [markdown]
# Constants
#
# ```python

# %%
# Constant.py
class Constant:
    days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]
    shifts = ["Shift1", "Shift2", "Shift3", "Shift4", "Shift5", "Shift6"]

# %% [markdown]
# # Algoritma Genetika

# %% [markdown]
# ## Gene Representation
#
# ```python

# %%
from collections import namedtuple
TimeSlot = namedtuple("TimeSlot", ["date", "day", "shift"])

class Gene:
    def __init__(self, laboratory, module, module_chapter, group, assistant, time_slot: TimeSlot):
        self.laboratory = laboratory
        self.module = module
        self.module_chapter = module_chapter
        self.group = group
        self.assistant = assistant
        self.time_slot = time_slot
        
    def __repr__(self):
        return f"Gene(lab={self.laboratory}, module={self.module}, module_chapter={self.module_chapter}, group={self.group}, assistant={self.assistant}, time_slot={self.time_slot})"
    
    def __eq__(self, other):
        return self.laboratory == other.laboratory and self.module == other.module and self.module_chapter == other.module_chapter and self.group == other.group and self.assistant == other.assistant and self.time_slot == other.time_slot

# %% [markdown]
# Test Gene Representation
#
# ```python

# %%
# Test Gene

# Assigning data to variables
lab_data = LaboratoryData()
module_data = ModuleData()
participant_data = ParticipantData()
group_data = GroupData()
assistant_data = AssistantData()
chapter_data = ChapterData()

gene = Gene(lab_data.laboratories[0].id, module_data.modules[0].id, chapter_data.chapters[0].id, group_data.groups[0].id,assistant_data.assistants[0].id, TimeSlot("2021-01-01", "Friday", "Shift1"))
gene2 = Gene(lab_data.laboratories[0].id, module_data.modules[0].id, chapter_data.chapters[0].id, group_data.groups[1].id, assistant_data.assistants[0].id, TimeSlot("2021-01-01", "Friday", "Shift2"))
gene3 = Gene(lab_data.laboratories[0].id, module_data.modules[0].id, chapter_data.chapters[0].id, group_data.groups[2].id, assistant_data.assistants[0].id, TimeSlot("2021-01-01", "Monday", "Shift1"))

# %% [markdown]
# ### Gene Level Constraints
#
# ```python

# %%
# Constraint Class for Constraint Function
# 1. Ensure that each chapter is assigned to the correct module.
# 2. Ensure that each module is assigned to the correct lab.
# 3. Ensure that each group is assigned to the correct module.
# 4. Ensure that each assistant is assigned to the correct lab.

# import LaboratoryData, ModuleData, GroupData, AssistantData, ChapterData

class ConstraintChecker:
    def __init__(self, gene : Gene, **kwargs):
        kwargs.setdefault("lab_data", LaboratoryData())
        kwargs.setdefault("module_data", ModuleData())
        kwargs.setdefault("group_data", GroupData())
        kwargs.setdefault("assistant_data", AssistantData())
        kwargs.setdefault("chapter_data", ChapterData())
        self.gene = gene
        self.lab_data = lab_data
        self.module_data = module_data
        self.group_data = group_data
        self.assistant_data = assistant_data
        self.chapter_data = chapter_data

    def chapter_module_constraint(self):
        module = self.module_data.get_module(self.gene.module)
        chapter = self.chapter_data.get_chapter(self.gene.module_chapter)
        return module == chapter.module
    
    def module_lab_constraint(self):
        module = self.module_data.get_module(self.gene.module)
        return module.laboratory.id == self.gene.laboratory
    
    def group_module_constraint(self):
        module = self.module_data.get_module(self.gene.module)
        group = self.group_data.get_group(self.gene.group)
        return module == group.module
    
    def assistant_lab_constraint(self):
        assistant = self.assistant_data.get_assistant(self.gene.assistant)
        return assistant.laboratory.id == self.gene.laboratory
    
    def schedule_constraint(self):
        return group_data.get_group_schedule(self.gene.group)[self.gene.time_slot.day][self.gene.time_slot.shift]
    
    def check(self):
        return self.chapter_module_constraint() and self.module_lab_constraint() and self.group_module_constraint() and self.assistant_lab_constraint()

# %% [markdown]
# Test Gene Level Constraints
#
# ```python

# %%
    # Test ConstraintChecker
ConstraintChecker(gene).check()
# Out:
# True

# %% [markdown]
# ## Chromosome Representation
#
# ```python

# %%
# Chromosome.py
# Chromosome Representation
# 1. Gene
# 2. Fitness

class Chromosome:
    def __init__(self, genes: list):
        self.genes = genes
        self.fitness = None

    def __repr__(self):
        return f"Chromosome(genes={self.genes}, fitness={self.fitness})"
    
    def __str__(self):
        return f"Chromosome(genes={self.genes}, fitness={self.fitness})"
    
    def __len__(self):
        return len(self.genes)
    
    def __eq__(self, other):
        #check for each gene if it is equal
        return all(gene == other_gene for gene, other_gene in zip(self.genes, other.genes))

# %% [markdown]
# ### Chromosome Level Constraints
#
# ```python

# %% [markdown]
# Objective class
# 1. Minimize conflict: Minimize conflicts in the schedule by ensuring that no two groups are assigned to the same lab and time slot simultaneously.
# 2. Maximize Resource Utilization: Maximize the utilization of assistants by distributing tasks evenly among them. Each assistant should be assigned to a balanced number of groups and shift to avoid overloading.
# 3. Maximize Participant Satisfaction: Maximize the satisfaction of participants by ensuring that each participant is assigned to a time slot that is available to them.

# %% [markdown]
# #### Objective Class for Fitness Function
# ##### 1. Minimize Conflicts:
# Minimize conflicts in the schedule by ensuring that no two groups are assigned to the same lab and time slot simultaneously.
#
# Deskripsi:
# - Jika dua kelompok berbeda memiliki jadwal yang sama, maka akan terjadi konflik.

# %%
#minimize_conflicts.py
from collections import namedtuple

class MinimizeConflicts:
    def __init__(self):
        self.conflicts = namedtuple("Conflicts", ["time_slot", "lab"])

    def calculate_conflicts(self, chromosome: Chromosome) -> int:
        conflicts_time_slot = set()
        assigned_time_slot = set()
        conflict_count = 0
        for gene in chromosome.genes:
            if (gene.laboratory, gene.time_slot) in assigned_time_slot:
                conflicts_time_slot.add(self.conflicts(gene.time_slot, gene.laboratory))
                conflict_count += 1
            else:
                assigned_time_slot.add((gene.laboratory, gene.time_slot))
        return conflict_count

    def calculate_fitness(self, chromosome: Chromosome) -> int:
        if settings.DEBUG:
            logger.info(f"Calculating conflicted group time slots for chromosome {chromosome}")
        return self.calculate_conflicts(chromosome)

# %% [markdown]
# ##### 2. Maximize Resource Utilization:
# Maximize the utilization of assistants by distributing tasks evenly among them. Each assistant should be assigned to a balanced number of groups and shift to avoid overloading.
#
# Deskripsi:
# - Menyeimbang tugas asistent dengan memastikan bahwa setiap asisten ditugaskan ke jumlah kelompok dan shift yang seimbang untuk menghindari overloading.

# %%
from collections import defaultdict

class MaximizeResourceUtilization:
    def __init__(self, max_groups_per_assistant: int = 2, max_shift_per_assistant: int = 2):
        self.max_groups_per_assistant = max_groups_per_assistant
        self.max_shift_per_assistant = max_shift_per_assistant
        self.assistants_assignments = defaultdict(list)
        self.assistants_shifts = defaultdict(list)
        self._overload_penalty = 0


    def calculate_assistants_assignments(self, chromosome: Chromosome) -> int:
        self.assistants_assignments.clear()
        for gene in chromosome.genes:
            self.assistants_assignments[gene.assistant].append(gene.group)
        return self.assistants_assignments
    
    def calculate_assistants_shifts(self, chromosome: Chromosome) -> int:
        self.assistants_shifts.clear()
        for gene in chromosome.genes:
            self.assistants_shifts[gene.assistant].append(gene.time_slot)
        return self.assistants_shifts
    
    def calculate_overload_penalty(self, chromosome: Chromosome) -> int:
        self._overload_penalty = 0
        self.calculate_assistants_assignments(chromosome)
        self.calculate_assistants_shifts(chromosome)
        for assistant , assignments in self.assistants_assignments.items():
            assignments_penalty = max(0, len(assignments) - self.max_groups_per_assistant)
            shift_penalty = (max(0, len(self.assistants_shifts[assistant]) - self.max_shift_per_assistant))
            self._overload_penalty += assignments_penalty + shift_penalty
        return self._overload_penalty
    
    def calculate_fitness(self, chromosome: Chromosome) -> int:
        if settings.DEBUG:
            logger.info(f"Calculating overload penalty for assistant distribution: {chromosome}")
        return self.calculate_overload_penalty(chromosome)

# %% [markdown]
# ##### 3. Maximize Participant Satisfaction:
# Maximize the satisfaction of participants by ensuring that each participant is assigned to a time slot that is available to them.
#
# Deskripsi:
# - Memaksimalkan kepuasan peserta dengan memastikan bahwa setiap peserta ditugaskan ke slot waktu yang tersedia untuk mereka.
#
# ```python

# %%
from collections import defaultdict

class ParticipantAvailability:
    def __init__(self, group_data: GroupData):
        self.group_data = group_data
        self.unsatified_participants = defaultdict(list)

    def calculate_unsatisfied_participants(self, chromosome: Chromosome):
        self.unsatified_participants.clear()
        unsatified_participants_count = 0
        for gene in chromosome.genes:
            participant_availability = group_data.get_group_schedule(gene.group)
            if not participant_availability[gene.time_slot.day][gene.time_slot.shift]:
                self.unsatified_participants[gene.group].append(gene.time_slot)
                unsatified_participants_count += 1
        return unsatified_participants_count
    
    def calculate_fitness(self, chromosome: Chromosome):
        if settings.DEBUG:
            logger.info(f"Calculating unsatisfied participants schedule for chromosome {chromosome}")
        return self.calculate_unsatisfied_participants(chromosome)

# %% [markdown]
# # Population Initialization

# %%
# import fitness_function

class Population:
    def __init__(self, chromosome, fitness_function):
        self.chromosome = chromosome
        self.fitness_function = fitness_function

    def __repr__(self):
        return f"Chromosome: {self.chromosome}, Fitness Function: {self.fitness_function}"
    
    def __str__(self):
        return f"Chromosome: {self.chromosome}, Fitness Function: {self.fitness_function}"
    
    def __len__(self):
        return len(self.chromosome)
    
    def calculate_fitness(self):
        for chromosome in self.chromosome:
            chromosome.fitness = self.fitness_function.calculate_fitness(chromosome)

# %% [markdown]
# # Helper Functions

# %% [markdown]
# ## Factory Method
#
# ```python

# %%
# Factory.py
import numpy as np
from math import ceil
from collections import namedtuple
from datetime import timedelta
# import LaboratoryData, ModuleData, GroupData, AssistantData, ChapterData
# import Constant, ConstraintChecker, Gene, Chromosome, Population

class Factory:
    def __init__(self, **kwargs):
        
        self.lab_data = kwargs.get("lab_data", LaboratoryData())
        self.module_data = kwargs.get("module_data", ModuleData())
        self.group_data = kwargs.get("group_data", GroupData())
        self.assistant_data = kwargs.get("assistant_data", AssistantData())
        self.chapter_data = kwargs.get("chapter_data", ChapterData())
        self.initialize()

    def initialize(self):
        # Caching data for faster access and less database query
        self.assistant_by_lab = defaultdict(list)
        for assistant in self.assistant_data.assistants:
            self.assistant_by_lab[assistant.laboratory.id].append(assistant.id)
            
        self.module_by_lab = defaultdict(list)
        for module in self.module_data.modules:
            self.module_by_lab[module.laboratory.id].append(module.id)

        self.group_by_module = defaultdict(list)
        for group in self.group_data.groups:
            self.group_by_module[group.module.id].append(group.id)

        self.chapter_by_module = defaultdict(list)
        for chapter in self.chapter_data.chapters:
            self.chapter_by_module[chapter.module.id].append(chapter.id)
            
        self.participant_by_group = defaultdict(list)
        for group in self.group_data.groups:
            for participant in self.group_data.participants(group.id):
                self.participant_by_group[group.id].append(participant.id)

    def create_time_slot(self, module_id):
        start = self.module_data.get_module(module_id).start_date
        end = self.module_data.get_module(module_id).end_date
        duration = (end - start).days + 1
        weeks_duration = ceil(duration / 7)
        week = np.random.randint(0, weeks_duration)
        day = np.random.choice(Constant.days)
        shift = np.random.choice(Constant.shifts)
        date = start + timedelta(days=week*7 + Constant.days.index(day))
        #date = start + timedelta(days=7 + Constant.days.index(day))
        return TimeSlot(date, day, shift)
    
    def create_time_slot_weekly(self, module_id, week):
        start = self.module_data.get_module(module_id).start_date
        day = np.random.choice(Constant.days)
        shift = np.random.choice(Constant.shifts)
        date = start + timedelta(days=week*7 + Constant.days.index(day))
        return TimeSlot(date, day, shift)

    # def generate_gene(self):
    #     while True:
    #         laboratory = np.random.choice(self.lab_data.laboratories)["id"]
    #         module = np.random.choice(self.lab_data.get_module(laboratory))["id"]
    #         module_chapter = np.random.choice(self.module_data.get_module_chapter(module))["id"]
    #         group = np.random.choice(self.module_data.get_group(module))["id"]
    #         assistant = np.random.choice(self.lab_data.get_assistant(laboratory))["id"]

    #         time_slot = self.create_time_slot(module_id=module)

    #         gene = Gene(laboratory, module, module_chapter, group, assistant, time_slot)
    #         constraint_checker = ConstraintChecker(gene)
    #         if constraint_checker.check():
    #             return gene

    def calculate_chromosome_length(self):
        chromosome_size = 0
        for module in self.module_data.modules:
            module_chapter_count = self.module_data.get_module_chapter(module.id).count()
            group_count = self.module_data.get_group(module.id).count()
            chromosome_size += module_chapter_count * group_count
        return chromosome_size
    
    def generate_chromosome(self):
        # if settings.DEBUG:
        #     logger.info("Generating chromosome...")
        genes = []
        for group in self.group_data.groups:
            for module in self.module_data.modules:
                if group.module.id == module.id:
                    # # Start of weekly chapter generation
                    # # Get weekly chapter duration
                    # start = module.start_date
                    # end = module.end_date
                    # duration = (end - start).days + 1
                    # weeks_duration = ceil(duration / 7)
                    # chapter_count = module.chapters.count()
                    # weekly_chapter_count = ceil(chapter_count / weeks_duration)
                    # # Generate weekly chapter
                    # for id in range(weekly_chapter_count):
                    #     laboratory_id = module.laboratory.id
                    #     module_id = module.id
                    #     module_chapter_id = id+1
                    #     group_id = group.id
                    #     assistant_id = np.random.choice(self.assistant_by_lab[laboratory_id])
                    #     time_slot = self.create_time_slot(module_id)
                    #     gene = Gene(laboratory_id, module_id, module_chapter_id, group_id, assistant_id, time_slot)
                    #     genes.append(gene)
                    # # End of weekly chapter generation

                    for chapter in module.chapters.all():
                        laboratory_id = module.laboratory.id
                        module_id = module.id
                        module_chapter_id = chapter.id
                        group_id = group.id
                        assistant_id = np.random.choice(self.assistant_by_lab[laboratory_id])
                        time_slot = self.create_time_slot(module_id)
                        gene = Gene(laboratory_id, module_id, module_chapter_id, group_id, assistant_id, time_slot)
                        genes.append(gene)

        chromosome = Chromosome(genes)
        return chromosome
            

    def generate_population(self, population_size):
        if settings.DEBUG:
            logger.info("Generating population...")
        chromosome = []
        for _ in range(population_size):
            if settings.DEBUG:
                logger.info(f"Generating chromosome {_+1}/{population_size}")
            chromosome.append(self.generate_chromosome())
        return Population(chromosome, None)

# %% [markdown]
# Test Factory

# %%
# #test Factory
factory = Factory()
settings.DEBUG = False
population = factory.generate_population(5)

# %%
# #count courses for each group
# def count_courses(population):
#     group_courses = defaultdict(list)
#     for chromosome in population.chromosome:
#         for gene in chromosome.genes:
#             group_courses[gene.group].append(gene.module_chapter)
#     return group_courses

# %%
# group_courses = count_courses(population)
# group_courses

# %%
# # test constraint checker
# # timer
# import time
# for chromosome in population.chromosome:
#     for gene in chromosome.genes:
#         constraint_checker = ConstraintChecker(gene)
#         start = time.time()
#         if not constraint_checker.check():
#             print(gene)
#             print(constraint_checker.check())
#         end = time.time()
#         print(f"Time taken for constraint checking: {end-start}")

# %% [markdown]
# ## Fitness Function
#
# ```python

# %%
class FitnessFunction:
    def __init__(self, all: bool = True):
        self.minimize_conflicts = None
        self.maximize_resource_utilization = None
        self.participant_availability = None
        self.all = all

        # MaximizeResourceUtilization Parameters
        self.max_groups_per_assistant = 2
        self.max_shift_per_assistant = 16

    def initialize(self):
        self.minimize_conflicts = MinimizeConflicts()
        self.maximize_resource_utilization = MaximizeResourceUtilization(self.max_groups_per_assistant, self.max_shift_per_assistant)
        self.participant_availability = ParticipantAvailability(GroupData())
    
    def calculate_all_fitness(self, chromosome: Chromosome):
        fitness = []
        fitness.append(self.minimize_conflicts.calculate_fitness(chromosome))
        fitness.append(self.maximize_resource_utilization.calculate_fitness(chromosome))
        fitness.append(self.participant_availability.calculate_fitness(chromosome))
        return sum(fitness)

    
    def calculate_fitness(self, chromosome: Chromosome):
        if settings.DEBUG:
            logger.info(f"Calculating fitness for chromosome {chromosome}")
        fitness = self.calculate_all_fitness(chromosome)
        return fitness

# %% [markdown]
# Test Fitness Function

# %%
# #test FitnessFunction
# factory = Factory()
# population = factory.generate_population(10)
# fitness_function = FitnessFunction()
# population.fitness_function = fitness_function
# fitness_function.initialize()

# %%
# population.calculate_fitness()

# %%
# for chromosome in population.chromosome:
#     print(chromosome.fitness)

# %% [markdown]
# ## Operator
#
# ```python

# %% [markdown]
# ### Genetic Operators
#
# ```python

# %% [markdown]
# #### Mutation
#
# ```python

# %%
from copy import deepcopy
from random import random, randint, choice
# import Factory, Chromosome, FitnessFunction

class Mutation:
    def __init__(self, mutation_rate: float = 0.1, mutation_size: int = 1, factory: Factory = Factory()):
        self.mutation_rate = mutation_rate
        self.mutation_size = mutation_size
        self.factory = factory


    def mutate(self, parent: Chromosome) -> Chromosome:
        if settings.DEBUG:
            logger.info("Mutating...")
        if random() < self.mutation_rate:
            chromosome = deepcopy(parent)
            for _ in range(self.mutation_size):
                mutation_point = self.mutation_point(parent)
                chromosome.genes[mutation_point].time_slot = self.factory.create_time_slot(chromosome.genes[mutation_point].module)
                chromosome.genes[mutation_point].assistant = choice(self.factory.assistant_by_lab[chromosome.genes[mutation_point].laboratory])
                if settings.DEBUG:
                    logger.info(f"Mutated chromosome: {chromosome}")
            return chromosome
        else:
            if settings.DEBUG:
                logger.info(f"Chromosome not mutated: {parent}")
            return parent
        
    def mutation_point(self, parent: Chromosome) -> int:
        return randint(0, len(parent.genes) - 1)

# %% [markdown]
# Test Mutation

# %%
# #test Mutation
# factory = Factory()
# population = factory.generate_population(1)
# fitness_function = FitnessFunction()
# population.fitness_function = fitness_function
# population.calculate_fitness()

# %%
# mutation = Mutation()
# mutation.mutate(population.chromosome[0])

# %% [markdown]
# #### Cross Over
#
# ```python

# %%
import logging
from copy import deepcopy
import numpy as np
class Crossover:
    def __init__(self, crossover_probability: float = 0.5, number_of_crossover_points: int = 1):

        self.crossover_probability = crossover_probability
        self.number_of_crossover_points = number_of_crossover_points
        

    def crossover(self, parent1: Chromosome, parent2: Chromosome) -> Chromosome:
        if settings.DEBUG:
            logger.info("Crossover...")

        if np.random.random() > self.crossover_probability:
            if settings.DEBUG:
                logger.info("No crossover")
            return parent1, parent2

        chromosome1 = deepcopy(parent1)
        chromosome2 = deepcopy(parent2)

        for _ in range(self.number_of_crossover_points):
            point = self.crossover_point(parent1)
            if settings.DEBUG:
                logger.info(f"Crossover point: {point}")
            chromosome1.genes[point], chromosome2.genes[point] = chromosome2.genes[point], chromosome1.genes[point] 
            if settings.DEBUG:
                logger.info(f"Chromosome 1: {chromosome1}")
                logger.info(f"Chromosome 2: {chromosome2}")


        return chromosome1, chromosome2
    
    def crossover_point(self, parent1: Chromosome):
        return np.random.randint(0, len(parent1.genes) - 1)

# %% [markdown]
# Test Cross Over

# %%
# #test Crossover
# factory = Factory()
# population = factory.generate_population(2)

# %%
# crossover = Crossover()
# a,b = crossover.crossover(population.chromosome[0], population.chromosome[1])

# %%
# import pandas as pd
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# # display population.chromosome[0].genes[0] on pandas dataframe
# data = []
# gene = population.chromosome[0].genes[158]
# data.append([gene.laboratory, gene.module, gene.module_chapter, gene.group, gene.assistant, gene.time_slot.date, gene.time_slot.day, gene.time_slot.shift])
# df = pd.DataFrame(data, columns=["Laboratory", "Module", "Module Chapter", "Group", "Assistant", "Date", "Day", "Shift"])
# df

# %%
# data2 = []
# gene2 = population.chromosome[1].genes[158]
# data2.append([gene2.laboratory, gene2.module, gene2.module_chapter, gene2.group, gene2.assistant, gene2.time_slot.date, gene2.time_slot.day, gene2.time_slot.shift])
# df2 = pd.DataFrame(data2, columns=["Laboratory", "Module", "Module Chapter", "Group", "Assistant", "Date", "Day", "Shift"])
# df2

# %%
# data3 = []
# gene3 = a.genes[158]
# data3.append([gene3.laboratory, gene3.module, gene3.module_chapter, gene3.group, gene3.assistant, gene3.time_slot.date, gene3.time_slot.day, gene3.time_slot.shift])
# df3 = pd.DataFrame(data3, columns=["Laboratory", "Module", "Module Chapter", "Group", "Assistant", "Date", "Day", "Shift"])
# df3

# %%
# data4 = []
# gene4 = b.genes[158]
# data4.append([gene4.laboratory, gene4.module, gene4.module_chapter, gene4.group, gene4.assistant, gene4.time_slot.date, gene4.time_slot.day, gene4.time_slot.shift])
# df4 = pd.DataFrame(data4, columns=["Laboratory", "Module", "Module Chapter", "Group", "Assistant", "Date", "Day", "Shift"])
# df4

# %% [markdown]
# #### Repair
#
# ```python

# %%
import time
class Repair:
    def __init__(self, factory: Factory = Factory()):
        self.factory = factory
        
    def repair(self, parent: Chromosome, max_iteration=100) -> Chromosome:
        if settings.DEBUG:
            logger.info("Repairing...")
            # count = 0
            # start = time.time()
        chromosome = deepcopy(parent)
        for index, gene in enumerate(chromosome.genes):
            constraint_checker = ConstraintChecker(gene)
            if not constraint_checker.schedule_constraint():
                # if settings.DEBUG:
                #     logger.info(f"Gene {index} is not feasible, repairing...")
                feasible_time_slot = self.find_feasible_solution(gene, max_iteration)
                gene.time_slot = feasible_time_slot
                # if settings.DEBUG:
                #     logger.info(f"Feasible time slot: {gene.time_slot}")
                #     count += 1
        # if settings.DEBUG:
        #     end = time.time()
        #     logger.info(f"Repaired {count} genes in {end-start} seconds")
        return chromosome
    
    def find_feasible_solution(self, gene, max_iteration=100):
        # if settings.DEBUG:
        #     logger.info("Finding feasible solution...")

        new_gene = deepcopy(gene)
        for _ in range(max_iteration):
            feasible_time_slot = self.factory.create_time_slot(gene.module)
            new_gene.time_slot = feasible_time_slot
            constraint_checker = ConstraintChecker(new_gene)
            if constraint_checker.schedule_constraint():
                # if settings.DEBUG:
                #     logger.info("Found!")
                return feasible_time_slot
            
        if settings.DEBUG:
            logger.info("No feasible solution found, returning random time slot")
        return self.factory.create_time_slot(gene.module)

# %% [markdown]
# Test Repair

# %%
# #test Repair
# factory = Factory()
# population = factory.generate_population(1)
# repair = Repair()
# z = repair.repair(population.chromosome[0])

# %%
# counter = 0
# for gene in z.genes:
#     constraint_checker = ConstraintChecker(gene)
#     if not constraint_checker.schedule_constraint():
#         print("not feasible")
#         counter += 1
# print(counter)

# %% [markdown]
# #### Selection
#
# ```python

# %%
import numpy as np
from copy import deepcopy
from collections import defaultdict

class Selection:
    '''
    Description:
    Selection class for selecting chromosomes from population
    Selection methods:
    1. Tournament selection
    2. Elitism selection
    3. Roulette selection
    '''
    def __init__(self, tournament_size: int = 3, elitism_size: int = 1, elitism_offset: int = 0, elitism_range: int = 1, elitism_probability: float = 0.5, method: str = "tournament"):
        self.tournament_size = tournament_size
        self.elitism_size = elitism_size
        self.elitism_offset = elitism_offset
        self.elitism_range = elitism_range
        self.elitism_probability = elitism_probability
        self.method = method
        
    def select(self, population: Population, method: str = None, **kwargs) -> Chromosome:
        method = method or self.method
        if settings.DEBUG:
            logger.info("Selecting...")
        if method == "tournament":
            return self.tournament_selection(population)
        elif method == "elitism":
            return self.elitism_selection(population)
        elif method == "roulette":
            return self.roulette_selection(population)
        else:
            raise ValueError("Invalid selection method")
    
    def elitism_selection(self, population: Population) -> Chromosome:
        if settings.DEBUG:
            logger.info("Elitism selection...")
        sorted_population = sorted(population.chromosome, key=lambda x: x.fitness)
        return sorted_population[self.elitism_offset:self.elitism_offset + self.elitism_range]
    
    def tournament_selection(self, population: Population) -> Chromosome:
        if settings.DEBUG:
            logger.info("Tournament selection...")
        selected_chromosome = []
        for _ in range(len(population.chromosome)):
            selected_chromosome.append(self.tournament_selection_helper(population))
        return selected_chromosome[0]
    
    def tournament_selection_helper(self, population: Population) -> Chromosome:
        tournament_population = np.random.choice(population.chromosome, self.tournament_size)
        sorted_population = sorted(tournament_population, key=lambda x: x.fitness)
        return sorted_population[0]
    
    def roulette_selection(self, population: Population) -> Chromosome:
        if settings.DEBUG:
            logger.info("Roulette selection...")
        fitness = [chromosome.fitness for chromosome in population.chromosome]
        total_fitness = sum(fitness)
        probabilities = [chromosome_fitness / total_fitness for chromosome_fitness in fitness]
        selected_chromosome = np.random.choice(population.chromosome, p=probabilities)
        return selected_chromosome

# %%
# # test Selection,
# factory = Factory()
# population = factory.generate_population(10)
# fitness_function = FitnessFunction()
# population.fitness_function = fitness_function
# population.calculate_fitness()

# %%
# for chromosome in population.chromosome:
#     print(chromosome.fitness)

# %% [markdown]
# Test Selection

# %%
# selection = Selection(method="elitism", elitism_offset=0, elitism_range=5, elitism_probability=0.5)
# a = selection.select(population)

# %%
# for chromosome in a:
#     print(chromosome.fitness)

# %%
#test Selection
# factory = Factory()
# population = factory.generate_population(2)
# population.chromosome[0].genes
# population.chromosome[1].genes
# selection = Selection(population, method="roulette")
# a = selection.select()

# %% [markdown]
# ### Genetic Algorithm
#
# ```python

# %%
from math import log


class GeneticAlgorithm:
    '''
    Description:
    Main class for genetic algorithm implementation
    '''
    def __init__(self, builder):
        # Dependency injection
        self.builder = builder
        self.population_size, self.max_generation = self.builder.get_population_parameters()
        self.mutation_rate, self.mutation_size = self.builder.get_mutations_parameters()
        self.crossover_probability, self.number_of_crossover_points = self.builder.get_crossover_parameters()
        self.fitness_function = self.builder.fitness_function
        self.factory = self.builder.factory
        self.mutation = self.builder.mutation
        self.crossover = self.builder.crossover
        self.selection = self.builder.selection
        self.repair = self.builder.repair
        self.logging = self.builder.logging
        # Results
        self._results = defaultdict(list)
        self._best_chromosome = None
        self._best_fitness = None
        self._best_generation = None
        self._best_chromosome_history = []
        self._best_fitness_history = []

    def show_config(self):
        if settings.DEBUG:
            logger.info("Showing configuration...")
        print(f"Population size: {self.population_size}")
        print(f"Max generation: {self.max_generation}")
        print(f"Mutation rate: {self.mutation_rate}")
        print(f"Mutation size: {self.mutation_size}")
        print(f"Crossover probability: {self.crossover_probability}")
        print(f"Number of crossover points: {self.number_of_crossover_points}")
        print(f"Fitness function: {self.fitness_function}")
        print(f"Logging: {self.logging}")
        return self

    def initialize_population(self):
        self.show_config()
        if settings.DEBUG:
            logger.info("Initializing population...")
        population = self.factory.generate_population(self.population_size)
        population.fitness_function = self.fitness_function
        population.calculate_fitness()
        return population
    
    def loggings(self, population):
        if settings.DEBUG:
            logger.info("Logging...")
        self._results["best_chromosome"].append(population.chromosome[0])
        self._results["best_fitness"].append(population.chromosome[0].fitness)
        self._results["average_fitness"].append(sum([chromosome.fitness for chromosome in population.chromosome]) / len(population.chromosome))
        self._results["worst_fitness"].append(population.chromosome[-1].fitness)
        self._best_chromosome_history.append(population.chromosome[0])
        self._best_fitness_history.append(population.chromosome[0].fitness)
        return self
    
    def evolve(self, population):
        if settings.DEBUG:
            logger.info("Evolving...")
        new_population = Population([], None)

        # Choose the best chromosome from the previous generation
        new_population.chromosome.extend(self.selection.select(population, method="elitism"))
        while len(new_population.chromosome) < self.population_size:
            parent1 = self.selection.select(population)
            parent2 = self.selection.select(population)
            child1, child2 = self.crossover.crossover(parent1, parent2)
            child1 = self.mutation.mutate(child1)
            child2 = self.mutation.mutate(child2)
            child2 = self.repair.repair(child2)
            child1 = self.repair.repair(child1)
            new_population.chromosome.extend([child1, child2])
        new_population.fitness_function = self.fitness_function
        new_population.calculate_fitness()
        if self.logging:
            self.loggings(new_population)

        return new_population
        

    def run(self):
        #if settings.DEBUG:
        logger.info("Running...")
        population = self.initialize_population()
        if self.logging:
            self.loggings(population)
        for generation in range(self.max_generation):
            #if settings.DEBUG:
            logger.info(f"Generation {generation}")
            start = time.time()
            population = self.evolve(population)
            logger.info(f"Population length: {len(population)}") 
            end = time.time()
            logger.info(f"Time taken for generation {generation}: {end-start}")
            if self.logging:
                self.loggings(population)
                logger.info(f"Best fitness: {self._results['best_fitness'][-1]}")
        self._best_chromosome = self._results["best_chromosome"][-1]
        self._best_fitness = self._results["best_fitness"][-1]
        self._best_generation = self._best_fitness_history.index(self._best_fitness)
        return self
    
    def get_results(self):
        return self._results
    
    def get_best_chromosome(self):
        return self._best_chromosome
    
    def get_best_fitness(self):
        return self._best_fitness
    
    def get_best_generation(self):
        return self._best_generation
    
    def get_best_chromosome_history(self):
        return self._best_chromosome_history
    
    def get_best_fitness_history(self):
        return self._best_fitness_history

# %% [markdown]
# #### Builder

# %%
from collections import defaultdict, namedtuple

class GeneticAlgorithmBuilder:
    '''
    Description:
    Genetic Algorithm Builder class for managing genetic algorithm parameters.
    '''
    def __init__(self):
        # Population parameters
        self.population_size = None
        self.max_generation = 10
        # Mutation parameters
        self.mutation_rate = 0.5
        self.mutation_size = 1
        # Crossover parameters
        self.crossover_probability = 0.5
        self.number_of_crossover_points = 1
        self.crossover = Crossover()
        # Selection parameters
        self.tournament_size = 3
        self.elitism_size = 1
        self.elitism_offset = 0
        self.elitism_range = 1
        self.elitism_probability = 0.5
        self.selection_method = "tournament"
        # Dependency injection
        # Fitness function
        self.fitness_function = FitnessFunction()
        # Factory
        self.factory = Factory()
        # Mutation
        self.mutation = Mutation()
        # Selection
        self.selection = Selection()
        # Repair
        self.repair = Repair()
        # Logging
        self.logging = False
        # Data
        self._lab_data = LaboratoryData()
        self._module_data = ModuleData()
        self._group_data = GroupData()
        self._assistant_data = AssistantData()
        self._chapter_data = ChapterData()

    
    
    def set_mutations_class(self, mutation):
        self.mutation = mutation
        return self

    def set_mutations(self, mutation_rate, mutation_size):
        """
        Set mutation parameters
        :param mutation_rate: Mutation rate, probability of mutation
        :type mutation_rate: float
        :param mutation_size: Number of genes to mutate
        :type mutation_size: int
        :return: self
        """
        self.mutation_rate = mutation_rate
        self.mutation_size = mutation_size
        return self
    
    def get_mutations_parameters(self):
        return self.mutation_rate, self.mutation_size
    
    def set_crossover_class(self, crossover):
        self.crossover = crossover
        return self
    
    def set_crossover(self, crossover_probability, number_of_crossover_points):
        """
        Set crossover parameters
        :param crossover_probability: Probability of crossover
        :type crossover_probability: float
        :param number_of_crossover_points: Number of points to crossover
        :type number_of_crossover_points: int
        :return: self"""

        self.crossover_probability = crossover_probability
        self.number_of_crossover_points = number_of_crossover_points
        return self
    
    def get_crossover_parameters(self):
        return self.crossover_probability, self.number_of_crossover_points
    
    def set_selection_class(self, selection):
        self.selection = selection
        return self
    
    def set_selection(self, selection_method, **kwargs):

        """
        Set selection parameters
        :param selection_method: Selection method, "tournament", "elitism" or "roulette"
        :type selection_method: str
        :param kwargs: Selection parameters, tournament_size, elitism_size, elitism_offset, elitism_range, elitism_probability
        :type kwargs: dict
        :param tournament_size: Number of chromosomes to select for tournament selection
        :type tournament_size: int
        :param elitism_size: Number of chromosomes to select for elitism selection
        :type elitism_size: int
        :param elitism_offset: Offset for elitism selection, position of the first chromosome to select
        :type elitism_offset: int
        :param elitism_range: Range for elitism selection, number of chromosomes to select from the offset
        :type elitism_range: int
        :param elitism_probability: Probability of selecting from the elitism selection
        :type elitism_probability: float
        :return: self
        """
        

        self.selection_method = selection_method
        if selection_method == "tournament":
            self.tournament_size = kwargs.get("tournament_size", 3)
        elif selection_method == "elitism":
            self.elitism_size = kwargs.get("elitism_size", 1)
            self.elitism_offset = kwargs.get("elitism_offset", 0)
            self.elitism_range = kwargs.get("elitism_range", 1)
            self.elitism_probability = kwargs.get("elitism_probability", 0.5)
        elif selection_method == "roulette":
            pass
        else:
            raise ValueError("Invalid selection method.")
        return self
    
    def get_selection_parameters(self):
        return self.tournament_size, self.elitism_size, self.elitism_offset, self.elitism_range, self.elitism_probability
    
    def set_population_parameters(self, population_size, max_generation):
        """
        Set population parameters
        :param population_size: Population size
        :type population_size: int
        :param max_generation: Maximum number of generation
        :type max_generation: int
        :return: self
        """
        self.population_size = population_size
        self.max_generation = max_generation
        return self
    
    def get_population_parameters(self):
        return self.population_size, self.max_generation
    
    def set_lab_data(self, lab_data: LaboratoryData):
        self._lab_data = lab_data
        return self
    
    def set_module_data(self, module_data: ModuleData):
        self._module_data = module_data
        return self
    
    def set_group_data(self, group_data: GroupData):
        self._group_data = group_data
        return self
    
    def set_assistant_data(self, assistant_data: AssistantData):
        self._assistant_data = assistant_data
        return self
    
    def set_chapter_data(self, chapter_data: ChapterData):
        self._chapter_data = chapter_data
        return self
    
    def initialize(self):
        self.mutation = Mutation(mutation_rate=self.mutation_rate, mutation_size=self.mutation_size, factory=self.factory)
        self.crossover = Crossover(crossover_probability=self.crossover_probability, number_of_crossover_points=self.number_of_crossover_points)
        self.selection = Selection(tournament_size=self.tournament_size, elitism_size=self.elitism_size, elitism_offset=self.elitism_offset, elitism_range=self.elitism_range, elitism_probability=self.elitism_probability, method = self.selection_method)
        self.repair = Repair(factory=self.factory)
        self.fitness_function.initialize()
        return self
    
    def build(self):
        """
        Build genetic algorithm
        :return: GeneticAlgorithm
        """
        self.initialize()
        return GeneticAlgorithm(self)

# %% [markdown]
# Test Genetic Algorithm

# %%
#test GeneticAlgorithm
builder = GeneticAlgorithmBuilder()
builder.set_population_parameters(population_size=25,
                                  max_generation=500)
builder.set_mutations(mutation_rate=0.7,
                      mutation_size=1)
builder.set_crossover(crossover_probability=0.7,
                      number_of_crossover_points=1)
builder.set_selection(selection_method="tournament",
                        tournament_size=3)

builder.fitness_function = FitnessFunction()
builder.fitness_function.max_groups_per_assistant = 15
builder.fitness_function.max_shift_per_assistant = 15
builder.logging = False
algorithm = builder.build()

# %%
import cProfile
settings.DEBUG = False
cp = cProfile.Profile()
cp.enable()
algorithm.run()
cp.disable()
# Out:
# INFO:__main__:Running...
# Population size: 25
# Max generation: 500
# Mutation rate: 0.7
# Mutation size: 1
# Crossover probability: 0.7
# Number of crossover points: 1
# Fitness function: <__main__.FitnessFunction object at 0x000001AC3734D660>
# Logging: False
# INFO:__main__:Generation 0
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 0: 190.9403555393219
# INFO:__main__:Generation 1
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 1: 73.38453602790833
# INFO:__main__:Generation 2
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 2: 72.87698554992676
# INFO:__main__:Generation 3
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 3: 74.07512044906616
# INFO:__main__:Generation 4
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 4: 72.33203458786011
# INFO:__main__:Generation 5
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 5: 72.0943853855133
# INFO:__main__:Generation 6
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 6: 73.28549671173096
# INFO:__main__:Generation 7
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 7: 72.07914328575134
# INFO:__main__:Generation 8
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 8: 79.78312540054321
# INFO:__main__:Generation 9
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 9: 74.22971844673157
# INFO:__main__:Generation 10
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 10: 78.46069598197937
# INFO:__main__:Generation 11
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 11: 77.84496903419495
# INFO:__main__:Generation 12
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 12: 82.39330911636353
# INFO:__main__:Generation 13
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 13: 78.92374920845032
# INFO:__main__:Generation 14
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 14: 74.79323863983154
# INFO:__main__:Generation 15
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 15: 77.26197361946106
# INFO:__main__:Generation 16
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 16: 99.21221661567688
# INFO:__main__:Generation 17
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 17: 85.69784760475159
# INFO:__main__:Generation 18
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 18: 157.64244556427002
# INFO:__main__:Generation 19
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 19: 85.61775231361389
# INFO:__main__:Generation 20
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 20: 75.54562854766846
# INFO:__main__:Generation 21
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 21: 76.12915062904358
# INFO:__main__:Generation 22
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 22: 75.22328090667725
# INFO:__main__:Generation 23
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 23: 122.05379629135132
# INFO:__main__:Generation 24
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 24: 154.06892681121826
# INFO:__main__:Generation 25
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 25: 126.83090400695801
# INFO:__main__:Generation 26
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 26: 68.99050641059875
# INFO:__main__:Generation 27
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 27: 67.55810570716858
# INFO:__main__:Generation 28
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 28: 70.48361086845398
# INFO:__main__:Generation 29
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 29: 69.94725179672241
# INFO:__main__:Generation 30
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 30: 69.27939319610596
# INFO:__main__:Generation 31
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 31: 69.3052134513855
# INFO:__main__:Generation 32
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 32: 67.95759916305542
# INFO:__main__:Generation 33
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 33: 70.40892767906189
# INFO:__main__:Generation 34
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 34: 72.76260423660278
# INFO:__main__:Generation 35
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 35: 72.68939661979675
# INFO:__main__:Generation 36
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 36: 72.27991819381714
# INFO:__main__:Generation 37
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 37: 72.2706208229065
# INFO:__main__:Generation 38
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 38: 73.95376920700073
# INFO:__main__:Generation 39
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 39: 71.524405002594
# INFO:__main__:Generation 40
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 40: 72.09941506385803
# INFO:__main__:Generation 41
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 41: 71.04746270179749
# INFO:__main__:Generation 42
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 42: 74.08585834503174
# INFO:__main__:Generation 43
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 43: 72.08337616920471
# INFO:__main__:Generation 44
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 44: 71.07788038253784
# INFO:__main__:Generation 45
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 45: 71.49757313728333
# INFO:__main__:Generation 46
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 46: 70.84063196182251
# INFO:__main__:Generation 47
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 47: 70.2208960056305
# INFO:__main__:Generation 48
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 48: 71.83012890815735
# INFO:__main__:Generation 49
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 49: 70.97263169288635
# INFO:__main__:Generation 50
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 50: 70.70267343521118
# INFO:__main__:Generation 51
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 51: 71.0056962966919
# INFO:__main__:Generation 52
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 52: 69.91454029083252
# INFO:__main__:Generation 53
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 53: 70.21104383468628
# INFO:__main__:Generation 54
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 54: 71.0965347290039
# INFO:__main__:Generation 55
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 55: 80.57901644706726
# INFO:__main__:Generation 56
# INFO:__main__:Population length: 25
# INFO:__main__:Time taken for generation 56: 71.36995506286621
# INFO:__main__:Generation 57
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hdiop\mambaforge\envs\jte-lab-timetabling\lib\site-packages\django\db\models\fields\related_descriptors.py:218, in ForwardManyToOneDescriptor.__get__(self, instance, cls)
#     217 try:
# --> 218     rel_obj = self.field.get_cached_value(instance)
#     219 except KeyError:
#
# File c:\Users\hdiop\mambaforge\envs\jte-lab-timetabling\lib\site-packages\django\db\models\fields\mixins.py:15, in FieldCacheMixin.get_cached_value(self, instance, default)
#      14 try:
# ---> 15     return instance._state.fields_cache[cache_name]
#      16 except KeyError:
#
# KeyError: 'participant'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[70], line 5
#       3 cp = cProfile.Profile()
#       4 cp.enable()
# ----> 5 algorithm.run()
#       6 cp.disable()
#
# Cell In[67], line 97, in GeneticAlgorithm.run(self)
#      95 logger.info(f"Generation {generation}")
#      96 start = time.time()
# ---> 97 population = self.evolve(population)
#      98 logger.info(f"Population length: {len(population)}")
#      99 end = time.time()
#
# Cell In[67], line 80, in GeneticAlgorithm.evolve(self, population)
#      78     new_population.chromosome.extend([child1, child2])
#      79 new_population.fitness_function = self.fitness_function
# ---> 80 new_population.calculate_fitness()
#      81 if self.logging:
#      82     self.loggings(new_population)
#
# Cell In[38], line 19, in Population.calculate_fitness(self)
#      17 def calculate_fitness(self):
#      18     for chromosome in self.chromosome:
# ---> 19         chromosome.fitness = self.fitness_function.calculate_fitness(chromosome)
#
# Cell In[44], line 28, in FitnessFunction.calculate_fitness(self, chromosome)
#      26 if settings.DEBUG:
#      27     logger.info(f"Calculating fitness for chromosome {chromosome}")
# ---> 28 fitness = self.calculate_all_fitness(chromosome)
#      29 return fitness
#
# Cell In[44], line 21, in FitnessFunction.calculate_all_fitness(self, chromosome)
#      19 fitness.append(self.minimize_conflicts.calculate_fitness(chromosome))
#      20 fitness.append(self.maximize_resource_utilization.calculate_fitness(chromosome))
# ---> 21 fitness.append(self.participant_availability.calculate_fitness(chromosome))
#      22 return sum(fitness)
#
# Cell In[37], line 21, in ParticipantAvailability.calculate_fitness(self, chromosome)
#      19 if settings.DEBUG:
#      20     logger.info(f"Calculating unsatisfied participants schedule for chromosome {chromosome}")
# ---> 21 return self.calculate_unsatisfied_participants(chromosome)
#
# Cell In[37], line 12, in ParticipantAvailability.calculate_unsatisfied_participants(self, chromosome)
#      10 unsatified_participants_count = 0
#      11 for gene in chromosome.genes:
# ---> 12     participant_availability = group_data.get_group_schedule(gene.group)
#      13     if not participant_availability[gene.time_slot.day][gene.time_slot.shift]:
#      14         self.unsatified_participants[gene.group].append(gene.time_slot)
#
# Cell In[26], line 118, in GroupData.get_group_schedule(self, id)
#     117 def get_group_schedule(self, id):
# --> 118     participant_schedule = self.get_participant_schedule(id)
#     119     if len(participant_schedule) == 0:
#     120         return {}
#
# Cell In[26], line 111, in GroupData.get_participant_schedule(self, id)
#     110 def get_participant_schedule(self, id):
# --> 111     participants = self.participants(id)
#     112     participant_schedule = []
#     113     for participant in participants:
#
# Cell In[26], line 106, in GroupData.participants(self, id)
#     104 participants = []
#     105 for group_membership in group_memberships:
# --> 106     participant = group_membership.participant
#     107     participants.append(participant)
#     108 return participants
#
# File c:\Users\hdiop\mambaforge\envs\jte-lab-timetabling\lib\site-packages\django\db\models\fields\related_descriptors.py:236, in ForwardManyToOneDescriptor.__get__(self, instance, cls)
#     234     rel_obj = None
#     235 if rel_obj is None and has_value:
# --> 236     rel_obj = self.get_object(instance)
#     237     remote_field = self.field.remote_field
#     238     # If this is a one-to-one relation, set the reverse accessor
#     239     # cache on the related object to the current instance to avoid
#     240     # an extra SQL query if it's accessed later on.
#
# File c:\Users\hdiop\mambaforge\envs\jte-lab-timetabling\lib\site-packages\django\db\models\fields\related_descriptors.py:199, in ForwardManyToOneDescriptor.get_object(self, instance)
#     197 qs = self.get_queryset(instance=instance)
#     198 # Assuming the database enforces foreign keys, this won't fail.
# --> 199 return qs.get(self.field.get_reverse_related_filter(instance))
#
# File c:\Users\hdiop\mambaforge\envs\jte-lab-timetabling\lib\site-packages\django\db\models\query.py:633, in QuerySet.get(self, *args, **kwargs)
#     631     limit = MAX_GET_RESULTS
#     632     clone.query.set_limits(high=limit)
# --> 633 num = len(clone)
#     634 if num == 1:
#     635     return clone._result_cache[0]
#
# File c:\Users\hdiop\mambaforge\envs\jte-lab-timetabling\lib\site-packages\django\db\models\query.py:380, in QuerySet.__len__(self)
#     379 def __len__(self):
# --> 380     self._fetch_all()
#     381     return len(self._result_cache)
#
# File c:\Users\hdiop\mambaforge\envs\jte-lab-timetabling\lib\site-packages\django\db\models\query.py:1881, in QuerySet._fetch_all(self)
#    1879 def _fetch_all(self):
#    1880     if self._result_cache is None:
# -> 1881         self._result_cache = list(self._iterable_class(self))
#    1882     if self._prefetch_related_lookups and not self._prefetch_done:
#    1883         self._prefetch_related_objects()
#
# File c:\Users\hdiop\mambaforge\envs\jte-lab-timetabling\lib\site-packages\django\db\models\query.py:91, in ModelIterable.__iter__(self)
#      88 compiler = queryset.query.get_compiler(using=db)
#      89 # Execute the query. This will also fill compiler.select, klass_info,
#      90 # and annotations.
# ---> 91 results = compiler.execute_sql(
#      92     chunked_fetch=self.chunked_fetch, chunk_size=self.chunk_size
#      93 )
#      94 select, klass_info, annotation_col_map = (
#      95     compiler.select,
#      96     compiler.klass_info,
#      97     compiler.annotation_col_map,
#      98 )
#      99 model_cls = klass_info["model"]
#
# File c:\Users\hdiop\mambaforge\envs\jte-lab-timetabling\lib\site-packages\django\db\models\sql\compiler.py:1562, in SQLCompiler.execute_sql(self, result_type, chunked_fetch, chunk_size)
#    1560     cursor = self.connection.cursor()
#    1561 try:
# -> 1562     cursor.execute(sql, params)
#    1563 except Exception:
#    1564     # Might fail for server-side cursors (e.g. connection closed)
#    1565     cursor.close()
#
# File c:\Users\hdiop\mambaforge\envs\jte-lab-timetabling\lib\site-packages\django\db\backends\utils.py:67, in CursorWrapper.execute(self, sql, params)
#      66 def execute(self, sql, params=None):
# ---> 67     return self._execute_with_wrappers(
#      68         sql, params, many=False, executor=self._execute
#      69     )
#
# File c:\Users\hdiop\mambaforge\envs\jte-lab-timetabling\lib\site-packages\django\db\backends\utils.py:80, in CursorWrapper._execute_with_wrappers(self, sql, params, many, executor)
#      78 for wrapper in reversed(self.db.execute_wrappers):
#      79     executor = functools.partial(wrapper, executor)
# ---> 80 return executor(sql, params, many, context)
#
# File c:\Users\hdiop\mambaforge\envs\jte-lab-timetabling\lib\site-packages\django\db\backends\utils.py:89, in CursorWrapper._execute(self, sql, params, *ignored_wrapper_args)
#      87     return self.cursor.execute(sql)
#      88 else:
# ---> 89     return self.cursor.execute(sql, params)
#
# File c:\Users\hdiop\mambaforge\envs\jte-lab-timetabling\lib\encodings\utf_8.py:15, in decode(input, errors)
#      11 ### Codec APIs
#      13 encode = codecs.utf_8_encode
# ---> 15 def decode(input, errors='strict'):
#      16     return codecs.utf_8_decode(input, errors, True)
#      18 class IncrementalEncoder(codecs.IncrementalEncoder):
#
# KeyboardInterrupt:

# %%
cp.print_stats(sort='cumtime')
# Out:
#          3524473201 function calls (3412798289 primitive calls) in 4750.639 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000 4747.835
# 2373.917 interactiveshell.py:3472(run_code)
#         2    0.000    0.000 4746.706 2373.353 {built-in method builtins.exec}
#         1    0.000    0.000 4732.251 4732.251 1175231824.py:1(<module>)
#         1    0.141    0.141 4732.251 4732.251 4031027849.py:87(run)
#        58    0.255    0.004 4671.012   80.535 4031027849.py:63(evolve)
#    840498   28.149    0.000 4545.903    0.005 2213152367.py:117(get_group_schedule)
#    840498    5.965    0.000 4488.638    0.005 2213152367.py:110(get_participant_schedule)
#    840498   12.699    0.000 4482.395    0.005 2213152367.py:101(participants)
#   4230320   27.878    0.000 3522.293    0.001 query.py:1879(_fetch_all)
#  10122909   68.250    0.000 3490.748    0.000 query.py:85(__iter__)
#   4229395   34.440    0.000 2761.917    0.001 compiler.py:1532(execute_sql)
#   2506417   18.874    0.000 2578.694    0.001 related_descriptors.py:201(__get__)
#   2498317   14.322    0.000 2534.549    0.001 related_descriptors.py:196(get_object)
#   2498317   18.887    0.000 2380.864    0.001 query.py:613(get)
#      1392    2.428    0.002 2375.071    1.706 397601474.py:6(repair)
#        59    0.005    0.000 2284.382   38.718 2172666981.py:17(calculate_fitness)
#      1470    0.004    0.000 2284.377    1.554 2059219220.py:25(calculate_fitness)
#      1470    0.012    0.000 2284.370    1.554 2059219220.py:17(calculate_all_fitness)
#      1470    0.004    0.000 2283.205    1.553 1002078068.py:18(calculate_fitness)
#      1470    2.998    0.002 2283.198    1.553 1002078068.py:8(calculate_unsatisfied_participants)
#    417296    2.827    0.000 2268.530    0.005 3432167734.py:41(schedule_constraint)
# 76102434/53617530   12.161    0.000 1869.311    0.000 {built-in method builtins.len}
#   2498317    3.120    0.000 1860.731    0.001 query.py:379(__len__)
#   1732003    2.318    0.000 1667.706    0.001 query.py:383(__iter__)
#   4229395    7.621    0.000 1232.151    0.000 utils.py:66(execute)
#   4229395    8.599    0.000 1224.530    0.000 utils.py:76(_execute_with_wrappers)
#   4229395   15.581    0.000 1215.931    0.000 utils.py:82(_execute)
#   4229395   63.608    0.000 1214.557    0.000 compiler.py:725(as_sql)
#   4229395 1168.711    0.000 1196.874    0.000 {method 'execute' of 'psycopg2.extensions.cursor' objects}
#    889680    5.931    0.000  920.193    0.001 query.py:1050(first)
#   4229395   22.078    0.000  795.008    0.000 compiler.py:78(pre_sql_setup)
#   4229395   11.461    0.000  656.548    0.000 query.py:1457(_filter_or_exclude_inplace)
#   4229395   16.630    0.000  627.583    0.000 query.py:1531(add_q)
# 6727712/4229395   43.785    0.000  600.911    0.000 query.py:1556(_add_q)
#   4229395    5.241    0.000  595.321    0.000 query.py:1430(filter)
#   4229395    9.031    0.000  585.755    0.000 query.py:1446(_filter_or_exclude)
# 6727712/4229395   72.994    0.000  501.476    0.000 query.py:1361(build_filter)
# 36529305/27180835   45.367    0.000  457.268    0.000 compiler.py:541(compile)
#   4229395   19.612    0.000  406.634    0.000 compiler.py:70(setup_query)
#   4229395   59.931    0.000  379.813    0.000 compiler.py:229(get_select)
#   4229395   18.473    0.000  270.906    0.000 where.py:114(as_sql)
#   4229395   14.175    0.000  260.057    0.000 compiler.py:448(get_order_by)
#   4229395    7.554    0.000  239.741    0.000 lookups.py:343(as_sql)
#   4229395   12.155    0.000  231.357    0.000 lookups.py:223(as_sql)
# 22135019/13676229   24.535    0.000  221.907    0.000 functional.py:49(__get__)
#   4229395   24.284    0.000  192.618    0.000 lookups.py:213(process_lhs)
#   5119075   20.638    0.000  183.057    0.000 compiler.py:316(_order_by_pairs)
#  52576910   11.753    0.000  179.034    0.000 query.py:310(query)
# 12688185/4229395   20.656    0.000  165.097    0.000 asyncio.py:15(inner)
#   8507072    5.280    0.000  160.517    0.000 query.py:1849(_chain)
#   8507072   29.944    0.000  155.238    0.000 query.py:1860(_clone)
# 163303063/158232270   65.538    0.000  146.654    0.000 {built-in method builtins.getattr}
#   4229395   16.301    0.000  143.805    0.000 query.py:1293(build_lookup)
#  22951440   29.203    0.000  138.029    0.000 expressions.py:1130(as_sql)
#   4229395    2.820    0.000  135.771    0.000 base.py:327(cursor)
#   8507072   35.321    0.000  134.788    0.000 copy.py:66(copy)
#      5061    0.157    0.000  134.430    0.027 397601474.py:27(find_feasible_solution)
#   4229395   16.013    0.000  132.951    0.000 base.py:304(_cursor)
#   4229395   39.204    0.000  131.161    0.000 compiler.py:950(get_default_columns)
# 11418620/8515462   28.193    0.000  125.856    0.000 copy.py:259(_reconstruct)
#   4229394   13.181    0.000  125.762    0.000 compiler.py:1504(results_iter)
#   5893514   17.144    0.000  122.641    0.000 base.py:574(from_db)
#   2816586    1.951    0.000  122.140    0.000 expressions.py:501(__hash__)
# 6008755/5119075   16.522    0.000  120.036    0.000 expressions.py:258(resolve_expression)
# 39928426/39922354   34.307    0.000  119.511    0.000 {method 'join' of 'str' objects}
#    938862   10.744    0.000  116.547    0.000 expressions.py:477(identity)
#   8458788   19.790    0.000  115.672    0.000 compiler.py:2087(cursor_iter)
#   4229395    9.935    0.000  113.897    0.000 lookups.py:98(process_lhs)
#   8507072   12.553    0.000  112.148    0.000 query.py:359(chain)
#   5426195    4.385    0.000  108.887    0.000 manager.py:157(all)
#   4229394   29.486    0.000  108.048    0.000 compiler.py:1483(get_converters)
#   5893514   52.277    0.000  103.574    0.000 base.py:460(__init__)
#   4229395    5.841    0.000  101.376    0.000 where.py:38(split_having_qualify)
#   4229395   12.066    0.000   98.529    0.000 query.py:296(get_compiler)
#   6008755    6.044    0.000   97.917    0.000 expressions.py:414(copy)
#   8507072   55.192    0.000   97.818    0.000 query.py:314(clone)
#   5070793    3.088    0.000   91.245    0.000 connection.py:56(__getitem__)
#   3387997   11.702    0.000   90.237    0.000 query.py:1653(order_by)
#   8458788   29.972    0.000   88.033    0.000 compiler.py:2093(<lambda>)
#   2498317    7.957    0.000   84.545    0.000 related_descriptors.py:152(get_queryset)
#  50132275   47.613    0.000   83.932    0.000 compiler.py:519(quote_name_unless_alias)
#   4996632   10.825    0.000   81.020    0.000 compiler.py:1493(apply_converters)
#    938864    1.610    0.000   80.264    0.000 inspect.py:3252(signature)
#    938864    1.946    0.000   78.654    0.000 inspect.py:2998(from_callable)
#   5070793   13.972    0.000   78.110    0.000 local.py:99(__getattr__)
# 1877728/938864   13.240    0.000   76.708    0.000 inspect.py:2375(_signature_from_callable)
#  17832360   25.973    0.000   75.558    0.000 expressions.py:1146(get_db_converters)
# 20296936/8390   32.230    0.000   75.076    0.009 copy.py:128(deepcopy)
# 967142/8390    4.228    0.000   74.827    0.009 copy.py:227(_deepcopy_dict)
#   5119075   32.214    0.000   74.501    0.000 query.py:1768(setup_joins)
#      3329    0.575    0.000   74.180    0.022 copy.py:201(_deepcopy_list)
#     24591    1.907    0.000   71.197    0.003 3007821717.py:42(create_time_slot)
#   2498316    6.941    0.000   69.811    0.000 json.py:86(from_db_value)
# 17811037/9352247   12.959    0.000   69.390    0.000 {built-in method builtins.any}
#   4229395   11.514    0.000   68.986    0.000 lookups.py:25(__init__)
#     49182    0.258    0.000   68.263    0.001 2213152367.py:31(get_module)
#    841398    5.196    0.000   66.889    0.000 related_descriptors.py:713(get_queryset)
#    841398    1.519    0.000   65.157    0.000 related_lookups.py:170(as_sql)
# 27835883/25330365   14.069    0.000   64.944    0.000 {built-in method builtins.setattr}
#   5960473   12.420    0.000   64.470    0.000 related.py:1184(get_col)
#  22951440   32.725    0.000   63.914    0.000 __init__.py:492(get_col)
#   5070793    7.917    0.000   62.392    0.000 local.py:80(_get_storage)
# 184360108/182580526   41.244    0.000   62.179    0.000 {built-in method builtins.isinstance}
#   2498320    6.048    0.000   61.836    0.000 __init__.py:299(loads)
#         1    0.000    0.000   60.885   60.885 4031027849.py:43(initialize_population)
#   2498317   14.222    0.000   54.817    0.000 related.py:402(get_reverse_related_filter)
#   2498320    9.285    0.000   53.639    0.000 decoder.py:332(decode)
#   9348470   17.982    0.000   53.377    0.000 query.py:1018(get_initial_alias)
#   5070793   27.375    0.000   51.923    0.000 local.py:44(_get_context_id)
#    841398    9.437    0.000   51.702    0.000 related_descriptors.py:665(_apply_rel_filters)
#  10238150   40.193    0.000   50.670    0.000 query.py:1652(names_to_path)
#   4229395    4.320    0.000   50.561    0.000 where.py:242(contains_aggregate)
#   4229395    4.241    0.000   49.892    0.000 expressions.py:379(get_lookup)
#   2498317    5.133    0.000   48.047    0.000 manager.py:136(db_manager)
#  13933267   25.385    0.000   47.869    0.000 query.py:294(__init__)
#   5426195   10.163    0.000   46.441    0.000 manager.py:150(get_queryset)
#   4229395   15.374    0.000   46.429    0.000 query.py:1222(solve_lookup_type)
# 8458790/4229395   11.504    0.000   46.241    0.000 where.py:236(_contains_aggregate)
#   4229395   21.249    0.000   45.650    0.000 query_utils.py:232(get_lookup)
#    938864   15.423    0.000   43.966    0.000 inspect.py:2280(_signature_from_function)
#   6727712   21.863    0.000   42.791    0.000 query.py:2640(update_join_types)
#   4229395    7.873    0.000   41.164    0.000 base.py:293(_prepare_cursor)
#  12688186    6.917    0.000   39.282    0.000 _collections_abc.py:821(get)
#  27180830   29.543    0.000   39.234    0.000 __init__.py:615(__eq__)
#   4229395   16.194    0.000   38.403    0.000 lookups.py:328(get_prep_lookup)
#   4229395    3.143    0.000   37.555    0.000 where.py:252(contains_over_clause)
#   4229395   10.060    0.000   37.226    0.000 base.py:321(create_cursor)
#  10946532   18.223    0.000   35.890    0.000 related_descriptors.py:86(__set__)
#   8458790    4.788    0.000   35.006    0.000 where.py:239(<genexpr>)
#   2498320   34.587    0.000   34.587    0.000 decoder.py:343(raw_decode)
# 8458790/4229395    8.339    0.000   34.413    0.000 where.py:246(_contains_over_clause)
#   8458788   12.808    0.000   33.373    0.000 utils.py:96(inner)
#  12688218   14.599    0.000   32.365    0.000 os.py:675(__getitem__)
# 20842851/19063491   26.801    0.000   32.088    0.000 deconstruct.py:15(__new__)
# 148765706   32.071    0.000   32.072    0.000 {built-in method builtins.hasattr}
#   4229395   10.210    0.000   31.961    0.000 __init__.py:798(db_type)
#  34489280   13.960    0.000   29.998    0.000 {built-in method builtins.all}
#  10454807   20.245    0.000   29.932    0.000 {method '__reduce_ex__' of 'object' objects}
#   6727712   15.566    0.000   29.054    0.000 query_utils.py:48(__init__)
#    889680    3.994    0.000   28.911    0.000 compiler.py:1026(find_ordering_name)
#   6727712    5.108    0.000   28.610    0.000 query.py:2633(add_votes)
# 9695128/6753349    2.940    0.000   28.540    0.000 copy.py:264(<genexpr>)
#  12688182   20.610    0.000   28.178    0.000 utils.py:22(__getattr__)
#  22061755   15.761    0.000   28.162    0.000 utf_8.py:15(decode)
#   5021611   15.692    0.000   27.416    0.000 query.py:1040(join)
#  22061760   19.575    0.000   26.844    0.000 operations.py:199(quote_name)
#   8458790    3.630    0.000   26.385    0.000 where.py:249(<genexpr>)
#   8507072   12.926    0.000   26.310    0.000 where.py:209(clone)
#      1392    0.102    0.000   25.973    0.019 1117434174.py:12(mutate)
#   4229395   12.211    0.000   25.934    0.000 compiler.py:1106(get_from_clause)
#  13455426    9.547    0.000   25.854    0.000 __init__.py:640(update)
#    417296    3.313    0.000   25.793    0.000 3432167734.py:10(__init__)
#   6727712   11.095    0.000   24.511    0.000 query.py:2612(__init__)
#  10438027    9.400    0.000   23.946    0.000 copyreg.py:100(__newobj__)
#  36614720   23.599    0.000   23.599    0.000 tree.py:22(__init__)
#         1    0.000    0.000   23.375   23.375 3007821717.py:125(generate_population)
#        25    0.144    0.006   23.375    0.935 3007821717.py:84(generate_chromosome)
#   4229395    8.509    0.000   23.321    0.000 query_utils.py:213(_get_lookup)
#    841398    4.188    0.000   23.300    0.000 related_lookups.py:152(get_prep_lookup)
#    841398    1.283    0.000   22.556    0.000 related.py:1162(db_type)
#   5426195   17.778    0.000   22.484    0.000 query.py:231(__init__)
#  17832365   14.127    0.000   21.952    0.000 expressions.py:463(select_format)
#   4229395    7.561    0.000   21.503    0.000 lookups.py:108(process_rhs)
#   4229395    8.686    0.000   21.337    0.000 lookups.py:80(get_prep_lookup)
#         4    0.000    0.000   21.037    5.259 base_events.py:1832(_run_once)
#    841398    2.871    0.000   20.922    0.000 __init__.py:2795(rel_db_type)
#  13503706   13.077    0.000   20.713    0.000 tree.py:28(create)
#       696    0.098    0.000   20.447    0.029 812580972.py:11(crossover)
#    889680    4.108    0.000   20.371    0.000 query.py:415(__getitem__)
#   4229395    7.279    0.000   20.257    0.000 __init__.py:781(db_type_parameters)
# 126938810   19.990    0.000   19.990    0.000 {method 'get' of 'dict' objects}
#   4229395    6.809    0.000   19.772    0.000 expressions.py:239(contains_aggregate)
#   4229395   19.593    0.000   19.593    0.000 {method 'cursor' of 'psycopg2.extensions.connection' objects}
#   2505518   10.356    0.000   18.647    0.000 related_descriptors.py:252(__set__)
#   4229395    3.795    0.000   18.319    0.000 query.py:379(_get_col)
#   5119075   14.917    0.000   18.194    0.000 query.py:1893(trim_joins)
#  12688218    9.004    0.000   17.766    0.000 os.py:747(encodekey)
#   8458788   15.070    0.000   17.739    0.000 {method 'fetchmany' of 'psycopg2.extensions.cursor' objects}
#  10946532   11.232    0.000   17.640    0.000 mixins.py:21(is_cached)
# 140998381   17.202    0.000   17.202    0.000 {method 'append' of 'list' objects}
#   3387997    9.222    0.000   17.034    0.000 operations.py:250(limit_offset_sql)
#  10253059   15.595    0.000   16.982    0.000 functional.py:291(__getattribute__)
# 6008755/5119075    2.714    0.000   16.919    0.000 expressions.py:278(<listcomp>)
#   2498317    2.120    0.000   16.750    0.000 query_utils.py:71(__and__)
#  11798513    5.654    0.000   16.696    0.000 abc.py:117(__instancecheck__)
#   4229395    6.030    0.000   16.650    0.000 base.py:647(validate_thread_sharing)
#    938862    1.179    0.000   16.409    0.000 inspect.py:3188(bind_partial)
#  10957107   12.406    0.000   16.002    0.000 tree.py:89(add)
#   5070793    5.517    0.000   15.862    0.000 sync.py:545(get_current_task)
#  96487416   15.780    0.000   15.780    0.000 2213152367.py:125(<genexpr>)
#  86753543   15.768    0.000   15.768    0.000 {method 'copy' of 'dict' objects}
#   4229395   10.220    0.000   15.639    0.000 query.py:909(reset_refcounts)
#  10957107   11.871    0.000   15.435    0.000 query.py:890(demote_joins)
#    938862   11.294    0.000   15.231    0.000 inspect.py:3050(_bind)
#   3755463    8.945    0.000   15.116    0.000 inspect.py:2637(__init__)
#   2498317    5.835    0.000   14.629    0.000 query_utils.py:55(_combine)
#   4229395    8.135    0.000   14.613    0.000 query.py:1769(db)
#         8    0.000    0.000   14.461    1.808 events.py:78(_run)
#         8    0.000    0.000   14.461    1.808 {method 'run' of '_contextvars.Context' objects}
#         2    0.000    0.000   14.461    7.230 kernelbase.py:493(process_one)
#         1    0.000    0.000   14.460   14.460 kernelbase.py:507(dispatch_queue)
#         1    0.000    0.000   14.460   14.460 kernelbase.py:363(dispatch_shell)
#         1    0.000    0.000   14.459   14.459 kernelbase.py:695(execute_request)
#         1    0.000    0.000   14.458   14.458 ipkernel.py:339(do_execute)
#         1    0.000    0.000   14.457   14.457 zmqshell.py:543(run_cell)
#         1    0.000    0.000   14.457   14.457 interactiveshell.py:2976(run_cell)
#         1    0.000    0.000   14.457   14.457 interactiveshell.py:3018(_run_cell)
#         1    0.000    0.000   14.457   14.457 async_helpers.py:120(_pseudo_sync_runner)
#         1    0.000    0.000   14.457   14.457 {method 'send' of 'coroutine' objects}
#         1    0.000    0.000   14.457   14.457 interactiveshell.py:3117(run_cell_async)
#         1    0.000    0.000   14.455   14.455 interactiveshell.py:3349(run_ast_nodes)
#         1    0.000    0.000   14.455   14.455 3710621001.py:1(<module>)
#         1    0.000    0.000   14.455   14.455 cProfile.py:16(run)
#         1    0.000    0.000   14.455   14.455 profile.py:51(run)
#         1    0.000    0.000   14.455   14.455 cProfile.py:93(run)
#         1    0.000    0.000   14.455   14.455 cProfile.py:98(runctx)
#         1   14.455   14.455   14.455   14.455 {method 'enable' of '_lsprof.Profiler' objects}
#    938864    5.434    0.000   14.336    0.000 inspect.py:1959(_signature_bound_method)
#   1877728   10.375    0.000   14.201    0.000 inspect.py:2920(__init__)
#    889680    2.564    0.000   14.037    0.000 compiler.py:1091(_setup_joins)
#   4229395    4.363    0.000   13.856    0.000 expressions.py:245(contains_over_clause)
#   4229394   13.569    0.000   13.569    0.000 query.py:102(<listcomp>)
#  22951434    8.313    0.000   13.439    0.000 __init__.py:860(get_db_converters)
#   6727714   11.064    0.000   13.416    0.000 __init__.py:565(__init__)
#    841398    2.831    0.000   13.360    0.000 related_descriptors.py:604(__get__)
#   4229395    8.576    0.000   13.241    0.000 lookups.py:242(get_db_prep_lookup)
#   4229395   12.977    0.000   12.977    0.000 datastructures.py:267(__init__)
#   5119074   10.407    0.000   12.917    0.000 related.py:1178(get_db_converters)
#   2498317    3.018    0.000   12.534    0.000 related.py:749(get_local_related_value)
#  22061765   12.402    0.000   12.402    0.000 {built-in method _codecs.utf_8_decode}
#    889680    5.513    0.000   11.576    0.000 expressions.py:1610(as_sql)
#   8458790    5.899    0.000   11.204    0.000 lookups.py:69(get_source_expressions)
#    841398    9.414    0.000   11.169    0.000 __init__.py:179(__init__)
#  11798513   11.042    0.000   11.042    0.000 {built-in method _abc._abc_instancecheck}
#   5070793    7.683    0.000   10.518    0.000 __init__.py:2048(get_prep_value)
#   3387997    5.622    0.000   10.395    0.000 query.py:2199(add_ordering)
#   5070793    6.362    0.000   10.345    0.000 tasks.py:35(current_task)
#  29675478   10.238    0.000   10.238    0.000 {built-in method __new__ of type object at 0x00007FFD378F8EF0}
#  25450535    9.682    0.000    9.682    0.000 {method 'startswith' of 'str' objects}
#   2498317    5.260    0.000    9.517    0.000 related.py:755(get_instance_value_for_fields)
#   5119075    7.432    0.000    9.481    0.000 expressions.py:1119(__init__)
#   6008755    6.409    0.000    9.372    0.000 expressions.py:185(__getstate__)
#   4229395    7.972    0.000    9.315    0.000 base.py:630(allow_thread_sharing)
#   4229395    3.037    0.000    9.247    0.000 base.py:183(queries_logged)
#   4229395    7.684    0.000    9.057    0.000 query_utils.py:223(get_instance_lookups)
#    889680    2.515    0.000    8.916    0.000 query.py:1748(ordered)
#    889680    2.788    0.000    8.858    0.000 compiler.py:1086(<listcomp>)
#  26291155    8.843    0.000    8.843    0.000 query.py:2482(extra_select)
#    841398    3.358    0.000    8.747    0.000 related_descriptors.py:641(__init__)
#   5070794    5.527    0.000    8.686    0.000 <frozen importlib._bootstrap>:404(parent)
#  14345104    8.666    0.000    8.666    0.000 query.py:2101(is_sliced)
#    841398    5.296    0.000    8.659    0.000 related_lookups.py:43(get_normalized_value)
#  23718551    8.356    0.000    8.356    0.000 query.py:305(get_meta)
#   5070793    7.059    0.000    8.002    0.000 utils.py:218(_route_db)
#   5126040    7.938    0.000    7.938    0.000 {method 'match' of 're.Pattern' objects}
#  44156213    7.761    0.000    7.761    0.000 {method 'items' of 'dict' objects}
#   4229395    7.683    0.000    7.683    0.000 compiler.py:46(__init__)
#  54194180    7.660    0.000    7.660    0.000 {method 'extend' of 'list' objects}
#   8458790    5.116    0.000    7.594    0.000 query.py:1280(check_filterable)
#    938864    1.422    0.000    7.547    0.000 inspect.py:3014(replace)
#    417296    1.231    0.000    7.487    0.000 2213152367.py:3(__init__)
#   4229395    4.859    0.000    7.394    0.000 base.py:690(make_cursor)
#   5021611    6.392    0.000    7.300    0.000 query.py:818(table_alias)
#  10315618    7.204    0.000    7.204    0.000 {method 'update' of 'dict' objects}
#   6763546    6.983    0.000    7.002    0.000 {built-in method builtins.sorted}
#         4    0.000    0.000    6.575    1.644 selectors.py:320(select)
#         4    0.000    0.000    6.575    1.644 selectors.py:314(_select)
#         4    6.575    1.644    6.575    1.644 {built-in method select.select}
#   3339715    5.075    0.000    6.509    0.000 manager.py:21(__new__)
#   2816586    2.930    0.000    6.426    0.000 compiler.py:31(__init__)
#  10238150    6.418    0.000    6.418    0.000 options.py:660(get_field)
#   2506417    5.934    0.000    6.369    0.000 mixins.py:12(get_cached_value)
#   5003834    5.284    0.000    6.303    0.000 mixins.py:24(set_cached_value)
#   2498317    2.924    0.000    6.155    0.000 tree.py:47(__copy__)
#  12688218    4.579    0.000    6.094    0.000 os.py:741(check_str)
#   4229395    4.623    0.000    6.023    0.000 compiler.py:1000(get_distinct)
#   4229395    2.877    0.000    5.877    0.000 query.py:1257(check_related_objects)
#   1828542    3.589    0.000    5.779    0.000 hashable.py:4(make_hashable)
#   4229395    3.694    0.000    5.684    0.000 query.py:1202(resolve_lookup_value)
#   6727714    5.667    0.000    5.667    0.000 {built-in method _collections._count_elements}
#   2498317    2.597    0.000    5.601    0.000 related.py:410(<listcomp>)
#   4229394    4.930    0.000    5.568    0.000 query.py:106(<listcomp>)
#   4229394    4.464    0.000    5.453    0.000 query.py:2625(get_related_populators)
#   4229395    4.212    0.000    5.398    0.000 datastructures.py:199(as_sql)
#    841398    2.832    0.000    5.389    0.000 manager.py:27(__init__)
#   6700601    3.867    0.000    5.385    0.000 copy.py:243(_keep_alive)
#   8458790    4.008    0.000    5.305    0.000 lookups.py:128(rhs_is_direct_value)
#    841398    2.080    0.000    5.160    0.000 datastructures.py:45(__init__)
#   7502152    5.114    0.000    5.114    0.000 query_utils.py:164(__get__)
#  15953741    5.013    0.000    5.013    0.000 tree.py:63(__bool__)
#    938862    4.021    0.000    4.879    0.000 inspect.py:2840(apply_defaults)
#  17758982    4.818    0.000    4.818    0.000 {built-in method _asyncio.get_running_loop}
#   6727712    4.751    0.000    4.751    0.000 query.py:853(promote_joins)
#   4229395    4.738    0.000    4.738    0.000 query_utils.py:206(__get__)
#  17832365    4.673    0.000    4.673    0.000 query.py:1090(join_parent_model)
#  18456783    4.664    0.000    4.664    0.000 related.py:509(get_cache_name)
#    889680    1.410    0.000    4.576    0.000 query.py:1980(__instancecheck__)
#   2086480    3.772    0.000    4.561    0.000 manager.py:184(__get__)
#   3755535    3.355    0.000    4.560    0.000 enum.py:359(__call__)
#  16917578    4.521    0.000    4.521    0.000 utils.py:70(__exit__)
#   2826972    4.376    0.000    4.376    0.000 {method '__deepcopy__' of 'numpy.generic' objects}
#    417296    0.955    0.000    4.369    0.000 2213152367.py:23(__init__)
#   4229395    3.123    0.000    4.324    0.000 query.py:1958(_not_support_combined_queries)
#   8458790    4.256    0.000    4.256    0.000 compiler.py:71(<genexpr>)
#   4229395    4.225    0.000    4.225    0.000 lookups.py:230(get_rhs_op)
#   8484667    4.194    0.000    4.194    0.000 related.py:1057(target_field)
#   4229395    4.108    0.000    4.108    0.000 operations.py:154(lookup_cast)
#  11787028    4.029    0.000    4.029    0.000 dispatcher.py:152(send)
#   4229395    2.626    0.000    3.887    0.000 operations.py:363(compiler)
#   8415615    3.787    0.000    3.787    0.000 {method 'pop' of 'list' objects}
#   4229395    3.668    0.000    3.668    0.000 query.py:47(__init__)
#   5021611    2.526    0.000    3.666    0.000 query.py:1061(<listcomp>)
#   8458790    3.606    0.000    3.606    0.000 {method 'update' of 'set' objects}
#  14622317    3.602    0.000    3.602    0.000 {built-in method builtins.iter}
#   8458788    3.574    0.000    3.574    0.000 utils.py:93(__call__)
#  18475108    3.553    0.000    3.553    0.000 {built-in method builtins.issubclass}
#   2816586    2.933    0.000    3.495    0.000 expressions.py:1160(__init__)
#   3387997    3.493    0.000    3.493    0.000 query.py:2074(set_limits)
#    938864    2.221    0.000    3.471    0.000 inspect.py:612(unwrap)
#    417296    0.772    0.000    3.447    0.000 2213152367.py:50(__init__)
#    938864    2.248    0.000    3.447    0.000 inspect.py:66(get_annotations)
#    417296    0.673    0.000    3.437    0.000 2213152367.py:85(__init__)
#   6013144    3.371    0.000    3.371    0.000 {method 'split' of 'str' objects}
#    417296    0.659    0.000    3.314    0.000 2213152367.py:132(__init__)
#   5912191    3.303    0.000    3.303    0.000 query.py:849(unref_alias)
#   5893514    3.198    0.000    3.198    0.000 base.py:440(__get__)
#   5070794    3.159    0.000    3.159    0.000 {method 'rpartition' of 'str' objects}
#  31826835    3.154    0.000    3.154    0.000 {built-in method builtins.id}
#   8458790    3.144    0.000    3.144    0.000 expressions.py:241(<genexpr>)
#   8507072    3.086    0.000    3.086    0.000 {method 'copy' of 'set' objects}
#    841398    2.254    0.000    3.080    0.000 related.py:779(get_joining_columns)
#   5168257    3.080    0.000    3.080    0.000 query.py:845(ref_alias)
#  14515827    3.069    0.000    3.069    0.000 {method 'pop' of 'dict' objects}
#   4229395    2.038    0.000    3.007    0.000 lookups.py:90(get_prep_lhs)
#  17832360    3.004    0.000    3.004    0.000 operations.py:632(get_db_converters)
#  17832365    2.984    0.000    2.984    0.000 __init__.py:507(select_format)
#   4229394    2.958    0.000    2.958    0.000 compiler.py:1516(<listcomp>)
#   2498317    1.483    0.000    2.935    0.000 query.py:2108(can_filter)
#    889680    1.425    0.000    2.929    0.000 functional.py:264(inner)
#   4229394    2.923    0.000    2.923    0.000 {method 'close' of 'psycopg2.extensions.cursor' objects}
#   4694327    2.284    0.000    2.909    0.000 inspect.py:2969(<genexpr>)
#   4180213    2.895    0.000    2.895    0.000 datastructures.py:195(__init__)
#   5070793    2.026    0.000    2.835    0.000 __init__.py:934(get_prep_value)
#    889680    1.039    0.000    2.831    0.000 query.py:2071(is_empty)
#   5486528    2.751    0.000    2.751    0.000 {built-in method builtins.hash}
#  12688224    2.668    0.000    2.668    0.000 {method 'upper' of 'str' objects}
#    841398    1.311    0.000    2.650    0.000 query.py:1245(check_query_object_type)
#   2498316    2.064    0.000    2.633    0.000 _json.py:159(typecast_json)
#   7935661    2.612    0.000    2.612    0.000 expressions.py:181(__init__)
#    889697    2.603    0.000    2.603    0.000 {method 'search' of 're.Pattern' objects}
#  16917578    2.559    0.000    2.559    0.000 utils.py:67(__enter__)
#    841398    2.557    0.000    2.557    0.000 manager.py:128(_set_creation_counter)
#   4229395    2.535    0.000    2.535    0.000 utils.py:16(__init__)
#    841398    0.909    0.000    2.509    0.000 related.py:1134(get_prep_value)
#   4229395    2.473    0.000    2.473    0.000 compiler.py:509(get_extra_select)
#   4229395    2.395    0.000    2.395    0.000 query.py:796(get_select_mask)
#   4229395    2.390    0.000    2.390    0.000 compiler.py:94(get_group_by)
#      1450    0.005    0.000    2.382    0.002 1255315854.py:22(select)
#   3387997    2.375    0.000    2.375    0.000 query.py:2236(clear_ordering)
#      1392    0.031    0.000    2.373    0.002 1255315854.py:41(tournament_selection)
#     34800    1.701    0.000    2.335    0.000 1255315854.py:49(tournament_selection_helper)
#   6775994    2.255    0.000    2.255    0.000 operations.py:253(<genexpr>)
#   4229395    2.241    0.000    2.241    0.000 query.py:2462(annotation_select)
#   2498317    2.234    0.000    2.234    0.000 options.py:715(get_ancestor_link)
#   8458790    2.182    0.000    2.182    0.000 expressions.py:247(<genexpr>)
#   3387997    2.117    0.000    2.117    0.000 operations.py:242(_get_limit_offset_params)
#   1682796    1.709    0.000    2.040    0.000 base.py:653(_get_pk_val)
#    889680    1.762    0.000    2.023    0.000 expressions.py:1578(__init__)
#   4229395    2.019    0.000    2.019    0.000 base.py:588(close_if_health_check_failed)
#   4229395    1.972    0.000    1.972    0.000 query.py:1542(<setcomp>)
#   4278577    1.967    0.000    1.967    0.000 query.py:267(base_table)
#   1877724    1.860    0.000    1.860    0.000 options.py:162(label)
#   8886998    1.832    0.000    1.832    0.000 {method 'add' of 'set' objects}
#   5071004    1.746    0.000    1.746    0.000 {method '__exit__' of '_thread.RLock' objects}
#    842309    1.292    0.000    1.713    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#   2505518    1.673    0.000    1.673    0.000 utils.py:240(allow_relation)
#   4229395    1.583    0.000    1.583    0.000 base.py:284(ensure_connection)
#   4229394    1.576    0.000    1.576    0.000 {built-in method from_iterable}
#   4229395    1.554    0.000    1.563    0.000 query.py:1436(<setcomp>)
#    125982    0.189    0.000    1.554    0.000 fromnumeric.py:2979(prod)
#   7512794    1.487    0.000    1.487    0.000 {built-in method builtins.next}
#  12205234    1.422    0.000    1.422    0.000 inspect.py:2687(name)
#   2498317    1.418    0.000    1.418    0.000 base.py:430(_base_manager)
#    125982    0.339    0.000    1.365    0.000 fromnumeric.py:71(_wrapreduction)
#   4229776    1.343    0.000    1.343    0.000 {method '__exit__' of '_thread.lock' objects}
#   6775994    1.330    0.000    1.330    0.000 __init__.py:2792(get_internal_type)
#   4230119    1.306    0.000    1.306    0.000 {built-in method _thread.get_ident}
#    889680    0.721    0.000    1.295    0.000 query.py:1813(final_transformer)
#   3755479    1.247    0.000    1.247    0.000 {method 'isidentifier' of 'str' objects}
#    840497    1.240    0.000    1.240    0.000 2213152367.py:122(<dictcomp>)
#  12632522    1.238    0.000    1.238    0.000 copy.py:182(_deepcopy_atomic)
#   1877753    1.046    0.000    1.230    0.000 inspect.py:277(isfunction)
#   4229395    1.221    0.000    1.221    0.000 base.py:529(validate_no_broken_transaction)
#    841398    0.754    0.000    1.210    0.000 query_utils.py:367(check_rel_lookup_compatibility)
#   3755535    1.204    0.000    1.204    0.000 enum.py:678(__new__)
#   5000298    1.201    0.000    1.201    0.000 {method 'end' of 're.Match' objects}
#   7046733    1.200    0.000    1.200    0.000 {built-in method builtins.callable}
#   5119075    1.196    0.000    1.196    0.000 expressions.py:200(set_source_expressions)
#   4229395    1.183    0.000    1.183    0.000 __init__.py:2740(get_db_prep_value)
#   1877726    1.166    0.000    1.166    0.000 {method 'values' of 'mappingproxy' objects}
#    889680    0.817    0.000    1.164    0.000 query.py:1969(_check_ordering_first_last_queryset_aggregation)
#         1    0.000    0.000    1.129    1.129 interactiveshell.py:2065(showtraceback)
#         1    0.000    0.000    1.126    1.126 ultratb.py:1412(structured_traceback)
#         1    0.000    0.000    1.126    1.126 ultratb.py:1314(structured_traceback)
#         1    0.000    0.000    1.126    1.126 ultratb.py:1163(structured_traceback)
#         2    0.000    0.000    1.126    0.563 ultratb.py:1038(format_exception_as_a_whole)
#  10327501    1.124    0.000    1.124    0.000 inspect.py:2699(kind)
#    841398    0.631    0.000    1.097    0.000 query.py:1929(_add_hints)
#    841398    0.814    0.000    1.018    0.000 __init__.py:643(__hash__)
#    841398    0.991    0.000    0.991    0.000 __init__.py:927(get_internal_type)
#   1779360    0.978    0.000    0.978    0.000 query.py:2592(get_order_dir)
#   1779360    0.708    0.000    0.950    0.000 query.py:2072(<genexpr>)
#    889682    0.947    0.000    0.947    0.000 {method 'count' of 'str' objects}
#   5119075    0.943    0.000    0.943    0.000 expressions.py:197(get_source_expressions)
#    841398    0.918    0.000    0.918    0.000 query.py:2573(is_nullable)
#    889680    0.712    0.000    0.893    0.000 itercompat.py:1(is_iterable)
#   4229395    0.875    0.000    0.875    0.000 operations.py:215(field_cast_sql)
#   1682796    0.826    0.000    0.826    0.000 related.py:781(<genexpr>)
#    125982    0.798    0.000    0.798    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#   2086480    0.790    0.000    0.790    0.000 options.py:415(swapped)
#    841398    0.782    0.000    0.782    0.000 query.py:1916(<dictcomp>)
#      1470    0.016    0.000    0.763    0.001 2174509031.py:20(calculate_fitness)
#      1470    0.592    0.000    0.746    0.001 2174509031.py:8(calculate_conflicts)
#    841398    0.487    0.000    0.689    0.000 datastructures.py:215(__eq__)
#    938862    0.669    0.000    0.669    0.000 inspect.py:2779(__init__)
#         2    0.000    0.000    0.650    0.325 ultratb.py:1105(get_records)
#    841398    0.639    0.000    0.639    0.000 query.py:111(<listcomp>)
#    938864    0.417    0.000    0.636    0.000 inspect.py:632(_is_wrapper)
#   2498316    0.570    0.000    0.570    0.000 base.py:283(<lambda>)
#   2498317    0.566    0.000    0.566    0.000 related.py:788(get_extra_descriptor_filter)
#   1682796    0.531    0.000    0.531    0.000 query.py:1921(<genexpr>)
#        27    0.000    0.000    0.514    0.019 core.py:562(stack_data)
#        27    0.000    0.000    0.514    0.019 utils.py:75(collapse_repeated)
#        25    0.000    0.000    0.513    0.021 core.py:586(mapper)
#        25    0.000    0.000    0.513    0.021 core.py:546(__init__)
#        25    0.001    0.000    0.513    0.021 executing.py:326(executing)
#    841398    0.493    0.000    0.493    0.000 query.py:1912(<setcomp>)
#        24    0.001    0.000    0.475    0.020 ultratb.py:853(format_record)
#    172/72    0.000    0.000    0.470    0.007 utils.py:140(cached_property_wrapper)
#    889680    0.464    0.000    0.464    0.000 expressions.py:1604(set_source_expressions)
#    841398    0.456    0.000    0.456    0.000 query_utils.py:375(check)
#    841398    0.313    0.000    0.451    0.000 datastructures.py:160(__eq__)
#    891666    0.427    0.000    0.427    0.000 {method 'rstrip' of 'str' objects}
#   2086593    0.427    0.000    0.427    0.000 {method 'setdefault' of 'dict' objects}
#   2816590    0.411    0.000    0.411    0.000 inspect.py:3006(parameters)
#    938862    0.396    0.000    0.396    0.000 {method 'items' of 'mappingproxy' objects}
#      1470    0.003    0.000    0.387    0.000 491081120.py:34(calculate_fitness)
#      1470    0.020    0.000    0.381    0.000 491081120.py:24(calculate_overload_penalty)
#        24    0.001    0.000    0.377    0.016 ultratb.py:195(_format_traceback_lines)
#       108    0.000    0.000    0.375    0.003 core.py:375(render)
#        24    0.000    0.000    0.374    0.016 core.py:799(_pygmented_scope_lines)
#        24    0.000    0.000    0.366    0.015 utils.py:150(_pygmented_with_ranges)
#    938864    0.365    0.000    0.365    0.000 {built-in method sys.getrecursionlimit}
#    963813    0.362    0.000    0.362    0.000 {method '__reduce_ex__' of 'datetime.datetime' objects}
#   2816595    0.335    0.000    0.335    0.000 inspect.py:2691(default)
#    841398    0.332    0.000    0.332    0.000 {method 'issubset' of 'set' objects}
#    963813    0.315    0.000    0.315    0.000 __init__.py:447(__getnewargs__)
#    840497    0.281    0.000    0.281    0.000 {method 'keys' of 'dict' objects}
#    889680    0.279    0.000    0.279    0.000 expressions.py:1607(get_source_expressions)
#    841398    0.277    0.000    0.277    0.000 query.py:1913(<setcomp>)
#        17    0.001    0.000    0.274    0.016 executing.py:627(__init__)
#    889680    0.259    0.000    0.259    0.000 operations.py:645(check_expression_support)
#        48    0.001    0.000    0.259    0.005 lexer.py:641(__call__)
#        24    0.000    0.000    0.255    0.011 lexer.py:584(process_tokendef)
#  2112/792    0.013    0.000    0.254    0.000 lexer.py:540(_process_state)
#        34    0.001    0.000    0.245    0.007 executing.py:787(matching_nodes)
#        17    0.000    0.000    0.237    0.014 executing.py:271(for_frame)
#        17    0.001    0.000    0.237    0.014 executing.py:279(for_filename)
#    841398    0.236    0.000    0.236    0.000 __init__.py:2063(get_internal_type)
#      2640    0.003    0.000    0.235    0.000 lexer.py:493(_process_regex)
#        17    0.001    0.000    0.233    0.014 executing.py:308(_for_filename_and_lines)
#         4    0.030    0.008    0.232    0.058 executing.py:220(__init__)
#        36    0.000    0.000    0.225    0.006 executing.py:870(compile_instructions)
#       192    0.000    0.000    0.225    0.001 lexer.py:483(get)
#       192    0.000    0.000    0.224    0.001 regexopt.py:82(regex_opt)
# 16128/192    0.049    0.000    0.223    0.001 regexopt.py:26(regex_opt_inner)
#        46    0.217    0.005    0.217    0.005 {built-in method builtins.compile}
#       174    0.001    0.000    0.213    0.001 __init__.py:1467(info)
#       178    0.001    0.000    0.212    0.001 __init__.py:1600(_log)
# 18288/576    0.032    0.000    0.212    0.000 regexopt.py:77(<genexpr>)
#      1470    0.170    0.000    0.205    0.000 491081120.py:12(calculate_assistants_assignments)
#       178    0.000    0.000    0.198    0.001 __init__.py:1626(handle)
#       178    0.001    0.000    0.197    0.001 __init__.py:1680(callHandlers)
#       173    0.001    0.000    0.196    0.001 __init__.py:955(handle)
#       173    0.001    0.000    0.195    0.001 __init__.py:1088(emit)
#        36    0.000    0.000    0.179    0.005 executing.py:603(compile_similar_to)
#       368    0.003    0.000    0.178    0.000 iostream.py:547(flush)
#      1470    0.116    0.000    0.149    0.000 491081120.py:18(calculate_assistants_shifts)
#       368    0.002    0.000    0.145    0.000 threading.py:589(wait)
#       354    0.002    0.000    0.142    0.000 threading.py:288(wait)
#      2716    0.139    0.000    0.139    0.000 {method 'acquire' of '_thread.lock' objects}
#       189    0.000    0.000    0.131    0.001 ansitowin32.py:46(write)
#       189    0.000    0.000    0.131    0.001 ansitowin32.py:175(write)
#       189    0.001    0.000    0.130    0.001 ansitowin32.py:192(write_and_convert)
#       189    0.001    0.000    0.128    0.001 ansitowin32.py:208(write_plain_text)
#        17    0.001    0.000    0.118    0.007 executing.py:768(get_original_clean_instructions)
#        24    0.000    0.000    0.100    0.004 __init__.py:77(highlight)
#        24    0.000    0.000    0.100    0.004 __init__.py:52(format)
#        24    0.000    0.000    0.099    0.004 terminal256.py:249(format)
#        24    0.000    0.000    0.099    0.004 formatter.py:114(format)
#        24    0.010    0.000    0.099    0.004 terminal256.py:252(format_unencoded)
#     49093    0.049    0.000    0.097    0.000 ast.py:267(iter_child_nodes)
#        24    0.000    0.000    0.095    0.004 ultratb.py:790(lines)
#        24    0.001    0.000    0.095    0.004 core.py:718(lines)
#        24    0.000    0.000    0.092    0.004 core.py:666(included_pieces)
#        24    0.000    0.000    0.091    0.004 core.py:604(scope_pieces)
#    125982    0.088    0.000    0.088    0.000 fromnumeric.py:72(<dictcomp>)
#    193016    0.044    0.000    0.086    0.000 <string>:1(<lambda>)
#      3717    0.006    0.000    0.084    0.000 utils.py:155(get_tokens)
#       810    0.001    0.000    0.082    0.000 core.py:177(line_range)
#     36/25    0.033    0.001    0.074    0.003 inspect.py:850(getmodule)
#      3717    0.002    0.000    0.074    0.000 lexer.py:258(streamer)
#      3717    0.027    0.000    0.072    0.000 lexer.py:690(get_tokens_unprocessed)
#       173    0.001    0.000    0.070    0.000 __init__.py:1077(flush)
#     15984    0.042    0.000    0.068    0.000 genericpath.py:69(commonprefix)
#    7760/4    0.010    0.000    0.056    0.014 ast.py:414(visit)
#    7658/4    0.021    0.000    0.056    0.014 ast.py:420(generic_visit)
#      4618    0.010    0.000    0.055    0.000 executing.py:157(get_instructions)
#    102/51    0.002    0.000    0.054    0.001 executing.py:549(visit_FunctionDef)
#        11    0.000    0.000    0.054    0.005 executing.py:587(visit_ClassDef)
#      7951    0.010    0.000    0.053    0.000 ast.py:380(walk)
#     88810    0.037    0.000    0.049    0.000 ast.py:255(iter_fields)
#       834    0.001    0.000    0.047    0.000 executing.py:418(asttext)
#         4    0.000    0.000    0.045    0.011 asttokens.py:299(__init__)
#        24    0.000    0.000    0.044    0.002 ultratb.py:161(get_line_number_of_frame)
#         4    0.003    0.001    0.044    0.011 util.py:438(annotate_fstring_nodes)
#        13    0.000    0.000    0.044    0.003 ultratb.py:139(count_lines_in_py_file)
#         4    0.000    0.000    0.042    0.011 core.py:94(pieces)
#       827    0.001    0.000    0.042    0.000 core.py:112(_clean_pieces)
#        15    0.041    0.003    0.041    0.003 {built-in method io.open}
#      7930    0.005    0.000    0.041    0.000 {method 'extend' of 'collections.deque' objects}
#      4618    0.019    0.000    0.041    0.000 dis.py:311(_get_instructions_bytes)
#      4851    0.009    0.000    0.040    0.000 util.py:278(walk)
#         4    0.000    0.000    0.040    0.010 core.py:114(<listcomp>)
#       929    0.003    0.000    0.040    0.000 iostream.py:243(schedule)
# 5514/1009    0.004    0.000    0.040    0.000 core.py:155(_raw_split_into_pieces)
#     36/25    0.000    0.000    0.038    0.002 inspect.py:838(getabsfile)
#         5    0.000    0.000    0.038    0.008 ast.py:33(parse)
#       880    0.001    0.000    0.038    0.000 asttokens.py:382(get_text_positions)
#     98364    0.036    0.000    0.036    0.000 base.py:342(tzinfo_factory)
#        25    0.000    0.000    0.036    0.001 inspect.py:813(getsourcefile)
#        53    0.000    0.000    0.036    0.001 executing.py:759(clean_instructions)
#        53    0.003    0.000    0.036    0.001 executing.py:761(<listcomp>)
#       880    0.003    0.000    0.035    0.000 asttokens.py:334(_get_text_positions_tokenless)
#       810    0.001    0.000    0.034    0.000 utils.py:29(line_range)
#       936    0.034    0.000    0.034    0.000 socket.py:545(send)
#       280    0.001    0.000    0.034    0.000 utils.py:110(group_by_key_func)
#    125982    0.030    0.000    0.030    0.000 fromnumeric.py:2974(_prod_dispatcher)
#      9690    0.008    0.000    0.028    0.000 util.py:148(iter_children_ast)
#      9480    0.009    0.000    0.022    0.000 re.py:269(escape)
#       189    0.001    0.000    0.020    0.000 iostream.py:610(write)
#        36    0.000    0.000    0.019    0.001 executing.py:876(find_codes)
#   1992/36    0.006    0.000    0.018    0.001 executing.py:901(finder)
#     25407    0.018    0.000    0.018    0.000 {method 'index' of 'list' objects}
#     13295    0.014    0.000    0.018    0.000 executing.py:1243(node_linenos)
#    104400    0.018    0.000    0.018    0.000 1255315854.py:51(<lambda>)
#       189    0.001    0.000    0.018    0.000 iostream.py:532(_schedule_flush)
#      1702    0.004    0.000    0.017    0.000 line_numbers.py:37(from_utf8_col)
#     24591    0.017    0.000    0.017    0.000 {built-in method math.ceil}
#     79488    0.016    0.000    0.016    0.000 regexopt.py:78(<lambda>)
#     35707    0.016    0.000    0.016    0.000 {built-in method builtins.max}
#       473    0.016    0.000    0.016    0.000 812580972.py:35(crossover_point)
#      6600    0.016    0.000    0.016    0.000 regexopt.py:66(<listcomp>)
#       991    0.004    0.000    0.016    0.000 1117434174.py:29(mutation_point)
#         2    0.000    0.000    0.015    0.007 terminal256.py:135(__init__)
#        17    0.000    0.000    0.015    0.001 executing.py:616(is_rewritten_by_pytest)
#       906    0.002    0.000    0.014    0.000 executing.py:618(<genexpr>)
#         2    0.002    0.001    0.014    0.007 terminal256.py:224(_setup_styles)
#     32159    0.010    0.000    0.014    0.000 inspect.py:182(ismodule)
#  1455/940    0.001    0.000    0.013    0.000 util.py:393(last_stmt)
#      9480    0.012    0.000    0.012    0.000 {method 'translate' of 'str' objects}
#       860    0.009    0.000    0.012    0.000 line_numbers.py:47(<listcomp>)
#     17836    0.012    0.000    0.012    0.000 {built-in method builtins.min}
#      1455    0.003    0.000    0.012    0.000 util.py:399(<listcomp>)
#  1152/912    0.002    0.000    0.012    0.000 lexer.py:505(_process_new_state)
#       991    0.002    0.000    0.011    0.000 random.py:366(randint)
#        17    0.000    0.000    0.011    0.001 executing.py:914(get_actual_current_instruction)
#         1    0.000    0.000    0.010    0.010 4031027849.py:30(show_config)
#      7200    0.010    0.000    0.010    0.000 1277855371.py:5(__init__)
#         8    0.000    0.000    0.010    0.001 {built-in method builtins.print}
#       178    0.000    0.000    0.010    0.000 __init__.py:1585(makeRecord)
#      4413    0.010    0.000    0.010    0.000 {method 'clear' of 'dict' objects}
#       178    0.003    0.000    0.009    0.000 __init__.py:283(__init__)
#       991    0.004    0.000    0.009    0.000 random.py:292(randrange)
#       416    0.000    0.000    0.008    0.000 terminal256.py:205(_color_index)
#      2736    0.001    0.000    0.008    0.000 re.py:249(compile)
#      1992    0.003    0.000    0.008    0.000 executing.py:890(matches)
#      9236    0.007    0.000    0.008    0.000 dis.py:422(_unpack_opargs)
#        46    0.007    0.000    0.007    0.000 terminal256.py:188(_closest_color)
#      1982    0.006    0.000    0.007    0.000 random.py:239(_randbelow_with_getrandbits)
#      2858    0.004    0.000    0.007    0.000 re.py:288(_compile)
#        87    0.004    0.000    0.007    0.000 dis.py:434(findlabels)
#       991    0.003    0.000    0.006    0.000 random.py:375(choice)
#         1    0.006    0.006    0.006    0.006 {built-in method time.sleep}
#      9408    0.004    0.000    0.005    0.000 inspect.py:379(iscode)
#        70    0.000    0.000    0.005    0.000 asttokens.py:63(get_text_range)
#       368    0.001    0.000    0.005    0.000 threading.py:545(__init__)
#        24    0.004    0.000    0.005    0.000 __init__.py:109(get_lexer_by_name)
#      4013    0.003    0.000    0.005    0.000 token.py:43(__repr__)
#      1297    0.002    0.000    0.004    0.000 threading.py:1169(is_alive)
#        26    0.000    0.000    0.004    0.000 {built-in method builtins.__build_class__}
#        19    0.001    0.000    0.004    0.000 executing.py:984(handle_jumps)
#      1472    0.002    0.000    0.004    0.000 {built-in method builtins.sum}
#       178    0.001    0.000    0.004    0.000 __init__.py:1549(findCaller)
#       268    0.001    0.000    0.003    0.000 ast.py:430(visit_Constant)
#     21980    0.003    0.000    0.003    0.000 typing.py:1737(cast)
#      4164    0.002    0.000    0.003    0.000 executing.py:892(<genexpr>)
#        31    0.003    0.000    0.003    0.000 {built-in method nt.stat}
#     37980    0.003    0.000    0.003    0.000 {method 'encode' of 'str' objects}
#       178    0.000    0.000    0.003    0.000 ntpath.py:240(basename)
#      2784    0.003    0.000    0.003    0.000 regexopt.py:63(<listcomp>)
#       369    0.003    0.000    0.003    0.000 threading.py:236(__init__)
#       178    0.001    0.000    0.003    0.000 ntpath.py:206(split)
#         1    0.000    0.000    0.003    0.003 zmqshell.py:548(_showtraceback)
#       111    0.001    0.000    0.003    0.000 executing.py:180(only)
#       173    0.000    0.000    0.003    0.000 __init__.py:932(format)
#        24    0.001    0.000    0.003    0.000 lexer.py:592(get_tokendefs)
#        24    0.001    0.000    0.003    0.000 asttokens.py:77(get_text)
#         5    0.000    0.000    0.003    0.001 session.py:751(send)
#         1    0.000    0.000    0.002    0.002 executing.py:1210(find_node_ipython)
#         2    0.000    0.000    0.002    0.001 core.py:450(style_with_executing_node)
# ...
#         2    0.000    0.000    0.000    0.000 contextlib.py:279(helper)
#         9    0.000    0.000    0.000    0.000 builtin_trap.py:53(add_builtin)
#        28    0.000    0.000    0.000    0.000 _parser.py:208(isnum)
#         1    0.000    0.000    0.000    0.000 threading.py:389(notify_all)
#         1    0.000    0.000    0.000    0.000 queue.py:154(get)
#         1    0.000    0.000    0.000    0.000 ipkernel.py:237(init_metadata)
#         9    0.000    0.000    0.000    0.000 session.py:280(extract_header)
#        53    0.000    0.000    0.000    0.000 ultratb.py:1517(nullrepr)
#         4    0.000    0.000    0.000    0.000 signal.py:34(_enum_to_int)
#         4    0.000    0.000    0.000    0.000 base_events.py:696(time)
#         1    0.000    0.000    0.000    0.000 _parser.py:233(__len__)
#         1    0.000    0.000    0.000    0.000 base_events.py:427(create_future)
#         2    0.000    0.000    0.000    0.000 _parser.py:1006(_find_hms_idx)
#         7    0.000    0.000    0.000    0.000 typing.py:306(inner)
#         6    0.000    0.000    0.000    0.000 base_futures.py:14(isfuture)
#         2    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:273(create_unicode_buffer)
#         5    0.000    0.000    0.000    0.000 traitlets.py:2146(validate)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.__import__}
#         2    0.000    0.000    0.000    0.000 contextlib.py:102(__init__)
#        12    0.000    0.000    0.000    0.000 jsonutil.py:39(_ensure_tzinfo)
#         1    0.000    0.000    0.000    0.000 display_trap.py:48(__enter__)
#         4    0.000    0.000    0.000    0.000 inputtransformer2.py:80(__call__)
#        14    0.000    0.000    0.000    0.000 _parser.py:203(isword)
#         2    0.000    0.000    0.000    0.000 interactiveshell.py:2501(find_magic)
#         1    0.000    0.000    0.000    0.000 traitlets.py:2863(validate)
#         1    0.000    0.000    0.000    0.000 __init__.py:99(__getattr__)
#         1    0.000    0.000    0.000    0.000 _parser.py:1217(_build_naive)
#         2    0.000    0.000    0.000    0.000 inputtransformer2.py:271(find)
#         4    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#        19    0.000    0.000    0.000    0.000 {method 'index' of 'tuple' objects}
#         4    0.000    0.000    0.000    0.000 events.py:85(trigger)
#        10    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         2    0.000    0.000    0.000    0.000 prefilter.py:406(check)
#         2    0.000    0.000    0.000    0.000 inputtransformer2.py:391(find)
#         2    0.000    0.000    0.000    0.000 contextlib.py:130(__enter__)
#         1    0.000    0.000    0.000    0.000 _parser.py:221(__init__)
#         1    0.000    0.000    0.000    0.000 _parser.py:474(resolve_ymd)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#         6    0.000    0.000    0.000    0.000 {built-in method utcnow}
#         2    0.000    0.000    0.000    0.000 _parser.py:1056(_could_be_tzname)
#         2    0.000    0.000    0.000    0.000 jsonutil.py:77(json_clean)
#         1    0.000    0.000    0.000    0.000 session.py:986(_add_digest)
#        25    0.000    0.000    0.000    0.000 utils.py:79(<lambda>)
#         2    0.000    0.000    0.000    0.000 contextlib.py:139(__exit__)
#         1    0.000    0.000    0.000    0.000 display_trap.py:67(unset)
#         1    0.000    0.000    0.000    0.000 traitlets.py:2340(_validate_bounds)
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         2    0.000    0.000    0.000    0.000 inputtransformer2.py:35(leading_indent)
#         2    0.000    0.000    0.000    0.000 hooks.py:106(__call__)
#         1    0.000    0.000    0.000    0.000 _base.py:410(add_done_callback)
#         1    0.000    0.000    0.000    0.000 _parser.py:1177(_build_tzaware)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:677(init_metadata)
#         2    0.000    0.000    0.000    0.000 kernelbase.py:620(get_parent)
#         4    0.000    0.000    0.000    0.000 six.py:939(ensure_text)
#         2    0.000    0.000    0.000    0.000 ultratb.py:383(_get_chained_exception)
#         1    0.000    0.000    0.000    0.000 _parser.py:62(__init__)
#        13    0.000    0.000    0.000    0.000 _parser.py:234(<genexpr>)
#         1    0.000    0.000    0.000    0.000 display_trap.py:61(set)
#         2    0.000    0.000    0.000    0.000 ipkernel.py:285(execution_count)
#         1    0.000    0.000    0.000    0.000 _base.py:465(exception)
#         1    0.000    0.000    0.000    0.000 _parser.py:1133(_parsems)
#         2    0.000    0.000    0.000    0.000 __init__.py:219(_acquireLock)
#         1    0.000    0.000    0.000    0.000 tempfile.py:297(gettempdir)
#         2    0.000    0.000    0.000    0.000 iostream.py:508(set_parent)
#         1    0.000    0.000    0.000    0.000 queues.py:317(__put_internal)
#         3    0.000    0.000    0.000    0.000 _parser.py:336(hms)
#        18    0.000    0.000    0.000    0.000 executing.py:644(<lambda>)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:283(on_send)
#         4    0.000    0.000    0.000    0.000 util.py:126(iter_children_func)
#         2    0.000    0.000    0.000    0.000 inputtransformer2.py:22(leading_empty_lines)
#         2    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 ipkernel.py:279(_restore_input)
#         7    0.000    0.000    0.000    0.000 {built-in method _bisect.bisect_right}
#         2    0.000    0.000    0.000    0.000 base_events.py:1817(_add_callback)
#        25    0.000    0.000    0.000    0.000 {method 'read' of '_io.StringIO' objects}
#         6    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         2    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         1    0.000    0.000    0.000    0.000 threading.py:90(RLock)
#         2    0.000    0.000    0.000    0.000 prefilter.py:474(check)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:608(set_parent)
#        47    0.000    0.000    0.000    0.000 {built-in method builtins.chr}
#         1    0.000    0.000    0.000    0.000 ast.py:180(copy_location)
#         2    0.000    0.000    0.000    0.000 prefilter.py:418(check)
#         1    0.000    0.000    0.000    0.000 interactiveshell.py:1496(push)
#         1    0.000    0.000    0.000    0.000 payload.py:51(read_payload)
#         2    0.000    0.000    0.000    0.000 {built-in method _signal.signal}
#         1    0.000    0.000    0.000    0.000 _base.py:430(result)
#         1    0.000    0.000    0.000    0.000 _parser.py:395(__init__)
#         4    0.000    0.000    0.000    0.000 compilerop.py:180(extra_flags)
#         1    0.000    0.000    0.000    0.000 traitlets.py:3011(validate_elements)
#         1    0.000    0.000    0.000    0.000 _base.py:385(cancelled)
#         1    0.000    0.000    0.000    0.000 interactiveshell.py:3318(transform_ast)
#        22    0.000    0.000    0.000    0.000 {method 'span' of 're.Match' objects}
#        47    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         1    0.000    0.000    0.000    0.000 interactiveshell.py:2017(_get_exc_info)
#        32    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 _parser.py:329(month)
#         2    0.000    0.000    0.000    0.000 core.py:194(__init__)
#         2    0.000    0.000    0.000    0.000 formatter.py:19(_lookup_style)
#         2    0.000    0.000    0.000    0.000 encoding.py:21(get_stream_enc)
#         3    0.000    0.000    0.000    0.000 {method 'fileno' of '_io.TextIOWrapper' objects}
#         2    0.000    0.000    0.000    0.000 selectors.py:276(_key_from_fd)
#         6    0.000    0.000    0.000    0.000 base_events.py:513(_check_closed)
#         1    0.000    0.000    0.000    0.000 {built-in method now}
#         4    0.000    0.000    0.000    0.000 _parser.py:213(isspace)
#         2    0.000    0.000    0.000    0.000 prefilter.py:256(transform_line)
#         1    0.000    0.000    0.000    0.000 _parser.py:1099(_parse_min_sec)
#         4    0.000    0.000    0.000    0.000 prefilter.py:226(get_handler_by_name)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:350(should_handle)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2608(validate)
#         5    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 {method 'replace' of 'bytes' objects}
#         4    0.000    0.000    0.000    0.000 traitlets.py:2527(validate)
#         1    0.000    0.000    0.000    0.000 session.py:1045(<listcomp>)
#         4    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         2    0.000    0.000    0.000    0.000 inputtransformer2.py:118(cell_magic)
#         1    0.000    0.000    0.000    0.000 ipkernel.py:253(finish_metadata)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3367(validate_elements)
#         2    0.000    0.000    0.000    0.000 _parser.py:319(jump)
#         1    0.000    0.000    0.000    0.000 executing.py:683(<lambda>)
#         2    0.000    0.000    0.000    0.000 inputtransformer2.py:455(find)
#         2    0.000    0.000    0.000    0.000 typing.py:1037(__hash__)
#         6    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         5    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 futures.py:297(_get_loop)
#         2    0.000    0.000    0.000    0.000 __init__.py:1710(getEffectiveLevel)
#         1    0.000    0.000    0.000    0.000 _parser.py:380(validate)
#         1    0.000    0.000    0.000    0.000 logger.py:167(log)
#         4    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         8    0.000    0.000    0.000    0.000 base_events.py:1927(get_debug)
#         2    0.000    0.000    0.000    0.000 _parser.py:322(weekday)
#         1    0.000    0.000    0.000    0.000 interactiveshell.py:1030(_clear_warning_registry)
#         3    0.000    0.000    0.000    0.000 interactiveshell.py:1229(user_global_ns)
#         2    0.000    0.000    0.000    0.000 inspect.py:348(isawaitable)
#         2    0.000    0.000    0.000    0.000 __init__.py:228(_releaseLock)
#         1    0.000    0.000    0.000    0.000 poll.py:29(register)
#         4    0.000    0.000    0.000    0.000 executing.py:1147(setter)
#         1    0.000    0.000    0.000    0.000 session.py:984(<listcomp>)
#         4    0.000    0.000    0.000    0.000 zmqstream.py:533(receiving)
#         2    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#         2    0.000    0.000    0.000    0.000 tokenize.py:614(generate_tokens)
#         2    0.000    0.000    0.000    0.000 prefilter.py:543(handle)
#         1    0.000    0.000    0.000    0.000 _parser.py:354(tzoffset)
#         2    0.000    0.000    0.000    0.000 interactiveshell.py:3424(compare)
#         7    0.000    0.000    0.000    0.000 {method 'isspace' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 _parser.py:342(ampm)
#        14    0.000    0.000    0.000    0.000 {method 'isalpha' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 _parser.py:1061(<genexpr>)
#         1    0.000    0.000    0.000    0.000 os.py:817(fsdecode)
#         1    0.000    0.000    0.000    0.000 queue.py:213(_put)
#         1    0.000    0.000    0.000    0.000 queue.py:217(_get)
#         2    0.000    0.000    0.000    0.000 {built-in method sys.exc_info}
#         1    0.000    0.000    0.000    0.000 interactiveshell.py:219(__init__)
#         1    0.000    0.000    0.000    0.000 profile.py:48(__init__)
#         2    0.000    0.000    0.000    0.000 prefilter.py:432(check)
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:627(_check_closed)
#         2    0.000    0.000    0.000    0.000 {method 'rjust' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 interactiveshell.py:259(success)
#         1    0.000    0.000    0.000    0.000 interactiveshell.py:1109(_get_call_pdb)
#         2    0.000    0.000    0.000    0.000 {method 'groups' of 're.Match' objects}
#         1    0.000    0.000    0.000    0.000 tempfile.py:285(_gettempdir)
#         3    0.000    0.000    0.000    0.000 {method 'is_finite' of 'decimal.Decimal' objects}
#         2    0.000    0.000    0.000    0.000 __init__.py:1307(disable)
#         1    0.000    0.000    0.000    0.000 futures.py:385(_call_check_cancel)
#         2    0.000    0.000    0.000    0.000 prefilter.py:139(transformers)
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         1    0.000    0.000    0.000    0.000 _parser.py:482(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 executing.py:1229(attr_names_match)
#         2    0.000    0.000    0.000    0.000 prefilter.py:175(checkers)
#         1    0.000    0.000    0.000    0.000 traitlets.py:2875(validate_elements)
#         1    0.000    0.000    0.000    0.000 compilerop.py:174(<listcomp>)
#         1    0.000    0.000    0.000    0.000 logger.py:187(log_write)
#         1    0.000    0.000    0.000    0.000 base_events.py:692(is_running)
#         2    0.000    0.000    0.000    0.000 ultratb.py:1030(<genexpr>)
#         2    0.000    0.000    0.000    0.000 hooks.py:88(synchronize_with_editor)
#         1    0.000    0.000    0.000    0.000 {method 'ljust' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 zmqstream.py:419(_finish_flush)
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         1    0.000    0.000    0.000    0.000 {built-in method _hashlib.compare_digest}
#         1    0.000    0.000    0.000    0.000 _base.py:400(__get_result)
#         1    0.000    0.000    0.000    0.000 _parser.py:360(convertyear)
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         2    0.000    0.000    0.000    0.000 inspect.py:1429(<lambda>)
#         1    0.000    0.000    0.000    0.000 _parser.py:186(__iter__)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:371(<lambda>)
#         1    0.000    0.000    0.000    0.000 _parser.py:402(has_year)
#         1    0.000    0.000    0.000    0.000 ultratb.py:401(prepare_chained_exception_message)
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 compiler.py:81(get_tmp_hash_seed)
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_event_loop}
#         3    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 interactiveshell.py:256(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'add_done_callback' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 enum.py:741(_missing_)
#         1    0.000    0.000    0.000    0.000 selector_events.py:109(_process_self_data)
#         1    0.000    0.000    0.000    0.000 session.py:1073(<listcomp>)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:50(stack_context_wrap)
#         1    0.000    0.000    0.000    0.000 ipkernel.py:289(execution_count)
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio._get_event_loop}
#         1    0.000    0.000    0.000    0.000 kernelbase.py:541(<lambda>)
#         1    0.000    0.000    0.000    0.000 {built-in method sys.audit}
#         1    0.000    0.000    0.000    0.000 {method 'get_loop' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:1430(<lambda>)

# %%
best_chromosome = algorithm.get_best_chromosome()

# %%
best_chromosome.fitness
# Out:
# 38

# %%
best_chromosome.genes
# Out:
# [Gene(lab=1, module=1, module_chapter=1, group=1, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=2, group=1, assistant=6, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=1, group=2, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=2, group=2, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift1')),
#  Gene(lab=1, module=1, module_chapter=1, group=3, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=2, group=3, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=1, group=4, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 19, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Monday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=2, group=4, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift1')),
#  Gene(lab=1, module=1, module_chapter=1, group=5, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 24, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Saturday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=2, group=5, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift1')),
#  Gene(lab=1, module=1, module_chapter=1, group=6, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 24, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Saturday', shift='Shift1')),
#  Gene(lab=1, module=1, module_chapter=2, group=6, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=1, group=7, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=2, group=7, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=1, group=8, assistant=6, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 19, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Monday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=2, group=8, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 24, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Saturday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=1, group=9, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=2, group=9, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=1, group=10, assistant=6, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=2, group=10, assistant=6, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=1, group=11, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 24, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Saturday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=2, group=11, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=1, group=12, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=2, group=12, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=1, group=13, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=2, group=13, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 24, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Saturday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=1, group=14, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=2, group=14, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=1, group=15, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 24, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Saturday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=2, group=15, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift1')),
#  Gene(lab=1, module=1, module_chapter=1, group=16, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=2, group=16, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=1, group=17, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=2, group=17, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=1, group=18, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=2, group=18, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=1, group=19, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 19, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Monday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=2, group=19, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=1, group=20, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift1')),
#  Gene(lab=1, module=1, module_chapter=2, group=20, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=1, group=21, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=2, group=21, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=1, group=22, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=2, group=22, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=1, group=23, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=2, group=23, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift4')),
#  Gene(lab=1, module=1, module_chapter=1, group=24, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=2, group=24, assistant=4, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 19, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Monday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=1, group=25, assistant=6, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 19, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Monday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=2, group=25, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=1, group=26, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 19, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Monday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=2, group=26, assistant=6, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=1, group=27, assistant=6, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=2, group=27, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=1, group=28, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=2, group=28, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=1, group=29, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 24, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Saturday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=2, group=29, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=1, group=30, assistant=3, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 21, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Wednesday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=2, group=30, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=1, group=31, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 19, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Monday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=2, group=31, assistant=1, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=1, group=32, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 24, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Saturday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=2, group=32, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift6')),
#  Gene(lab=1, module=1, module_chapter=1, group=33, assistant=6, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift1')),
#  Gene(lab=1, module=1, module_chapter=2, group=33, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 19, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Monday', shift='Shift1')),
#  Gene(lab=1, module=1, module_chapter=1, group=34, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 19, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Monday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=2, group=34, assistant=6, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 22, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Thursday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=1, group=35, assistant=2, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 24, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Saturday', shift='Shift5')),
#  Gene(lab=1, module=1, module_chapter=2, group=35, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift3')),
#  Gene(lab=1, module=1, module_chapter=1, group=36, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 20, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Tuesday', shift='Shift2')),
#  Gene(lab=1, module=1, module_chapter=2, group=36, assistant=5, time_slot=TimeSlot(date=datetime.datetime(2022, 9, 23, 7, 30, 0, 530000, tzinfo=datetime.timezone.utc), day='Friday', shift='Shift2'))]

# %% [markdown]
# ##### Test Data

# %%
# display best chromosome on pandas dataframe, group each gene by date and shift, which the assistant as the column and show the group as the value
import pandas as pd
data = []
for gene in best_chromosome.genes:
    data.append([gene.time_slot.date, gene.time_slot.shift, gene.assistant, gene.group])
df = pd.DataFrame(data, columns=["Date", "Shift", "Assistant", "Group"])
df = df.groupby(["Date", "Shift", "Assistant"])["Group"].apply(list).reset_index()
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 4
#       2 import pandas as pd
#       3 data = []
# ----> 4 for gene in best_chromosome.genes:
#       5     data.append([gene.time_slot.date, gene.time_slot.shift, gene.assistant, gene.group])
#       6 df = pd.DataFrame(data, columns=["Date", "Shift", "Assistant", "Group"])
#
# NameError: name 'best_chromosome' is not defined

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')
start_date = df["Date"].min()
date_interval = pd.DateOffset(days=7)

weekly_schedule = []
while start_date <= df["Date"].max():
    end_date = start_date + date_interval
    weekly_df = df[(df["Date"] >= start_date) & (df["Date"] < end_date)]
    # fill missing values with empty list
    weekly_schedule.append(weekly_df.pivot_table(index=["Date", "Shift"], columns="Assistant", values="Group", aggfunc=lambda x: x))
    start_date = end_date

for i, weekly_df in enumerate(weekly_schedule):
    print(f"Week {i+1}")
    # Format date to dd-mm-yyyy
    weekly_df.index = weekly_df.index.set_levels(weekly_df.index.levels[0].strftime('%d-%m-%Y'), level=0)
    print(weekly_df)
    print("\n")
# Out:
# Week 1
# Assistant                1         2             3         4        5        6
# Date       Shift
# 19-09-2022 Shift1      NaN       NaN           NaN       NaN     [33]      NaN
#            Shift2      NaN       NaN           NaN       NaN      NaN  [8, 25]
#            Shift3      NaN  [31, 34]           NaN      [24]      NaN      NaN
#            Shift4      NaN       [4]           NaN       NaN      NaN      NaN
#            Shift5      NaN       NaN          [26]       NaN     [19]      NaN
# 20-09-2022 Shift1      NaN       NaN           [2]       NaN      NaN      NaN
#            Shift2      NaN       NaN      [20, 21]  [12, 21]     [36]      NaN
#            Shift3      NaN       NaN          [14]       NaN     [24]      NaN
#            Shift4     [16]       NaN           NaN       NaN      NaN      NaN
#            Shift5     [31]  [13, 27]           NaN    [7, 9]      NaN     [10]
#            Shift6      NaN       NaN           NaN       NaN     [29]      NaN
# 21-09-2022 Shift1      NaN       NaN           NaN      [20]      NaN      NaN
#            Shift2      NaN       NaN           NaN      [11]      [7]      NaN
#            Shift3      NaN       NaN  [18, 19, 30]       NaN      NaN      NaN
#            Shift4     [14]       NaN           NaN       NaN      NaN      NaN
#            Shift6      NaN       NaN       [3, 25]       NaN      NaN      [1]
# 22-09-2022 Shift1      NaN       [4]           NaN       NaN      NaN      NaN
#            Shift2      NaN       NaN           NaN       NaN      NaN     [10]
#            Shift3      NaN       NaN           NaN       NaN     [30]      NaN
#            Shift4     [17]      [17]           NaN      [23]     [12]      NaN
#            Shift5      NaN       [1]           NaN       NaN      NaN     [34]
#            Shift6      NaN  [18, 22]           NaN       [9]      NaN     [26]
# 23-09-2022 Shift1      NaN      [15]           NaN       [5]      NaN     [33]
#            Shift2      NaN       NaN          [28]       NaN     [36]      NaN
#            Shift3     [22]       NaN           NaN       NaN  [3, 35]      NaN
#            Shift4  [2, 16]       NaN           NaN       NaN      NaN      NaN
#            Shift5     [23]       NaN           NaN       NaN      NaN      NaN
#            Shift6      NaN      [32]          [28]       [6]      NaN     [27]
# 24-09-2022 Shift1      [6]       NaN           NaN       NaN      NaN      NaN
#            Shift2      [8]       NaN          [29]       NaN     [32]      NaN
#            Shift3      NaN       NaN      [13, 15]       NaN      NaN      NaN
#            Shift4      [5]       NaN           NaN       NaN      NaN      NaN
#            Shift5      NaN      [35]           NaN       NaN      NaN      NaN
#            Shift6      NaN      [11]           NaN       NaN      NaN      NaN

# %%
# Count total of shifts and group for each assistant, each shift of the same day with different group is counted as 1

assistant_shifts = defaultdict(set)
assistant_groups = defaultdict(set)
assistant_modules = defaultdict(set)

for gene in best_chromosome.genes:
    assistant_shifts[gene.assistant].add((gene.time_slot.date, gene.time_slot.shift, gene.module))
    assistant_groups[gene.assistant].add((gene.time_slot.date, gene.time_slot.shift, gene.group, gene.module))


#sort by assistant id
assistant_shifts = dict(sorted(assistant_shifts.items()))
for assistant in assistant_shifts:
    assistant_name = assistant_data.get_assistant(assistant)
    print(f"Assistant {assistant_name} of {assistant_name.laboratory}")
    print(f"Total shifts: {len(assistant_shifts[assistant])}")
    print(f"Total groups: {len(assistant_groups[assistant])}")
    print("---------------------------------")
# Out:
# Assistant Fatimah of Dasar Elektro
# Total shifts: 10
# Total groups: 11
# ---------------------------------
# Assistant Rahmat of Dasar Elektro
# Total shifts: 11
# Total groups: 14
# ---------------------------------
# Assistant Amel of Dasar Elektro
# Total shifts: 10
# Total groups: 15
# ---------------------------------
# Assistant Bowo of Dasar Elektro
# Total shifts: 9
# Total groups: 11
# ---------------------------------
# Assistant Rafli of Dasar Elektro
# Total shifts: 11
# Total groups: 12
# ---------------------------------
# Assistant Andi of Dasar Elektro
# Total shifts: 8
# Total groups: 9
# ---------------------------------

# %% [markdown]
# # Tabu Search
#
# ```python

# %%
#tabu search
import collections
from copy import deepcopy
import numpy as np
import itertools
import random

# %% [markdown]
# ## Tabu List

# %%
# Tabu Search Operators
import collections
class TabuList:
    def __init__(self, tabu_list_size):
        """"
        Tabu list class for managing tabu list
        :param tabu_list_size: Tabu list size
        :type tabu_list_size: int
        """
        self.tabu_list_size = tabu_list_size
        self.tabu_list = collections.deque(maxlen=tabu_list_size)
    
    def __repr__(self):
        return f"Tabu List Size: {self.tabu_list_size}, Tabu List: {self.tabu_list}"
    
    def __str__(self):
        return f"Tabu List Size: {self.tabu_list_size}, Tabu List: {self.tabu_list}"
    
    def is_tabu(self, chromosome: Chromosome):
        '''
        Check if chromosome is in tabu list
        :param chromosome: Chromosome
        :type chromosome: Chromosome
        :return: bool
        '''
        return chromosome in self.tabu_list
        
    
    def clear(self):
        '''
        Clear tabu list
        :return: None
        '''
        self.tabu_list.clear()
    
    def update(self, chromosome):
        '''
        Update tabu list
        :param chromosome: Chromosome
        :type chromosome: Chromosome
        :return: None
        '''
        self.tabu_list.append(chromosome)

# %% [markdown]
# ## Neighborhood Operation

# %%
# Neighborhood Operators

import itertools
from copy import deepcopy
import numpy as np
class Neighborhood:
    def __init__(self, tabu_list: TabuList):
        self.tabu_list = tabu_list
    
    def swap(self, chromosome: Chromosome):
        '''
        Swap two adjacent genes
        :param chromosome: Chromosome
        :type chromosome: Chromosome
        :return: Chromosome
        '''
        if settings.DEBUG:
            logger.info("Swapping...")
        new_chromosome = deepcopy(chromosome)
        max_distance = min(2, len(new_chromosome.genes) - 1)
        swap_attempt = min(2, len(new_chromosome.genes) // 2)

        for _ in range(swap_attempt):
            gene1, gene2 = np.random.choice(new_chromosome.genes, 2, replace=False)
            if abs(new_chromosome.genes.index(gene1) - new_chromosome.genes.index(gene2)) <= max_distance:
                if gene1.module == gene2.module:
                    gene1.assistant, gene2.assistant = gene2.assistant, gene1.assistant
                    gene1.time_slot, gene2.time_slot = gene2.time_slot, gene1.time_slot
                if not self.tabu_list.is_tabu(new_chromosome):
                    logger.info("Swapped! gene1 index: {}, gene2 index: {}".format(new_chromosome.genes.index(gene1), new_chromosome.genes.index(gene2)))
                    return new_chromosome
                else:
                    if gene1.module == gene2.module:
                        gene1.assistant, gene2.assistant = gene2.assistant, gene1.assistant
                        gene1.time_slot, gene2.time_slot = gene2.time_slot, gene1.time_slot
    
    def swap_random(self, chromosome: Chromosome):
        '''
        Swap two random genes
        :param chromosome: Chromosome
        :type chromosome: Chromosome
        :return: Chromosome
        '''
        if settings.DEBUG:
            logger.info("Swapping random...")
        new_chromosome = deepcopy(chromosome)
        swap_attempt = min(2, len(new_chromosome.genes) // 2)
        for _ in range(swap_attempt):
            gene1, gene2 = np.random.choice(new_chromosome.genes, 2, replace=False)
            if gene1.module == gene2.module:
                gene1.assistant, gene2.assistant = gene2.assistant, gene1.assistant
                gene1.time_slot, gene2.time_slot = gene2.time_slot, gene1.time_slot
            if not self.tabu_list.is_tabu(new_chromosome):
                logger.info("Swapped! gene1 index: {}, gene2 index: {}".format(new_chromosome.genes.index(gene1), new_chromosome.genes.index(gene2)))
                return new_chromosome
            else:
                if gene1.module == gene2.module:
                    gene1.assistant, gene2.assistant = gene2.assistant, gene1.assistant
                    gene1.time_slot, gene2.time_slot = gene2.time_slot, gene1.time_slot

        
    def run(self, chromosome: Chromosome):
        '''
        Run neighborhood operators
        :param chromosome: Chromosome
        :type chromosome: Chromosome
        :return: list
        '''
        if settings.DEBUG:
            logger.info("Running neighborhood operators...")
        neighborhood = []
        neighborhood.append(self.swap(chromosome))
        #neighborhood.append(self.swap_random(chromosome))

        neighborhood = [neighbor for neighbor in neighborhood if neighbor is not None]
        return neighborhood

# %%
# Test Neighborhood
tabu_list = TabuList(tabu_list_size=10)
neighborhood = Neighborhood(tabu_list)
best_chromosome = algorithm.get_best_chromosome()

len(best_chromosome.genes)
# Out:
# 72

# %% [markdown]
# ## Search Strategy
#
# ```python

# %%
# Strategy Operators
# Best Improvement, First Improvement, Random

class Strategy:
    def __init__(self, tabu_list: TabuList, fitness_function: FitnessFunction):
        self.tabu_list = tabu_list
        self.fitness_function = fitness_function
    
    def best_improvement(self, neighborhood: list) -> Chromosome:
        '''
        Best improvement strategy
        :param neighborhood: Neighborhood
        :type neighborhood: list
        :return: Chromosome
        '''
        if settings.DEBUG:
            logger.info("Best improvement...")
        best_chromosome = None
        best_fitness = 0
        for chromosome in neighborhood:
            fitness = self.fitness_function.calculate_fitness(chromosome)
            logger.info(f"Fitness: {fitness}, Best fitness: {best_fitness}")

            if fitness > best_fitness:
                best_fitness = fitness
                best_chromosome = chromosome
        return best_chromosome
    
    def first_improvement(self, neighborhood: list) -> Chromosome:
        '''
        First improvement strategy
        :param neighborhood: Neighborhood
        :type neighborhood: list
        :return: Chromosome
        '''
        if settings.DEBUG:
            logger.info("First improvement...")
        for chromosome in neighborhood:
            if not self.tabu_list.is_tabu(chromosome):
                return chromosome
        return None
    
    def random(self, neighborhood: list) -> Chromosome:
        '''
        Random strategy
        :param neighborhood: Neighborhood
        :type neighborhood: list
        :return: Chromosome
        '''
        if settings.DEBUG:
            logger.info("Random...")
        return random.choice(neighborhood)
    
    def run(self, neighborhood: list, method: str = "best_improvement") -> Chromosome:
        '''
        Run strategy
        :param neighborhood: Neighborhood
        :type neighborhood: list
        :return: Chromosome
        '''
        if method == "best_improvement":
            selected_strategy = self.best_improvement
        elif method == "first_improvement":
            selected_strategy = self.first_improvement
        elif method == "random":
            selected_strategy = self.random
        return selected_strategy(neighborhood)

# %% [markdown]
# ## Tabu Search Algorithm
#
# ```python

# %%
# Tabu Search
class TabuSearch:
    def __init__(self, tabu_list: TabuList, neighborhood: Neighborhood, strategy: Strategy, fitness_function: FitnessFunction, max_iteration: int = 100):
        self.tabu_list = tabu_list
        self.neighborhood = neighborhood
        self.strategy = strategy
        self.max_iteration = max_iteration
        self.fitness_function = fitness_function
        self.fitness_function.initialize()
        
    
    def search(self, chromosome: Chromosome, method: str = "swap") -> Chromosome:
        '''
        Tabu search
        :param chromosome: Chromosome
        :type chromosome: Chromosome
        :return: Chromosome
        '''
        self.tabu_list.clear()
        if settings.DEBUG:
            logger.info("Tabu search...")
        iteration = 0
        best_chromosome = chromosome
        while iteration < self.max_iteration:
            iteration += 1
            neighborhood = self.neighborhood.run(best_chromosome)
            logger.info(f"Neighborhood size: {len(neighborhood)}")
            best_chromosome = self.strategy.run(neighborhood, method="best_improvement")
            self.tabu_list.update(best_chromosome)
            logger.info(f"Iteration {iteration}, Best fitness: {best_chromosome.fitness}")
        return best_chromosome

# %%
chromosome = best_chromosome
tabu_list = TabuList(tabu_list_size=5)
fitness_function = FitnessFunction()
fitness_function.max_groups_per_assistant = 15
fitness_function.max_shift_per_assistant = 15
neighborhood = Neighborhood(tabu_list)
strategy = Strategy(tabu_list, fitness_function)
tabu_search = TabuSearch(tabu_list, neighborhood, strategy, max_iteration=20, fitness_function=fitness_function)
settings.DEBUG = False
best_chromosome_tabu = tabu_search.search(chromosome, method="swap")
# Out:
# INFO:__main__:Neighborhood size: 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Projects\Kuliah\skripsi\jte-lab-timetabling\LabTimetablingAPI\Sistem_penjadwalan GA dan TS weekly.ipynb Cell 99 line 1
#       <a href='vscode-notebook-cell:/d%3A/Projects/Kuliah/skripsi/jte-lab-timetabling/LabTimetablingAPI/Sistem_penjadwalan%20GA%20dan%20TS%20weekly.ipynb#Y200sZmlsZQ%3D%3D?line=7'>8</a> tabu_search = TabuSearch(tabu_list, neighborhood, strategy, max_iteration=20, fitness_function=fitness_function)
#       <a href='vscode-notebook-cell:/d%3A/Projects/Kuliah/skripsi/jte-lab-timetabling/LabTimetablingAPI/Sistem_penjadwalan%20GA%20dan%20TS%20weekly.ipynb#Y200sZmlsZQ%3D%3D?line=8'>9</a> settings.DEBUG = False
# ---> <a href='vscode-notebook-cell:/d%3A/Projects/Kuliah/skripsi/jte-lab-timetabling/LabTimetablingAPI/Sistem_penjadwalan%20GA%20dan%20TS%20weekly.ipynb#Y200sZmlsZQ%3D%3D?line=9'>10</a> best_chromosome_tabu = tabu_search.search(chromosome, method="swap")
#
# d:\Projects\Kuliah\skripsi\jte-lab-timetabling\LabTimetablingAPI\Sistem_penjadwalan GA dan TS weekly.ipynb Cell 99 line 3
#      <a href='vscode-notebook-cell:/d%3A/Projects/Kuliah/skripsi/jte-lab-timetabling/LabTimetablingAPI/Sistem_penjadwalan%20GA%20dan%20TS%20weekly.ipynb#Y200sZmlsZQ%3D%3D?line=27'>28</a>     best_chromosome = self.strategy.run(neighborhood, method="best_improvement")
#      <a href='vscode-notebook-cell:/d%3A/Projects/Kuliah/skripsi/jte-lab-timetabling/LabTimetablingAPI/Sistem_penjadwalan%20GA%20dan%20TS%20weekly.ipynb#Y200sZmlsZQ%3D%3D?line=28'>29</a>     self.tabu_list.update(best_chromosome)
# ---> <a href='vscode-notebook-cell:/d%3A/Projects/Kuliah/skripsi/jte-lab-timetabling/LabTimetablingAPI/Sistem_penjadwalan%20GA%20dan%20TS%20weekly.ipynb#Y200sZmlsZQ%3D%3D?line=29'>30</a>     logger.info(f"Iteration {iteration}, Best fitness: {best_chromosome.fitness}")
#      <a href='vscode-notebook-cell:/d%3A/Projects/Kuliah/skripsi/jte-lab-timetabling/LabTimetablingAPI/Sistem_penjadwalan%20GA%20dan%20TS%20weekly.ipynb#Y200sZmlsZQ%3D%3D?line=30'>31</a> return best_chromosome
#
# AttributeError: 'NoneType' object has no attribute 'fitness'

# %%
# Out:
# False

# %%
class TabuSearchBuilder:
    def __init__(self):
        self.tabu_list_size = None
        self.max_iteration = None
        self.neighborhood_method = None
        self.search_strategy = None
        self.factory = Factory()
        self.fitness_function = FitnessFunction()
        self.tabu_list = TabuList(self.tabu_list_size)
        self.neighborhood = Neighborhood()
        self.logging = False
        self._results = defaultdict(list)
        self._best_chromosome = None
        self._best_fitness = None
        self._best_iteration = None
        self._best_chromosome_history = []
        self._best_fitness_history = []
    
    def set_tabu_list_size(self, tabu_list_size):
        self.tabu_list_size = tabu_list_size
        return self
    
    def set_max_iteration(self, max_iteration):
        self.max_iteration = max_iteration
        return self
    
    def set_neighborhood_method(self, neighborhood_method):
        self.neighborhood_method = neighborhood_method
        return self
    
    def set_search_strategy(self, search_strategy):
        self.search_strategy = search_strategy
        return self
    
    def set_factory(self, factory):
        self.factory = factory
        return self
    
    def set_fitness_function(self, fitness_function):
        self.fitness_function = fitness_function
        return self
    
    def set_logging(self, logging):
        self.logging = logging
        return self
    
    def get_results(self):
        return self._results
    
    def get_best_chromosome(self):
        return self._best_chromosome
    
    def get_best_fitness(self):
        return self._best_fitness
    
    def get_best_iteration(self):
        return self._best_iteration
    
    def get_best_chromosome_history(self):
        return self._best_chromosome_history
    
    def get_best_fitness_history(self):
        return self._best_fitness_history
    
    def build(self):
        if self.tabu_list_size is None:
            raise ValueError("Tabu list size is not set")
        if self.max_iteration is None:
            raise ValueError("Max iteration is not set")
        if self.neighborhood_method is None:
            raise ValueError("Neighborhood method is not set")
        if self.search_strategy is None:
            raise ValueError("Search strategy is not set")
        if self.factory is None:
            raise ValueError("Factory is not set")
        if self.fitness_function is None:
            raise ValueError("Fitness function is not set")
        return TabuSearch(self)

# %%
# #test TabuSearch
builder = TabuSearchBuilder()
builder.tabu_list_size = 10
builder.max_iteration = 100
builder.neighborhood_method = "swap"
builder.search_strategy = FirstImprovementStrategy(max_iteration=100)
builder.factory = Factory()
builder.fitness_function = FitnessFunction()
builder.logging = True
tabu_search = builder.build()
